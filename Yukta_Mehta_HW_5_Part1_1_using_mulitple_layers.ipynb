# %% [markdown]
# #GAN
#
# # Generative Adverserial Networks in PyTorch
#
# Deep neural networks are used mainly for supervised learning: classification or regression. Generative Adverserial Networks or GANs, however, use neural networks for a very different purpose: Generative modeling
#
# > Generative modeling is an unsupervised learning task in machine learning that involves automatically discovering and learning the regularities or patterns in input data in such a way that the model can be used to generate or output new examples that plausibly could have been drawn from the original dataset. - [Source](https://machinelearningmastery.com/what-are-generative-adversarial-networks-gans/)
#
# While there are many approaches used for generative modeling, a Generative Adverserial Network takes the following approach:
#
# ![GAN Flowchart](https://i.imgur.com/6NMdO9u.png)
#
# There are two neural networks: a *Generator* and a *Discriminator*. The generator generates a "fake" sample given a random vector/matrix, and the discriminator attempts to detect whether a given sample is "real" (picked from the training data) or "fake" (generated by the generator). Training happens in tandem: we train the discriminator for a few epochs, then train the generator for a few epochs, and repeat. This way both the generator and the discriminator get better at doing their jobs. This rather simple approach can lead to some astounding results. The following images ([source](https://machinelearningmastery.com/resources-for-getting-started-with-generative-adversarial-networks/)), for instances, were all generated using GANs:
#
# <img src="https://3qeqpr26caki16dnhd19sv6by6v-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Example-of-Photorealistic-Human-Faces-Generated-by-a-GAN.png" alt="gans_results" width="480">
#
#
# GANs however, can be notoriously difficult to train, and are extremely sensitive to hyperparameters, activation functions and regularization. In this tutorial, we'll train a GAN to generate images of handwritten digits similar to those from the Fashion MNIST database.
#
# <img src="https://datasets.activeloop.ai/wp-content/uploads/2022/09/Fashion-MNIST-dataset-Activeloop-Platform-visualization-image.webp" width="360" >
#
# Most of the code for this tutorial has been borrowed for this excellent repository of PyTorch tutorials: [github.com/yunjey/pytorch-tutorial](https://github.com/yunjey/pytorch-tutorial). Here's what we're going to do:
#
# * Define the problem statement
# * Load the data (with transforms and normalization)
#     * Denormalize for visual inspection of samples
# * Define the Discriminator network
#     * Study the activation function: Leaky ReLU
# * Define the Generator network
#     * Explain the output activation function: TanH
#     * Look at some sample outputs
# * Define losses, optimizers and helper functions for training
#     * For discriminator
#     * For generator
# * Train the model
#     * Save intermediate generated images to file
# * Look at some outputs
# * Save the models
# * Commit to Jovian.ml

# %% [markdown]
# #Step1. Load the Fashion MNIST dataset
#
# ## Load the Data
#
# We begin by downloading and importing the data as a PyTorch dataset using the `MNIST` helper class from `torchvision.datasets`.

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import FashionMNIST

mnist = FashionMNIST(root='data',
              train=True,
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))

# %% [markdown]
# Note that we are are transforming the pixel values from the range `[0, 1]` to the range `[-1, 1]`. The reason for doing this will become clear when define the generator network. Let's look at a sample tensor from the data.

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  9
# tensor([[[-1.0000, -1.0000, -1.0000,  0.5137,  0.7882],
#          [-0.9765, -1.0000, -0.9059,  0.7176,  0.7255],
#          [-0.9529, -1.0000, -0.2235,  0.9137,  0.7412],
#          [-1.0000, -1.0000, -0.5686,  0.8510,  0.7882],
#          [-1.0000, -1.0000,  0.8588,  0.7725,  0.7020]]])
# (tensor(-1.), tensor(1.))

# %% [markdown]
# There are total 9 classes
#
# As expected, the pixel values range from -1 to 1. Let's define a helper to denormalize and view the images. This function will also be useful for viewing the generated images.
#
# (tensor(-1.), tensor(1.))

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 9

# %% [markdown]
# Finally, let's create a dataloader to load the images in batches.

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([1, 9, 1, 4, 2, 2, 2, 0, 8, 6, 4, 1, 1, 2, 9, 1, 2, 3, 8, 5, 3, 1, 3, 9,
#         2, 7, 6, 6, 0, 8, 1, 7, 6, 4, 9, 6, 7, 7, 8, 3, 3, 9, 2, 0, 5, 4, 5, 3,
#         5, 4, 8, 8, 9, 2, 7, 5, 9, 1, 1, 2, 5, 7, 6, 0, 2, 4, 8, 6, 3, 9, 2, 2,
#         4, 0, 6, 5, 7, 9, 7, 1, 7, 2, 9, 4, 6, 4, 4, 8, 5, 6, 8, 9, 4, 7, 7, 2,
#         5, 6, 9, 4])

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## Discriminator Network
#
# The discriminator takes an image as input, and tries to classify it as "real" or "generated". In this sense, it's like any other neural network. While we can use a CNN for the discriminator, we'll use a simple feedforward network with 3 linear layers to keep things since. We'll treat each 28x28 image as a vector of size 784.

# %%
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn



D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),  # Additional layer
    nn.LeakyReLU(0.2),  # Activation function
    nn.Linear(hidden_size, hidden_size),  # Additional layer
    nn.LeakyReLU(0.2),  # Activation function
    nn.Linear(hidden_size, 1),
    nn.Sigmoid()
)

# %% [markdown]
# We use the Leaky ReLU activation for the discriminator.
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*ypsvQH7kvtI2BhzR2eT_Sw.png" width="420">
#
#
# >  Different from the regular ReLU function, Leaky ReLU allows the pass of a small gradient signal for negative values. As a result, it makes the gradients from the discriminator flows stronger into the generator. Instead of passing a gradient (slope) of 0 in the back-prop pass, it passes a small negative gradient.  - [Source](https://sthalles.github.io/advanced_gans/)
#
# Just like any other binary classification model, the output of the discriminator is a single number between 0 and 1, which can be interpreted as the probability of the input image being fake i.e. generated.
#
# Let's move the discriminator model to the chosen device.
#
# In the context of PyTorch or similar deep learning frameworks, the expression D.to(device) is used to move a tensor or a model to a specific device for computation, such as a CPU or a GPU. Let me break it down for you:
#
# Tensor or Model: D represents either a tensor (data) or a model (neural network) object in PyTorch.
#
# .to(device): This is a method in PyTorch that allows you to specify the device where you want to perform computations. The device argument specifies the target device, which can be a CPU or a GPU. For example:
#
# device='cpu': Indicates that computations should be performed on the CPU.
# device='cuda:0' or device='cuda:1': Indicates that computations should be performed on a specific GPU. The number after cuda: refers to the GPU index.

# %%
D.to(device);

# %% [markdown]
# ## Generator Network
#
# The input to the generator is typically a vector or a matrix which is used as a seed for generating an image. Once again, to keep things simple, we'll use a feedfoward neural network with 3 layers, and the output will be a vector of size 784, which can be transformed to a 28x28 px image.

# %% [markdown]
# Generative Adversarial Networks (GANs), the term latent_size = 64 typically refers to the dimensionality of the latent space.
#
# Latent Space: The latent space is a lower-dimensional space where the model learns to represent the underlying structure or features of the input data in a more compact form. In VAEs and GANs, the latent space represents the space of encoded or generated data points.
#
# The latent_size = 64 statement indicates that the dimensionality of the latent space is 64. This means that each data point in the latent space is represented by a vector of 64 numbers.

# %%
latent_size = 64

# %%
# G = nn.Sequential(
#     nn.Linear(latent_size, hidden_size),
#     nn.ReLU(),
#     nn.Linear(hidden_size, hidden_size),
#     nn.ReLU(),
#     nn.Linear(hidden_size, image_size),
#     nn.Tanh())


# D = nn.Sequential(
#     nn.Linear(image_size, hidden_size),
#     nn.LeakyReLU(0.2),
#     nn.Linear(hidden_size, hidden_size),
#     nn.LeakyReLU(0.2),
#     nn.Linear(hidden_size, 1),
#     nn.Sigmoid())


G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),  # Additional layer
    nn.ReLU(),  # Activation function
    nn.Linear(hidden_size, hidden_size),  # Additional layer
    nn.ReLU(),  # Activation function
    nn.Linear(hidden_size, image_size),
    nn.Tanh()
)

# %% [markdown]
# We use the TanH activation function for the output layer of the generator.
#
# <img src="https://nic.schraudolph.org/teach/NNcourse/figs/tanh.gif" width="420" >
#
# > "The ReLU activation (Nair & Hinton, 2010) is used in the generator with the exception of the output layer which uses the Tanh function. We observed that using a bounded activation allowed the model to learn more quickly to saturate and cover the color space of the training distribution. Within the discriminator we found the leaky rectified activation (Maas et al., 2013) (Xu et al., 2015) to work well, especially for higher resolution modeling." - [Source](https://stackoverflow.com/questions/41489907/generative-adversarial-networks-tanh)
#
#
# Note that since the outputs of the TanH activation lie in the range `[-1,1]`, we have applied the same transformation to the images in the training dataset. Let's generate an output vector using the generator and view it as an image by transforming and denormalizing the output.

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %% [markdown]
# As one might expect, the output from the generator is basically random noise. Let's define a helper function which can save a batch of outputs from the generator to a file.
#
# Let's move the generator to the chosen device.

# %%
G.to(device);

# %% [markdown]
# ## Discriminator Training
#
# Since the discriminator is a binary classification model, we can use the binary cross entropy loss function to quantify how well it is able to differentiate between real and generated images.
#
# <img src="https://image.slidesharecdn.com/chrishokamp-dublinnlp3-160805110319/95/task-based-learning-for-nlp-going-beyond-cross-entropy-chris-hokamp-10-638.jpg?cb=1470395213" width="420" >

# %%
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %% [markdown]
# Let's define helper functions to reset gradients and  train the discriminator.

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)

    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()

    return d_loss, real_score, fake_score

# %% [markdown]
# Here are the steps involved in training the discriminator.
#
# - We expect the discriminator to output 1 if the image was picked from the real MNIST dataset, and 0 if it was generated.
#
# - We first pass a batch of real images, and compute the loss, setting the target labels to 1.
#
# - Then, we generate a batch of fake images using the generator, pass them into the discriminator, and compute the loss, setting the target labels to 0.
#
# - Finally we add the two losses and use the overall loss to perform gradient descent to adjust the weights of the discriminator.
#
# It's important to note that we don't change the weights of the generator model while training the discriminator (`d_optimizer` only affects the `D.parameters()`)

# %% [markdown]
# # Step2. Train the GAN model to produce images in this new domain.

# %% [markdown]
# ## Generator Training
#
# Since the outputs of the generator are images, it's not obvious how we can train the generator. This is where we employ a rather elegant trick, which is to use the discriminator as a part of the loss function. Here's how it works:
#
# - We generate a batch of images using the generator, pass the into the discriminator.
#
# - We calculate the loss by setting the target labels to 1 i.e. real. We do this because the generator's objective is to "fool" the discriminator.
#
# - We use the loss to perform gradient descent i.e. change the weights of the generator, so it gets better at generating real-like images.
#
# Here's what this looks like in code.

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# ## Training the Model
#
# Let's create a directory where we can save intermediate outputs from the generator to visually inspect the progress of the model

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break

Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# We'll also define a helper function to save a batch of generated images to disk at the end of every epoch. We'll use a fixed set of input vectors to the generator to see how the individual generated images evolve over time as we train the model.

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)

# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# We are now ready to train the model. In each epoch, we train the discriminator first, and then the generator. The training might take a while if you're not using a GPU.

# %%
# %%time

num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)

        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.0751, g_loss: 5.6517, D(x): 0.97, D(G(z)): 0.03
# Epoch [0/300], Step [400/600], d_loss: 0.0471, g_loss: 6.9961, D(x): 0.99, D(G(z)): 0.03
# Epoch [0/300], Step [600/600], d_loss: 0.1394, g_loss: 8.4025, D(x): 0.97, D(G(z)): 0.07
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.1246, g_loss: 5.9928, D(x): 0.97, D(G(z)): 0.02
# Epoch [1/300], Step [400/600], d_loss: 0.0794, g_loss: 8.6196, D(x): 0.97, D(G(z)): 0.01
# Epoch [1/300], Step [600/600], d_loss: 0.2923, g_loss: 8.7440, D(x): 0.93, D(G(z)): 0.00
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.1212, g_loss: 6.7930, D(x): 0.97, D(G(z)): 0.05
# Epoch [2/300], Step [400/600], d_loss: 0.0238, g_loss: 6.4153, D(x): 1.00, D(G(z)): 0.02
# Epoch [2/300], Step [600/600], d_loss: 0.0589, g_loss: 8.0812, D(x): 0.98, D(G(z)): 0.00
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 0.8749, g_loss: 2.4766, D(x): 0.86, D(G(z)): 0.20
# Epoch [3/300], Step [400/600], d_loss: 0.2011, g_loss: 4.0121, D(x): 0.94, D(G(z)): 0.03
# Epoch [3/300], Step [600/600], d_loss: 0.0922, g_loss: 5.1988, D(x): 0.98, D(G(z)): 0.05
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.0322, g_loss: 5.8354, D(x): 0.99, D(G(z)): 0.01
# Epoch [4/300], Step [400/600], d_loss: 0.0614, g_loss: 5.0640, D(x): 0.99, D(G(z)): 0.02
# Epoch [4/300], Step [600/600], d_loss: 0.2347, g_loss: 4.3145, D(x): 0.94, D(G(z)): 0.06
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.0826, g_loss: 3.8281, D(x): 0.98, D(G(z)): 0.04
# Epoch [5/300], Step [400/600], d_loss: 0.0523, g_loss: 5.6443, D(x): 0.99, D(G(z)): 0.03
# Epoch [5/300], Step [600/600], d_loss: 0.1769, g_loss: 3.2934, D(x): 0.96, D(G(z)): 0.07
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.2209, g_loss: 6.5577, D(x): 0.93, D(G(z)): 0.01
# Epoch [6/300], Step [400/600], d_loss: 0.1635, g_loss: 4.4647, D(x): 0.96, D(G(z)): 0.07
# Epoch [6/300], Step [600/600], d_loss: 0.1640, g_loss: 3.2519, D(x): 0.97, D(G(z)): 0.11
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.3546, g_loss: 4.0968, D(x): 0.91, D(G(z)): 0.08
# Epoch [7/300], Step [400/600], d_loss: 0.4253, g_loss: 3.9093, D(x): 0.90, D(G(z)): 0.15
# Epoch [7/300], Step [600/600], d_loss: 0.0308, g_loss: 7.2244, D(x): 0.99, D(G(z)): 0.02
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.1433, g_loss: 5.6778, D(x): 0.93, D(G(z)): 0.01
# Epoch [8/300], Step [400/600], d_loss: 0.1849, g_loss: 7.6467, D(x): 0.94, D(G(z)): 0.04
# Epoch [8/300], Step [600/600], d_loss: 0.3026, g_loss: 5.7576, D(x): 0.90, D(G(z)): 0.02
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.1937, g_loss: 3.8601, D(x): 0.95, D(G(z)): 0.09
# Epoch [9/300], Step [400/600], d_loss: 0.3627, g_loss: 5.0517, D(x): 0.97, D(G(z)): 0.23
# Epoch [9/300], Step [600/600], d_loss: 0.1259, g_loss: 3.6957, D(x): 0.97, D(G(z)): 0.07
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.1280, g_loss: 5.3701, D(x): 0.97, D(G(z)): 0.02
# Epoch [10/300], Step [400/600], d_loss: 0.5505, g_loss: 3.6458, D(x): 0.87, D(G(z)): 0.15
# Epoch [10/300], Step [600/600], d_loss: 0.0571, g_loss: 4.2241, D(x): 0.98, D(G(z)): 0.04
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.1950, g_loss: 3.0078, D(x): 0.93, D(G(z)): 0.08
# Epoch [11/300], Step [400/600], d_loss: 0.4374, g_loss: 4.5769, D(x): 0.93, D(G(z)): 0.16
# Epoch [11/300], Step [600/600], d_loss: 0.1896, g_loss: 3.2318, D(x): 0.94, D(G(z)): 0.07
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.1880, g_loss: 3.5414, D(x): 0.93, D(G(z)): 0.04
# Epoch [12/300], Step [400/600], d_loss: 0.3837, g_loss: 3.0523, D(x): 0.92, D(G(z)): 0.15
# Epoch [12/300], Step [600/600], d_loss: 0.3184, g_loss: 4.2069, D(x): 0.91, D(G(z)): 0.08
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.1935, g_loss: 3.6821, D(x): 0.94, D(G(z)): 0.07
# Epoch [13/300], Step [400/600], d_loss: 0.3815, g_loss: 2.5025, D(x): 0.89, D(G(z)): 0.14
# Epoch [13/300], Step [600/600], d_loss: 0.3881, g_loss: 5.2028, D(x): 0.91, D(G(z)): 0.03
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.1922, g_loss: 3.7271, D(x): 0.94, D(G(z)): 0.05
# Epoch [14/300], Step [400/600], d_loss: 0.3007, g_loss: 3.9277, D(x): 0.86, D(G(z)): 0.04
# Epoch [14/300], Step [600/600], d_loss: 0.2634, g_loss: 3.2621, D(x): 0.91, D(G(z)): 0.09
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.2861, g_loss: 3.1747, D(x): 0.96, D(G(z)): 0.17
# Epoch [15/300], Step [400/600], d_loss: 0.3191, g_loss: 2.6422, D(x): 0.91, D(G(z)): 0.13
# Epoch [15/300], Step [600/600], d_loss: 0.4568, g_loss: 3.0576, D(x): 0.80, D(G(z)): 0.08
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.2361, g_loss: 2.8302, D(x): 0.91, D(G(z)): 0.07
# Epoch [16/300], Step [400/600], d_loss: 0.3445, g_loss: 2.9454, D(x): 0.90, D(G(z)): 0.11
# Epoch [16/300], Step [600/600], d_loss: 0.3126, g_loss: 4.7548, D(x): 0.89, D(G(z)): 0.07
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.3711, g_loss: 3.3318, D(x): 0.89, D(G(z)): 0.09
# Epoch [17/300], Step [400/600], d_loss: 0.4233, g_loss: 3.6827, D(x): 0.89, D(G(z)): 0.08
# Epoch [17/300], Step [600/600], d_loss: 0.2675, g_loss: 4.2111, D(x): 0.88, D(G(z)): 0.03
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.2812, g_loss: 3.1962, D(x): 0.94, D(G(z)): 0.13
# Epoch [18/300], Step [400/600], d_loss: 0.2759, g_loss: 4.0800, D(x): 0.92, D(G(z)): 0.07
# Epoch [18/300], Step [600/600], d_loss: 0.6379, g_loss: 3.9545, D(x): 0.82, D(G(z)): 0.08
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.5161, g_loss: 4.2963, D(x): 0.84, D(G(z)): 0.11
# Epoch [19/300], Step [400/600], d_loss: 1.0238, g_loss: 4.6850, D(x): 0.80, D(G(z)): 0.20
# Epoch [19/300], Step [600/600], d_loss: 0.5388, g_loss: 2.8640, D(x): 0.84, D(G(z)): 0.15
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.5356, g_loss: 3.7399, D(x): 0.89, D(G(z)): 0.18
# Epoch [20/300], Step [400/600], d_loss: 0.2974, g_loss: 3.4491, D(x): 0.92, D(G(z)): 0.12
# Epoch [20/300], Step [600/600], d_loss: 0.4044, g_loss: 2.5063, D(x): 0.90, D(G(z)): 0.18
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.6900, g_loss: 4.8177, D(x): 0.81, D(G(z)): 0.04
# Epoch [21/300], Step [400/600], d_loss: 0.7974, g_loss: 2.8870, D(x): 0.77, D(G(z)): 0.18
# Epoch [21/300], Step [600/600], d_loss: 0.5193, g_loss: 2.5135, D(x): 0.90, D(G(z)): 0.26
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.7318, g_loss: 2.4722, D(x): 0.79, D(G(z)): 0.22
# Epoch [22/300], Step [400/600], d_loss: 0.4794, g_loss: 3.6500, D(x): 0.84, D(G(z)): 0.09
# Epoch [22/300], Step [600/600], d_loss: 0.3443, g_loss: 3.4189, D(x): 0.89, D(G(z)): 0.11
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.6849, g_loss: 1.9916, D(x): 0.75, D(G(z)): 0.19
# Epoch [23/300], Step [400/600], d_loss: 0.6205, g_loss: 3.4217, D(x): 0.79, D(G(z)): 0.09
# Epoch [23/300], Step [600/600], d_loss: 0.3365, g_loss: 2.5813, D(x): 0.86, D(G(z)): 0.12
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.6215, g_loss: 2.3634, D(x): 0.80, D(G(z)): 0.20
# Epoch [24/300], Step [400/600], d_loss: 0.5801, g_loss: 2.5123, D(x): 0.84, D(G(z)): 0.20
# Epoch [24/300], Step [600/600], d_loss: 0.8187, g_loss: 2.6540, D(x): 0.74, D(G(z)): 0.17
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.4767, g_loss: 2.2767, D(x): 0.91, D(G(z)): 0.20
# Epoch [25/300], Step [400/600], d_loss: 0.3693, g_loss: 3.9227, D(x): 0.88, D(G(z)): 0.11
# Epoch [25/300], Step [600/600], d_loss: 0.3900, g_loss: 3.3711, D(x): 0.89, D(G(z)): 0.14
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.6592, g_loss: 3.0961, D(x): 0.82, D(G(z)): 0.19
# Epoch [26/300], Step [400/600], d_loss: 0.7568, g_loss: 2.1338, D(x): 0.75, D(G(z)): 0.20
# Epoch [26/300], Step [600/600], d_loss: 0.5378, g_loss: 2.8107, D(x): 0.86, D(G(z)): 0.20
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.4136, g_loss: 3.5483, D(x): 0.88, D(G(z)): 0.14
# Epoch [27/300], Step [400/600], d_loss: 0.6452, g_loss: 2.4385, D(x): 0.79, D(G(z)): 0.18
# Epoch [27/300], Step [600/600], d_loss: 0.3492, g_loss: 3.7094, D(x): 0.90, D(G(z)): 0.10
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.3597, g_loss: 2.7096, D(x): 0.87, D(G(z)): 0.11
# Epoch [28/300], Step [400/600], d_loss: 0.5103, g_loss: 2.5688, D(x): 0.84, D(G(z)): 0.18
# Epoch [28/300], Step [600/600], d_loss: 0.4063, g_loss: 2.9743, D(x): 0.82, D(G(z)): 0.11
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.6735, g_loss: 1.9763, D(x): 0.80, D(G(z)): 0.25
# Epoch [29/300], Step [400/600], d_loss: 0.2793, g_loss: 3.0157, D(x): 0.91, D(G(z)): 0.12
# Epoch [29/300], Step [600/600], d_loss: 0.4538, g_loss: 2.7055, D(x): 0.82, D(G(z)): 0.14
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.4414, g_loss: 3.4740, D(x): 0.84, D(G(z)): 0.11
# Epoch [30/300], Step [400/600], d_loss: 0.7207, g_loss: 3.2432, D(x): 0.79, D(G(z)): 0.22
# Epoch [30/300], Step [600/600], d_loss: 0.4663, g_loss: 2.4653, D(x): 0.87, D(G(z)): 0.16
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.6119, g_loss: 2.1598, D(x): 0.75, D(G(z)): 0.16
# Epoch [31/300], Step [400/600], d_loss: 0.8686, g_loss: 2.0011, D(x): 0.76, D(G(z)): 0.31
# Epoch [31/300], Step [600/600], d_loss: 1.0185, g_loss: 2.6793, D(x): 0.67, D(G(z)): 0.22
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.5667, g_loss: 1.9976, D(x): 0.77, D(G(z)): 0.15
# Epoch [32/300], Step [400/600], d_loss: 0.4558, g_loss: 2.4963, D(x): 0.84, D(G(z)): 0.11
# Epoch [32/300], Step [600/600], d_loss: 0.6953, g_loss: 5.2704, D(x): 0.82, D(G(z)): 0.07
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.4594, g_loss: 3.5593, D(x): 0.88, D(G(z)): 0.15
# Epoch [33/300], Step [400/600], d_loss: 0.3280, g_loss: 3.3093, D(x): 0.87, D(G(z)): 0.11
# Epoch [33/300], Step [600/600], d_loss: 0.6392, g_loss: 2.1064, D(x): 0.86, D(G(z)): 0.27
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.6850, g_loss: 1.8657, D(x): 0.77, D(G(z)): 0.23
# Epoch [34/300], Step [400/600], d_loss: 0.5331, g_loss: 2.7983, D(x): 0.80, D(G(z)): 0.17
# Epoch [34/300], Step [600/600], d_loss: 0.5733, g_loss: 2.6755, D(x): 0.82, D(G(z)): 0.19
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.5162, g_loss: 1.9732, D(x): 0.80, D(G(z)): 0.19
# Epoch [35/300], Step [400/600], d_loss: 0.6461, g_loss: 2.2344, D(x): 0.84, D(G(z)): 0.26
# Epoch [35/300], Step [600/600], d_loss: 0.5366, g_loss: 2.5429, D(x): 0.82, D(G(z)): 0.14
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.5543, g_loss: 2.4101, D(x): 0.80, D(G(z)): 0.16
# Epoch [36/300], Step [400/600], d_loss: 0.6595, g_loss: 1.9550, D(x): 0.75, D(G(z)): 0.17
# Epoch [36/300], Step [600/600], d_loss: 0.4735, g_loss: 2.2203, D(x): 0.85, D(G(z)): 0.18
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.6731, g_loss: 2.4495, D(x): 0.78, D(G(z)): 0.16
# Epoch [37/300], Step [400/600], d_loss: 0.6785, g_loss: 2.3047, D(x): 0.75, D(G(z)): 0.19
# Epoch [37/300], Step [600/600], d_loss: 0.5334, g_loss: 2.9709, D(x): 0.81, D(G(z)): 0.17
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.6527, g_loss: 2.4894, D(x): 0.80, D(G(z)): 0.17
# Epoch [38/300], Step [400/600], d_loss: 0.7240, g_loss: 2.0064, D(x): 0.83, D(G(z)): 0.28
# Epoch [38/300], Step [600/600], d_loss: 0.6958, g_loss: 2.2674, D(x): 0.80, D(G(z)): 0.25
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.7918, g_loss: 1.9316, D(x): 0.85, D(G(z)): 0.32
# Epoch [39/300], Step [400/600], d_loss: 0.6082, g_loss: 2.2800, D(x): 0.88, D(G(z)): 0.28
# Epoch [39/300], Step [600/600], d_loss: 0.7875, g_loss: 1.5539, D(x): 0.83, D(G(z)): 0.29
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.7511, g_loss: 2.1665, D(x): 0.92, D(G(z)): 0.34
# Epoch [40/300], Step [400/600], d_loss: 0.5225, g_loss: 2.8138, D(x): 0.77, D(G(z)): 0.13
# Epoch [40/300], Step [600/600], d_loss: 0.6429, g_loss: 2.2539, D(x): 0.83, D(G(z)): 0.22
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.6477, g_loss: 1.9921, D(x): 0.75, D(G(z)): 0.22
# Epoch [41/300], Step [400/600], d_loss: 0.7725, g_loss: 2.3968, D(x): 0.73, D(G(z)): 0.20
# Epoch [41/300], Step [600/600], d_loss: 0.5660, g_loss: 2.3965, D(x): 0.79, D(G(z)): 0.18
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.6156, g_loss: 1.8228, D(x): 0.79, D(G(z)): 0.21
# Epoch [42/300], Step [400/600], d_loss: 0.6810, g_loss: 3.5326, D(x): 0.83, D(G(z)): 0.20
# Epoch [42/300], Step [600/600], d_loss: 0.5986, g_loss: 2.2388, D(x): 0.84, D(G(z)): 0.22
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.6933, g_loss: 1.8615, D(x): 0.80, D(G(z)): 0.29
# Epoch [43/300], Step [400/600], d_loss: 0.6932, g_loss: 2.5135, D(x): 0.73, D(G(z)): 0.15
# Epoch [43/300], Step [600/600], d_loss: 0.6187, g_loss: 2.5836, D(x): 0.78, D(G(z)): 0.18
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.6510, g_loss: 2.0303, D(x): 0.85, D(G(z)): 0.24
# Epoch [44/300], Step [400/600], d_loss: 0.7348, g_loss: 2.7283, D(x): 0.79, D(G(z)): 0.25
# Epoch [44/300], Step [600/600], d_loss: 0.8830, g_loss: 2.6787, D(x): 0.69, D(G(z)): 0.23
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.6466, g_loss: 1.9039, D(x): 0.82, D(G(z)): 0.25
# Epoch [45/300], Step [400/600], d_loss: 0.6588, g_loss: 2.1843, D(x): 0.75, D(G(z)): 0.18
# Epoch [45/300], Step [600/600], d_loss: 0.9460, g_loss: 2.0596, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.6415, g_loss: 1.7901, D(x): 0.82, D(G(z)): 0.25
# Epoch [46/300], Step [400/600], d_loss: 0.8532, g_loss: 2.0403, D(x): 0.69, D(G(z)): 0.24
# Epoch [46/300], Step [600/600], d_loss: 0.9914, g_loss: 1.7179, D(x): 0.70, D(G(z)): 0.25
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.6834, g_loss: 2.7313, D(x): 0.77, D(G(z)): 0.18
# Epoch [47/300], Step [400/600], d_loss: 0.6343, g_loss: 2.6054, D(x): 0.80, D(G(z)): 0.20
# Epoch [47/300], Step [600/600], d_loss: 0.3848, g_loss: 2.3118, D(x): 0.86, D(G(z)): 0.14
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.6178, g_loss: 2.8374, D(x): 0.82, D(G(z)): 0.19
# Epoch [48/300], Step [400/600], d_loss: 0.7551, g_loss: 2.7314, D(x): 0.82, D(G(z)): 0.31
# Epoch [48/300], Step [600/600], d_loss: 0.5629, g_loss: 2.2202, D(x): 0.78, D(G(z)): 0.16
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.8932, g_loss: 2.1605, D(x): 0.81, D(G(z)): 0.37
# Epoch [49/300], Step [400/600], d_loss: 0.7147, g_loss: 2.1019, D(x): 0.74, D(G(z)): 0.20
# Epoch [49/300], Step [600/600], d_loss: 0.4301, g_loss: 2.9598, D(x): 0.83, D(G(z)): 0.14
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.7095, g_loss: 1.9047, D(x): 0.78, D(G(z)): 0.25
# Epoch [50/300], Step [400/600], d_loss: 0.5796, g_loss: 2.0455, D(x): 0.85, D(G(z)): 0.26
# Epoch [50/300], Step [600/600], d_loss: 0.8341, g_loss: 2.1043, D(x): 0.72, D(G(z)): 0.23
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.6416, g_loss: 2.4142, D(x): 0.85, D(G(z)): 0.25
# Epoch [51/300], Step [400/600], d_loss: 0.8878, g_loss: 2.3820, D(x): 0.75, D(G(z)): 0.27
# Epoch [51/300], Step [600/600], d_loss: 0.8804, g_loss: 2.3298, D(x): 0.81, D(G(z)): 0.34
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.7313, g_loss: 1.7917, D(x): 0.83, D(G(z)): 0.31
# Epoch [52/300], Step [400/600], d_loss: 0.6728, g_loss: 2.3524, D(x): 0.78, D(G(z)): 0.21
# Epoch [52/300], Step [600/600], d_loss: 0.5226, g_loss: 2.6073, D(x): 0.79, D(G(z)): 0.12
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.6048, g_loss: 2.2128, D(x): 0.79, D(G(z)): 0.18
# Epoch [53/300], Step [400/600], d_loss: 0.6108, g_loss: 2.3840, D(x): 0.80, D(G(z)): 0.19
# Epoch [53/300], Step [600/600], d_loss: 0.5460, g_loss: 1.9457, D(x): 0.81, D(G(z)): 0.18
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.5637, g_loss: 2.1813, D(x): 0.85, D(G(z)): 0.23
# Epoch [54/300], Step [400/600], d_loss: 0.8330, g_loss: 2.1525, D(x): 0.73, D(G(z)): 0.26
# Epoch [54/300], Step [600/600], d_loss: 0.8111, g_loss: 1.8904, D(x): 0.74, D(G(z)): 0.24
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.8469, g_loss: 1.4345, D(x): 0.73, D(G(z)): 0.31
# Epoch [55/300], Step [400/600], d_loss: 0.6723, g_loss: 1.8346, D(x): 0.77, D(G(z)): 0.25
# Epoch [55/300], Step [600/600], d_loss: 0.6058, g_loss: 2.7105, D(x): 0.92, D(G(z)): 0.28
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.7853, g_loss: 2.3279, D(x): 0.82, D(G(z)): 0.26
# Epoch [56/300], Step [400/600], d_loss: 0.8481, g_loss: 2.4580, D(x): 0.71, D(G(z)): 0.15
# Epoch [56/300], Step [600/600], d_loss: 0.6526, g_loss: 2.1716, D(x): 0.81, D(G(z)): 0.26
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.8951, g_loss: 1.9617, D(x): 0.80, D(G(z)): 0.32
# Epoch [57/300], Step [400/600], d_loss: 0.7089, g_loss: 2.2670, D(x): 0.81, D(G(z)): 0.27
# Epoch [57/300], Step [600/600], d_loss: 0.9915, g_loss: 2.2057, D(x): 0.70, D(G(z)): 0.28
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.8509, g_loss: 1.8256, D(x): 0.73, D(G(z)): 0.25
# Epoch [58/300], Step [400/600], d_loss: 0.6713, g_loss: 2.3883, D(x): 0.77, D(G(z)): 0.20
# Epoch [58/300], Step [600/600], d_loss: 1.0060, g_loss: 2.6125, D(x): 0.65, D(G(z)): 0.17
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 0.8505, g_loss: 1.4511, D(x): 0.76, D(G(z)): 0.28
# Epoch [59/300], Step [400/600], d_loss: 0.5383, g_loss: 2.1256, D(x): 0.84, D(G(z)): 0.22
# Epoch [59/300], Step [600/600], d_loss: 0.5834, g_loss: 2.2829, D(x): 0.83, D(G(z)): 0.20
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.7785, g_loss: 1.7222, D(x): 0.85, D(G(z)): 0.34
# Epoch [60/300], Step [400/600], d_loss: 0.7048, g_loss: 2.5816, D(x): 0.77, D(G(z)): 0.20
# Epoch [60/300], Step [600/600], d_loss: 0.7254, g_loss: 1.5305, D(x): 0.79, D(G(z)): 0.28
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.9103, g_loss: 1.7106, D(x): 0.67, D(G(z)): 0.23
# Epoch [61/300], Step [400/600], d_loss: 0.8645, g_loss: 2.0874, D(x): 0.72, D(G(z)): 0.23
# Epoch [61/300], Step [600/600], d_loss: 0.5537, g_loss: 2.2744, D(x): 0.77, D(G(z)): 0.15
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.9799, g_loss: 1.6722, D(x): 0.76, D(G(z)): 0.36
# Epoch [62/300], Step [400/600], d_loss: 0.8952, g_loss: 2.6638, D(x): 0.71, D(G(z)): 0.25
# Epoch [62/300], Step [600/600], d_loss: 0.8353, g_loss: 1.3560, D(x): 0.77, D(G(z)): 0.35
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.8654, g_loss: 1.5925, D(x): 0.73, D(G(z)): 0.26
# Epoch [63/300], Step [400/600], d_loss: 0.7560, g_loss: 1.7521, D(x): 0.76, D(G(z)): 0.26
# Epoch [63/300], Step [600/600], d_loss: 0.7935, g_loss: 1.5833, D(x): 0.78, D(G(z)): 0.31
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.8930, g_loss: 1.6561, D(x): 0.74, D(G(z)): 0.29
# Epoch [64/300], Step [400/600], d_loss: 0.6546, g_loss: 2.2044, D(x): 0.76, D(G(z)): 0.20
# Epoch [64/300], Step [600/600], d_loss: 0.9333, g_loss: 1.4837, D(x): 0.69, D(G(z)): 0.28
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 0.8203, g_loss: 1.9438, D(x): 0.73, D(G(z)): 0.22
# Epoch [65/300], Step [400/600], d_loss: 0.8764, g_loss: 1.7783, D(x): 0.68, D(G(z)): 0.26
# Epoch [65/300], Step [600/600], d_loss: 0.7529, g_loss: 2.3511, D(x): 0.71, D(G(z)): 0.19
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.7621, g_loss: 1.9668, D(x): 0.69, D(G(z)): 0.17
# Epoch [66/300], Step [400/600], d_loss: 0.7216, g_loss: 2.2395, D(x): 0.82, D(G(z)): 0.27
# Epoch [66/300], Step [600/600], d_loss: 0.8943, g_loss: 1.9133, D(x): 0.66, D(G(z)): 0.22
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.7060, g_loss: 2.1700, D(x): 0.78, D(G(z)): 0.20
# Epoch [67/300], Step [400/600], d_loss: 0.8995, g_loss: 1.8175, D(x): 0.73, D(G(z)): 0.30
# Epoch [67/300], Step [600/600], d_loss: 0.8160, g_loss: 1.7845, D(x): 0.71, D(G(z)): 0.26
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.8116, g_loss: 1.9188, D(x): 0.68, D(G(z)): 0.18
# Epoch [68/300], Step [400/600], d_loss: 0.8795, g_loss: 1.9078, D(x): 0.79, D(G(z)): 0.33
# Epoch [68/300], Step [600/600], d_loss: 1.1197, g_loss: 1.6654, D(x): 0.63, D(G(z)): 0.27
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 0.6948, g_loss: 2.2780, D(x): 0.70, D(G(z)): 0.15
# Epoch [69/300], Step [400/600], d_loss: 0.8343, g_loss: 1.9786, D(x): 0.70, D(G(z)): 0.22
# Epoch [69/300], Step [600/600], d_loss: 0.9134, g_loss: 2.0324, D(x): 0.74, D(G(z)): 0.29
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 0.6055, g_loss: 2.3594, D(x): 0.81, D(G(z)): 0.23
# Epoch [70/300], Step [400/600], d_loss: 0.6417, g_loss: 2.1175, D(x): 0.79, D(G(z)): 0.23
# Epoch [70/300], Step [600/600], d_loss: 0.7383, g_loss: 1.6495, D(x): 0.77, D(G(z)): 0.26
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.8852, g_loss: 1.2951, D(x): 0.73, D(G(z)): 0.33
# Epoch [71/300], Step [400/600], d_loss: 0.6910, g_loss: 1.6846, D(x): 0.79, D(G(z)): 0.26
# Epoch [71/300], Step [600/600], d_loss: 0.7645, g_loss: 1.6638, D(x): 0.74, D(G(z)): 0.26
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.9895, g_loss: 1.3685, D(x): 0.69, D(G(z)): 0.33
# Epoch [72/300], Step [400/600], d_loss: 0.7515, g_loss: 1.8798, D(x): 0.80, D(G(z)): 0.30
# Epoch [72/300], Step [600/600], d_loss: 0.8238, g_loss: 1.3900, D(x): 0.70, D(G(z)): 0.24
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.9298, g_loss: 1.6509, D(x): 0.69, D(G(z)): 0.27
# Epoch [73/300], Step [400/600], d_loss: 0.6964, g_loss: 2.3928, D(x): 0.77, D(G(z)): 0.20
# Epoch [73/300], Step [600/600], d_loss: 0.8372, g_loss: 1.6517, D(x): 0.75, D(G(z)): 0.31
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.8908, g_loss: 1.8127, D(x): 0.65, D(G(z)): 0.18
# Epoch [74/300], Step [400/600], d_loss: 0.7720, g_loss: 1.6092, D(x): 0.76, D(G(z)): 0.27
# Epoch [74/300], Step [600/600], d_loss: 0.9451, g_loss: 1.6475, D(x): 0.66, D(G(z)): 0.25
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 1.0277, g_loss: 1.5152, D(x): 0.73, D(G(z)): 0.34
# Epoch [75/300], Step [400/600], d_loss: 0.7614, g_loss: 1.5335, D(x): 0.76, D(G(z)): 0.25
# Epoch [75/300], Step [600/600], d_loss: 0.9210, g_loss: 1.7156, D(x): 0.68, D(G(z)): 0.29
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.8562, g_loss: 1.8016, D(x): 0.72, D(G(z)): 0.29
# Epoch [76/300], Step [400/600], d_loss: 0.8315, g_loss: 1.5887, D(x): 0.76, D(G(z)): 0.31
# Epoch [76/300], Step [600/600], d_loss: 0.7276, g_loss: 1.8144, D(x): 0.73, D(G(z)): 0.23
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.7828, g_loss: 1.5940, D(x): 0.73, D(G(z)): 0.24
# Epoch [77/300], Step [400/600], d_loss: 0.8764, g_loss: 1.9366, D(x): 0.69, D(G(z)): 0.26
# Epoch [77/300], Step [600/600], d_loss: 0.8762, g_loss: 2.0919, D(x): 0.69, D(G(z)): 0.25
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.7998, g_loss: 1.5816, D(x): 0.75, D(G(z)): 0.31
# Epoch [78/300], Step [400/600], d_loss: 0.9898, g_loss: 1.4062, D(x): 0.73, D(G(z)): 0.38
# Epoch [78/300], Step [600/600], d_loss: 0.7927, g_loss: 1.4724, D(x): 0.77, D(G(z)): 0.32
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 1.0126, g_loss: 1.7158, D(x): 0.74, D(G(z)): 0.39
# Epoch [79/300], Step [400/600], d_loss: 0.9745, g_loss: 1.3371, D(x): 0.72, D(G(z)): 0.37
# Epoch [79/300], Step [600/600], d_loss: 0.9502, g_loss: 1.2814, D(x): 0.67, D(G(z)): 0.29
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 1.0753, g_loss: 1.2061, D(x): 0.70, D(G(z)): 0.37
# Epoch [80/300], Step [400/600], d_loss: 0.8547, g_loss: 1.6398, D(x): 0.76, D(G(z)): 0.32
# Epoch [80/300], Step [600/600], d_loss: 0.8161, g_loss: 1.6240, D(x): 0.73, D(G(z)): 0.29
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 1.1453, g_loss: 1.6130, D(x): 0.62, D(G(z)): 0.30
# Epoch [81/300], Step [400/600], d_loss: 0.9344, g_loss: 1.9055, D(x): 0.64, D(G(z)): 0.23
# Epoch [81/300], Step [600/600], d_loss: 0.9458, g_loss: 1.4499, D(x): 0.74, D(G(z)): 0.34
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 0.7757, g_loss: 2.2995, D(x): 0.73, D(G(z)): 0.21
# Epoch [82/300], Step [400/600], d_loss: 1.0456, g_loss: 1.4557, D(x): 0.69, D(G(z)): 0.36
# Epoch [82/300], Step [600/600], d_loss: 0.8109, g_loss: 1.6574, D(x): 0.76, D(G(z)): 0.29
# Saving fake_images-0083.png
# Epoch [83/300], Step [200/600], d_loss: 0.9204, g_loss: 1.6371, D(x): 0.69, D(G(z)): 0.23
# Epoch [83/300], Step [400/600], d_loss: 0.8569, g_loss: 1.8318, D(x): 0.71, D(G(z)): 0.27
# Epoch [83/300], Step [600/600], d_loss: 0.6479, g_loss: 2.0936, D(x): 0.78, D(G(z)): 0.23
# Saving fake_images-0084.png
# Epoch [84/300], Step [200/600], d_loss: 0.8618, g_loss: 1.4172, D(x): 0.75, D(G(z)): 0.33
# Epoch [84/300], Step [400/600], d_loss: 0.9333, g_loss: 1.4712, D(x): 0.70, D(G(z)): 0.28
# Epoch [84/300], Step [600/600], d_loss: 0.8347, g_loss: 1.6189, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0085.png
# Epoch [85/300], Step [200/600], d_loss: 0.8153, g_loss: 1.5305, D(x): 0.70, D(G(z)): 0.26
# Epoch [85/300], Step [400/600], d_loss: 0.9340, g_loss: 1.7098, D(x): 0.72, D(G(z)): 0.31
# Epoch [85/300], Step [600/600], d_loss: 0.8109, g_loss: 1.6130, D(x): 0.72, D(G(z)): 0.26
# Saving fake_images-0086.png
# Epoch [86/300], Step [200/600], d_loss: 0.8719, g_loss: 1.6821, D(x): 0.70, D(G(z)): 0.28
# Epoch [86/300], Step [400/600], d_loss: 0.9586, g_loss: 1.6142, D(x): 0.68, D(G(z)): 0.32
# Epoch [86/300], Step [600/600], d_loss: 0.9047, g_loss: 1.8434, D(x): 0.71, D(G(z)): 0.27
# Saving fake_images-0087.png
# Epoch [87/300], Step [200/600], d_loss: 0.7949, g_loss: 1.6558, D(x): 0.72, D(G(z)): 0.25
# Epoch [87/300], Step [400/600], d_loss: 0.9338, g_loss: 1.5436, D(x): 0.66, D(G(z)): 0.29
# Epoch [87/300], Step [600/600], d_loss: 0.6861, g_loss: 1.8959, D(x): 0.74, D(G(z)): 0.20
# Saving fake_images-0088.png
# Epoch [88/300], Step [200/600], d_loss: 0.8819, g_loss: 1.7646, D(x): 0.69, D(G(z)): 0.26
# Epoch [88/300], Step [400/600], d_loss: 0.9997, g_loss: 1.7795, D(x): 0.75, D(G(z)): 0.35
# Epoch [88/300], Step [600/600], d_loss: 0.9151, g_loss: 1.3491, D(x): 0.73, D(G(z)): 0.34
# Saving fake_images-0089.png
# Epoch [89/300], Step [200/600], d_loss: 0.9138, g_loss: 1.3534, D(x): 0.76, D(G(z)): 0.37
# Epoch [89/300], Step [400/600], d_loss: 0.7590, g_loss: 1.7849, D(x): 0.69, D(G(z)): 0.23
# Epoch [89/300], Step [600/600], d_loss: 0.9257, g_loss: 1.1672, D(x): 0.73, D(G(z)): 0.35
# Saving fake_images-0090.png
# Epoch [90/300], Step [200/600], d_loss: 0.8361, g_loss: 1.5480, D(x): 0.71, D(G(z)): 0.30
# Epoch [90/300], Step [400/600], d_loss: 0.8327, g_loss: 1.6980, D(x): 0.72, D(G(z)): 0.26
# Epoch [90/300], Step [600/600], d_loss: 0.7990, g_loss: 1.6509, D(x): 0.71, D(G(z)): 0.26
# Saving fake_images-0091.png
# Epoch [91/300], Step [200/600], d_loss: 0.8549, g_loss: 1.3399, D(x): 0.77, D(G(z)): 0.35
# Epoch [91/300], Step [400/600], d_loss: 0.9403, g_loss: 1.4290, D(x): 0.67, D(G(z)): 0.29
# Epoch [91/300], Step [600/600], d_loss: 0.8188, g_loss: 1.2696, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0092.png
# Epoch [92/300], Step [200/600], d_loss: 0.7405, g_loss: 2.0411, D(x): 0.72, D(G(z)): 0.22
# Epoch [92/300], Step [400/600], d_loss: 0.9603, g_loss: 1.4926, D(x): 0.74, D(G(z)): 0.36
# Epoch [92/300], Step [600/600], d_loss: 0.7356, g_loss: 1.3908, D(x): 0.78, D(G(z)): 0.32
# Saving fake_images-0093.png
# Epoch [93/300], Step [200/600], d_loss: 0.9450, g_loss: 1.7809, D(x): 0.67, D(G(z)): 0.25
# Epoch [93/300], Step [400/600], d_loss: 1.2407, g_loss: 1.4003, D(x): 0.61, D(G(z)): 0.37
# Epoch [93/300], Step [600/600], d_loss: 1.0143, g_loss: 1.5744, D(x): 0.67, D(G(z)): 0.31
# Saving fake_images-0094.png
# Epoch [94/300], Step [200/600], d_loss: 0.9867, g_loss: 1.2617, D(x): 0.76, D(G(z)): 0.39
# Epoch [94/300], Step [400/600], d_loss: 0.8709, g_loss: 1.4911, D(x): 0.70, D(G(z)): 0.29
# Epoch [94/300], Step [600/600], d_loss: 0.8594, g_loss: 1.4054, D(x): 0.73, D(G(z)): 0.32
# Saving fake_images-0095.png
# Epoch [95/300], Step [200/600], d_loss: 1.2849, g_loss: 1.4546, D(x): 0.54, D(G(z)): 0.33
# Epoch [95/300], Step [400/600], d_loss: 0.9091, g_loss: 1.9151, D(x): 0.67, D(G(z)): 0.25
# Epoch [95/300], Step [600/600], d_loss: 1.0556, g_loss: 1.3915, D(x): 0.66, D(G(z)): 0.35
# Saving fake_images-0096.png
# Epoch [96/300], Step [200/600], d_loss: 0.9358, g_loss: 1.4976, D(x): 0.70, D(G(z)): 0.33
# Epoch [96/300], Step [400/600], d_loss: 0.9320, g_loss: 1.4005, D(x): 0.69, D(G(z)): 0.34
# Epoch [96/300], Step [600/600], d_loss: 0.9317, g_loss: 1.4976, D(x): 0.67, D(G(z)): 0.30
# Saving fake_images-0097.png
# Epoch [97/300], Step [200/600], d_loss: 0.7606, g_loss: 1.6528, D(x): 0.78, D(G(z)): 0.28
# Epoch [97/300], Step [400/600], d_loss: 0.9700, g_loss: 1.5374, D(x): 0.70, D(G(z)): 0.32
# Epoch [97/300], Step [600/600], d_loss: 1.0052, g_loss: 1.3294, D(x): 0.67, D(G(z)): 0.34
# Saving fake_images-0098.png
# Epoch [98/300], Step [200/600], d_loss: 0.8042, g_loss: 1.3390, D(x): 0.75, D(G(z)): 0.29
# Epoch [98/300], Step [400/600], d_loss: 0.9385, g_loss: 1.4320, D(x): 0.65, D(G(z)): 0.28
# Epoch [98/300], Step [600/600], d_loss: 0.8957, g_loss: 1.5849, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0099.png
# Epoch [99/300], Step [200/600], d_loss: 1.0139, g_loss: 1.3028, D(x): 0.70, D(G(z)): 0.39
# Epoch [99/300], Step [400/600], d_loss: 0.9075, g_loss: 1.4849, D(x): 0.72, D(G(z)): 0.34
# Epoch [99/300], Step [600/600], d_loss: 0.9781, g_loss: 1.4584, D(x): 0.71, D(G(z)): 0.35
# Saving fake_images-0100.png
# Epoch [100/300], Step [200/600], d_loss: 0.9808, g_loss: 1.6222, D(x): 0.67, D(G(z)): 0.30
# Epoch [100/300], Step [400/600], d_loss: 0.9983, g_loss: 1.5669, D(x): 0.64, D(G(z)): 0.31
# Epoch [100/300], Step [600/600], d_loss: 0.8787, g_loss: 1.4771, D(x): 0.72, D(G(z)): 0.30
# Saving fake_images-0101.png
# Epoch [101/300], Step [200/600], d_loss: 0.9596, g_loss: 1.3971, D(x): 0.67, D(G(z)): 0.31
# Epoch [101/300], Step [400/600], d_loss: 0.9854, g_loss: 1.4428, D(x): 0.66, D(G(z)): 0.31
# Epoch [101/300], Step [600/600], d_loss: 1.0704, g_loss: 1.5873, D(x): 0.63, D(G(z)): 0.32
# Saving fake_images-0102.png
# Epoch [102/300], Step [200/600], d_loss: 0.9834, g_loss: 1.5522, D(x): 0.68, D(G(z)): 0.33
# Epoch [102/300], Step [400/600], d_loss: 0.9704, g_loss: 1.2193, D(x): 0.65, D(G(z)): 0.32
# Epoch [102/300], Step [600/600], d_loss: 1.0621, g_loss: 1.4653, D(x): 0.63, D(G(z)): 0.33
# Saving fake_images-0103.png
# Epoch [103/300], Step [200/600], d_loss: 1.0289, g_loss: 1.3853, D(x): 0.68, D(G(z)): 0.34
# Epoch [103/300], Step [400/600], d_loss: 0.8492, g_loss: 1.5421, D(x): 0.72, D(G(z)): 0.31
# Epoch [103/300], Step [600/600], d_loss: 0.9095, g_loss: 1.3999, D(x): 0.66, D(G(z)): 0.30
# Saving fake_images-0104.png
# Epoch [104/300], Step [200/600], d_loss: 0.9855, g_loss: 1.3721, D(x): 0.71, D(G(z)): 0.33
# Epoch [104/300], Step [400/600], d_loss: 0.9688, g_loss: 1.4879, D(x): 0.68, D(G(z)): 0.30
# Epoch [104/300], Step [600/600], d_loss: 0.8801, g_loss: 1.6570, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0105.png
# Epoch [105/300], Step [200/600], d_loss: 0.9024, g_loss: 1.3697, D(x): 0.66, D(G(z)): 0.26
# Epoch [105/300], Step [400/600], d_loss: 1.0440, g_loss: 1.3022, D(x): 0.69, D(G(z)): 0.34
# Epoch [105/300], Step [600/600], d_loss: 1.1893, g_loss: 1.2919, D(x): 0.70, D(G(z)): 0.43
# Saving fake_images-0106.png
# Epoch [106/300], Step [200/600], d_loss: 1.0520, g_loss: 1.3119, D(x): 0.62, D(G(z)): 0.30
# Epoch [106/300], Step [400/600], d_loss: 0.9381, g_loss: 1.4013, D(x): 0.70, D(G(z)): 0.31
# Epoch [106/300], Step [600/600], d_loss: 1.1919, g_loss: 1.4723, D(x): 0.67, D(G(z)): 0.40
# Saving fake_images-0107.png
# Epoch [107/300], Step [200/600], d_loss: 1.0366, g_loss: 1.2070, D(x): 0.72, D(G(z)): 0.38
# Epoch [107/300], Step [400/600], d_loss: 0.8958, g_loss: 1.4256, D(x): 0.70, D(G(z)): 0.31
# Epoch [107/300], Step [600/600], d_loss: 1.0068, g_loss: 1.3715, D(x): 0.64, D(G(z)): 0.32
# Saving fake_images-0108.png
# Epoch [108/300], Step [200/600], d_loss: 1.1289, g_loss: 1.2587, D(x): 0.62, D(G(z)): 0.34
# Epoch [108/300], Step [400/600], d_loss: 0.9311, g_loss: 1.4912, D(x): 0.67, D(G(z)): 0.30
# Epoch [108/300], Step [600/600], d_loss: 0.9318, g_loss: 1.4701, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0109.png
# Epoch [109/300], Step [200/600], d_loss: 0.9165, g_loss: 1.2538, D(x): 0.71, D(G(z)): 0.33
# Epoch [109/300], Step [400/600], d_loss: 1.0602, g_loss: 1.3178, D(x): 0.67, D(G(z)): 0.34
# Epoch [109/300], Step [600/600], d_loss: 0.9497, g_loss: 1.3346, D(x): 0.67, D(G(z)): 0.30
# Saving fake_images-0110.png
# Epoch [110/300], Step [200/600], d_loss: 1.1043, g_loss: 1.2728, D(x): 0.60, D(G(z)): 0.31
# Epoch [110/300], Step [400/600], d_loss: 0.8671, g_loss: 1.4207, D(x): 0.83, D(G(z)): 0.39
# Epoch [110/300], Step [600/600], d_loss: 0.8477, g_loss: 1.1745, D(x): 0.76, D(G(z)): 0.37
# Saving fake_images-0111.png
# Epoch [111/300], Step [200/600], d_loss: 1.1183, g_loss: 1.3711, D(x): 0.70, D(G(z)): 0.39
# Epoch [111/300], Step [400/600], d_loss: 0.7503, g_loss: 1.5391, D(x): 0.72, D(G(z)): 0.27
# Epoch [111/300], Step [600/600], d_loss: 1.2487, g_loss: 1.5534, D(x): 0.55, D(G(z)): 0.31
# Saving fake_images-0112.png
# Epoch [112/300], Step [200/600], d_loss: 1.0028, g_loss: 1.4339, D(x): 0.66, D(G(z)): 0.32
# Epoch [112/300], Step [400/600], d_loss: 0.7839, g_loss: 1.6013, D(x): 0.69, D(G(z)): 0.22
# Epoch [112/300], Step [600/600], d_loss: 1.2269, g_loss: 1.4133, D(x): 0.60, D(G(z)): 0.35
# Saving fake_images-0113.png
# Epoch [113/300], Step [200/600], d_loss: 0.9574, g_loss: 1.2038, D(x): 0.68, D(G(z)): 0.32
# Epoch [113/300], Step [400/600], d_loss: 1.1221, g_loss: 1.1723, D(x): 0.61, D(G(z)): 0.34
# Epoch [113/300], Step [600/600], d_loss: 1.5579, g_loss: 1.3582, D(x): 0.45, D(G(z)): 0.34
# Saving fake_images-0114.png
# Epoch [114/300], Step [200/600], d_loss: 1.0857, g_loss: 1.5195, D(x): 0.62, D(G(z)): 0.32
# Epoch [114/300], Step [400/600], d_loss: 1.2326, g_loss: 1.1064, D(x): 0.60, D(G(z)): 0.38
# Epoch [114/300], Step [600/600], d_loss: 0.7522, g_loss: 1.5560, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0115.png
# Epoch [115/300], Step [200/600], d_loss: 0.9331, g_loss: 1.4347, D(x): 0.73, D(G(z)): 0.34
# Epoch [115/300], Step [400/600], d_loss: 1.2194, g_loss: 1.3014, D(x): 0.67, D(G(z)): 0.43
# Epoch [115/300], Step [600/600], d_loss: 0.8813, g_loss: 1.3611, D(x): 0.72, D(G(z)): 0.35
# Saving fake_images-0116.png
# Epoch [116/300], Step [200/600], d_loss: 0.7109, g_loss: 1.7896, D(x): 0.72, D(G(z)): 0.23
# Epoch [116/300], Step [400/600], d_loss: 0.8823, g_loss: 1.7683, D(x): 0.66, D(G(z)): 0.24
# Epoch [116/300], Step [600/600], d_loss: 1.1982, g_loss: 1.1306, D(x): 0.62, D(G(z)): 0.37
# Saving fake_images-0117.png
# Epoch [117/300], Step [200/600], d_loss: 1.2318, g_loss: 1.2001, D(x): 0.60, D(G(z)): 0.37
# Epoch [117/300], Step [400/600], d_loss: 1.3532, g_loss: 0.9728, D(x): 0.63, D(G(z)): 0.46
# Epoch [117/300], Step [600/600], d_loss: 1.0218, g_loss: 1.0914, D(x): 0.69, D(G(z)): 0.40
# Saving fake_images-0118.png
# Epoch [118/300], Step [200/600], d_loss: 0.8915, g_loss: 1.2681, D(x): 0.74, D(G(z)): 0.37
# Epoch [118/300], Step [400/600], d_loss: 1.0299, g_loss: 0.8917, D(x): 0.63, D(G(z)): 0.35
# Epoch [118/300], Step [600/600], d_loss: 0.7628, g_loss: 1.7064, D(x): 0.74, D(G(z)): 0.25
# Saving fake_images-0119.png
# Epoch [119/300], Step [200/600], d_loss: 0.9434, g_loss: 1.5371, D(x): 0.70, D(G(z)): 0.32
# Epoch [119/300], Step [400/600], d_loss: 1.5107, g_loss: 1.2322, D(x): 0.57, D(G(z)): 0.44
# Epoch [119/300], Step [600/600], d_loss: 0.9280, g_loss: 1.0667, D(x): 0.72, D(G(z)): 0.36
# Saving fake_images-0120.png
# Epoch [120/300], Step [200/600], d_loss: 0.7549, g_loss: 1.6490, D(x): 0.74, D(G(z)): 0.31
# Epoch [120/300], Step [400/600], d_loss: 0.9812, g_loss: 1.7725, D(x): 0.72, D(G(z)): 0.34
# Epoch [120/300], Step [600/600], d_loss: 0.8632, g_loss: 1.4738, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0121.png
# Epoch [121/300], Step [200/600], d_loss: 1.1139, g_loss: 1.3359, D(x): 0.68, D(G(z)): 0.38
# Epoch [121/300], Step [400/600], d_loss: 1.1635, g_loss: 1.2486, D(x): 0.59, D(G(z)): 0.33
# Epoch [121/300], Step [600/600], d_loss: 1.2748, g_loss: 1.1542, D(x): 0.53, D(G(z)): 0.36
# Saving fake_images-0122.png
# Epoch [122/300], Step [200/600], d_loss: 0.7154, g_loss: 1.3375, D(x): 0.74, D(G(z)): 0.26
# Epoch [122/300], Step [400/600], d_loss: 0.8923, g_loss: 1.5959, D(x): 0.67, D(G(z)): 0.28
# Epoch [122/300], Step [600/600], d_loss: 1.2031, g_loss: 1.2691, D(x): 0.59, D(G(z)): 0.33
# Saving fake_images-0123.png
# Epoch [123/300], Step [200/600], d_loss: 1.0591, g_loss: 1.0668, D(x): 0.66, D(G(z)): 0.39
# Epoch [123/300], Step [400/600], d_loss: 0.9733, g_loss: 1.1739, D(x): 0.69, D(G(z)): 0.38
# Epoch [123/300], Step [600/600], d_loss: 0.7800, g_loss: 1.5610, D(x): 0.76, D(G(z)): 0.31
# Saving fake_images-0124.png
# Epoch [124/300], Step [200/600], d_loss: 0.8217, g_loss: 1.4658, D(x): 0.74, D(G(z)): 0.33
# Epoch [124/300], Step [400/600], d_loss: 0.8175, g_loss: 1.5877, D(x): 0.73, D(G(z)): 0.30
# Epoch [124/300], Step [600/600], d_loss: 1.3792, g_loss: 0.9775, D(x): 0.58, D(G(z)): 0.40
# Saving fake_images-0125.png
# Epoch [125/300], Step [200/600], d_loss: 1.2274, g_loss: 1.0622, D(x): 0.59, D(G(z)): 0.38
# Epoch [125/300], Step [400/600], d_loss: 0.9518, g_loss: 1.3136, D(x): 0.66, D(G(z)): 0.32
# Epoch [125/300], Step [600/600], d_loss: 1.0445, g_loss: 1.4437, D(x): 0.62, D(G(z)): 0.31
# Saving fake_images-0126.png
# Epoch [126/300], Step [200/600], d_loss: 1.4626, g_loss: 0.8692, D(x): 0.52, D(G(z)): 0.40
# Epoch [126/300], Step [400/600], d_loss: 1.0760, g_loss: 1.2306, D(x): 0.69, D(G(z)): 0.40
# Epoch [126/300], Step [600/600], d_loss: 0.6891, g_loss: 1.7051, D(x): 0.78, D(G(z)): 0.29
# Saving fake_images-0127.png
# Epoch [127/300], Step [200/600], d_loss: 0.8644, g_loss: 1.4558, D(x): 0.72, D(G(z)): 0.32
# Epoch [127/300], Step [400/600], d_loss: 0.8405, g_loss: 1.5748, D(x): 0.73, D(G(z)): 0.29
# Epoch [127/300], Step [600/600], d_loss: 1.2922, g_loss: 1.2805, D(x): 0.55, D(G(z)): 0.36
# Saving fake_images-0128.png
# Epoch [128/300], Step [200/600], d_loss: 0.9559, g_loss: 1.1285, D(x): 0.69, D(G(z)): 0.36
# Epoch [128/300], Step [400/600], d_loss: 0.6715, g_loss: 1.4873, D(x): 0.78, D(G(z)): 0.27
# Epoch [128/300], Step [600/600], d_loss: 1.0695, g_loss: 1.3293, D(x): 0.66, D(G(z)): 0.34
# Saving fake_images-0129.png
# Epoch [129/300], Step [200/600], d_loss: 1.5176, g_loss: 1.1637, D(x): 0.50, D(G(z)): 0.37
# Epoch [129/300], Step [400/600], d_loss: 1.0568, g_loss: 1.2934, D(x): 0.63, D(G(z)): 0.34
# Epoch [129/300], Step [600/600], d_loss: 0.9991, g_loss: 1.4938, D(x): 0.68, D(G(z)): 0.32
# Saving fake_images-0130.png
# Epoch [130/300], Step [200/600], d_loss: 0.8369, g_loss: 1.5498, D(x): 0.73, D(G(z)): 0.32
# Epoch [130/300], Step [400/600], d_loss: 1.0779, g_loss: 1.2230, D(x): 0.67, D(G(z)): 0.38
# Epoch [130/300], Step [600/600], d_loss: 0.8496, g_loss: 1.3954, D(x): 0.72, D(G(z)): 0.33
# Saving fake_images-0131.png
# Epoch [131/300], Step [200/600], d_loss: 1.1834, g_loss: 1.0922, D(x): 0.62, D(G(z)): 0.39
# Epoch [131/300], Step [400/600], d_loss: 0.8577, g_loss: 1.4930, D(x): 0.72, D(G(z)): 0.30
# Epoch [131/300], Step [600/600], d_loss: 1.1772, g_loss: 1.0794, D(x): 0.66, D(G(z)): 0.40
# Saving fake_images-0132.png
# Epoch [132/300], Step [200/600], d_loss: 1.1317, g_loss: 1.3675, D(x): 0.60, D(G(z)): 0.34
# Epoch [132/300], Step [400/600], d_loss: 0.8333, g_loss: 1.6105, D(x): 0.69, D(G(z)): 0.27
# Epoch [132/300], Step [600/600], d_loss: 1.1996, g_loss: 1.0882, D(x): 0.63, D(G(z)): 0.41
# Saving fake_images-0133.png
# Epoch [133/300], Step [200/600], d_loss: 0.7127, g_loss: 1.4870, D(x): 0.77, D(G(z)): 0.29
# Epoch [133/300], Step [400/600], d_loss: 1.3774, g_loss: 1.1993, D(x): 0.60, D(G(z)): 0.42
# Epoch [133/300], Step [600/600], d_loss: 1.2584, g_loss: 1.1205, D(x): 0.59, D(G(z)): 0.39
# Saving fake_images-0134.png
# Epoch [134/300], Step [200/600], d_loss: 1.2345, g_loss: 1.1679, D(x): 0.63, D(G(z)): 0.39
# Epoch [134/300], Step [400/600], d_loss: 1.2640, g_loss: 1.1783, D(x): 0.60, D(G(z)): 0.41
# Epoch [134/300], Step [600/600], d_loss: 0.6831, g_loss: 1.4000, D(x): 0.75, D(G(z)): 0.26
# Saving fake_images-0135.png
# Epoch [135/300], Step [200/600], d_loss: 0.7397, g_loss: 1.5661, D(x): 0.75, D(G(z)): 0.27
# Epoch [135/300], Step [400/600], d_loss: 1.1697, g_loss: 1.3179, D(x): 0.62, D(G(z)): 0.36
# Epoch [135/300], Step [600/600], d_loss: 0.9158, g_loss: 1.3892, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0136.png
# Epoch [136/300], Step [200/600], d_loss: 0.8784, g_loss: 1.3576, D(x): 0.68, D(G(z)): 0.31
# Epoch [136/300], Step [400/600], d_loss: 1.2416, g_loss: 1.1983, D(x): 0.63, D(G(z)): 0.39
# Epoch [136/300], Step [600/600], d_loss: 1.3730, g_loss: 0.8752, D(x): 0.62, D(G(z)): 0.48
# Saving fake_images-0137.png
# Epoch [137/300], Step [200/600], d_loss: 1.3929, g_loss: 0.9586, D(x): 0.59, D(G(z)): 0.45
# Epoch [137/300], Step [400/600], d_loss: 1.1059, g_loss: 1.0907, D(x): 0.65, D(G(z)): 0.38
# Epoch [137/300], Step [600/600], d_loss: 0.6198, g_loss: 1.6732, D(x): 0.75, D(G(z)): 0.23
# Saving fake_images-0138.png
# Epoch [138/300], Step [200/600], d_loss: 0.9498, g_loss: 1.3931, D(x): 0.71, D(G(z)): 0.33
# Epoch [138/300], Step [400/600], d_loss: 1.0109, g_loss: 1.1102, D(x): 0.64, D(G(z)): 0.33
# Epoch [138/300], Step [600/600], d_loss: 1.2831, g_loss: 0.9337, D(x): 0.60, D(G(z)): 0.40
# Saving fake_images-0139.png
# Epoch [139/300], Step [200/600], d_loss: 1.3944, g_loss: 0.9858, D(x): 0.54, D(G(z)): 0.42
# Epoch [139/300], Step [400/600], d_loss: 1.1315, g_loss: 1.1825, D(x): 0.65, D(G(z)): 0.39
# Epoch [139/300], Step [600/600], d_loss: 0.8329, g_loss: 1.7185, D(x): 0.69, D(G(z)): 0.30
# Saving fake_images-0140.png
# Epoch [140/300], Step [200/600], d_loss: 0.6612, g_loss: 1.4326, D(x): 0.74, D(G(z)): 0.23
# Epoch [140/300], Step [400/600], d_loss: 0.8638, g_loss: 1.5876, D(x): 0.72, D(G(z)): 0.32
# Epoch [140/300], Step [600/600], d_loss: 1.3803, g_loss: 1.1518, D(x): 0.54, D(G(z)): 0.38
# Saving fake_images-0141.png
# Epoch [141/300], Step [200/600], d_loss: 0.7033, g_loss: 1.9647, D(x): 0.74, D(G(z)): 0.25
# Epoch [141/300], Step [400/600], d_loss: 1.3831, g_loss: 1.2856, D(x): 0.54, D(G(z)): 0.37
# Epoch [141/300], Step [600/600], d_loss: 0.8805, g_loss: 1.2597, D(x): 0.72, D(G(z)): 0.35
# Saving fake_images-0142.png
# Epoch [142/300], Step [200/600], d_loss: 0.7802, g_loss: 1.5850, D(x): 0.73, D(G(z)): 0.26
# Epoch [142/300], Step [400/600], d_loss: 1.3658, g_loss: 1.1725, D(x): 0.57, D(G(z)): 0.41
# Epoch [142/300], Step [600/600], d_loss: 0.6939, g_loss: 1.8590, D(x): 0.80, D(G(z)): 0.29
# Saving fake_images-0143.png
# Epoch [143/300], Step [200/600], d_loss: 0.7161, g_loss: 1.8861, D(x): 0.74, D(G(z)): 0.27
# Epoch [143/300], Step [400/600], d_loss: 0.7404, g_loss: 1.6564, D(x): 0.72, D(G(z)): 0.25
# Epoch [143/300], Step [600/600], d_loss: 0.9642, g_loss: 1.4576, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0144.png
# Epoch [144/300], Step [200/600], d_loss: 1.0625, g_loss: 1.3396, D(x): 0.64, D(G(z)): 0.35
# Epoch [144/300], Step [400/600], d_loss: 0.7740, g_loss: 1.4440, D(x): 0.73, D(G(z)): 0.29
# Epoch [144/300], Step [600/600], d_loss: 1.2539, g_loss: 1.2213, D(x): 0.59, D(G(z)): 0.38
# Saving fake_images-0145.png
# Epoch [145/300], Step [200/600], d_loss: 0.7444, g_loss: 1.4357, D(x): 0.77, D(G(z)): 0.29
# Epoch [145/300], Step [400/600], d_loss: 1.4291, g_loss: 1.0608, D(x): 0.61, D(G(z)): 0.45
# Epoch [145/300], Step [600/600], d_loss: 0.9440, g_loss: 1.3609, D(x): 0.67, D(G(z)): 0.30
# Saving fake_images-0146.png
# Epoch [146/300], Step [200/600], d_loss: 0.6985, g_loss: 1.5742, D(x): 0.77, D(G(z)): 0.28
# Epoch [146/300], Step [400/600], d_loss: 1.4877, g_loss: 1.1736, D(x): 0.52, D(G(z)): 0.38
# Epoch [146/300], Step [600/600], d_loss: 0.9463, g_loss: 1.2542, D(x): 0.69, D(G(z)): 0.34
# Saving fake_images-0147.png
# Epoch [147/300], Step [200/600], d_loss: 1.0551, g_loss: 1.5108, D(x): 0.69, D(G(z)): 0.38
# Epoch [147/300], Step [400/600], d_loss: 0.8016, g_loss: 1.5574, D(x): 0.74, D(G(z)): 0.30
# Epoch [147/300], Step [600/600], d_loss: 0.9760, g_loss: 1.6896, D(x): 0.65, D(G(z)): 0.26
# Saving fake_images-0148.png
# Epoch [148/300], Step [200/600], d_loss: 1.2599, g_loss: 1.1784, D(x): 0.61, D(G(z)): 0.39
# Epoch [148/300], Step [400/600], d_loss: 0.7893, g_loss: 1.5540, D(x): 0.74, D(G(z)): 0.32
# Epoch [148/300], Step [600/600], d_loss: 1.0276, g_loss: 1.5024, D(x): 0.67, D(G(z)): 0.31
# Saving fake_images-0149.png
# Epoch [149/300], Step [200/600], d_loss: 1.2544, g_loss: 1.1958, D(x): 0.58, D(G(z)): 0.38
# Epoch [149/300], Step [400/600], d_loss: 0.7436, g_loss: 1.7544, D(x): 0.74, D(G(z)): 0.26
# Epoch [149/300], Step [600/600], d_loss: 1.0774, g_loss: 1.1679, D(x): 0.64, D(G(z)): 0.36
# Saving fake_images-0150.png
# Epoch [150/300], Step [200/600], d_loss: 0.8863, g_loss: 1.4578, D(x): 0.67, D(G(z)): 0.29
# Epoch [150/300], Step [400/600], d_loss: 1.1663, g_loss: 1.3566, D(x): 0.61, D(G(z)): 0.36
# Epoch [150/300], Step [600/600], d_loss: 1.0011, g_loss: 1.3594, D(x): 0.59, D(G(z)): 0.28
# Saving fake_images-0151.png
# Epoch [151/300], Step [200/600], d_loss: 0.7377, g_loss: 1.6629, D(x): 0.76, D(G(z)): 0.28
# Epoch [151/300], Step [400/600], d_loss: 1.2251, g_loss: 1.0685, D(x): 0.62, D(G(z)): 0.38
# Epoch [151/300], Step [600/600], d_loss: 1.0817, g_loss: 1.3766, D(x): 0.64, D(G(z)): 0.38
# Saving fake_images-0152.png
# Epoch [152/300], Step [200/600], d_loss: 0.6842, g_loss: 1.4030, D(x): 0.79, D(G(z)): 0.28
# Epoch [152/300], Step [400/600], d_loss: 1.3704, g_loss: 1.1311, D(x): 0.53, D(G(z)): 0.37
# Epoch [152/300], Step [600/600], d_loss: 0.7740, g_loss: 1.4509, D(x): 0.76, D(G(z)): 0.30
# Saving fake_images-0153.png
# Epoch [153/300], Step [200/600], d_loss: 1.4769, g_loss: 1.0382, D(x): 0.58, D(G(z)): 0.44
# Epoch [153/300], Step [400/600], d_loss: 0.6934, g_loss: 1.6843, D(x): 0.78, D(G(z)): 0.28
# Epoch [153/300], Step [600/600], d_loss: 0.9252, g_loss: 1.3770, D(x): 0.65, D(G(z)): 0.29
# Saving fake_images-0154.png
# Epoch [154/300], Step [200/600], d_loss: 1.3215, g_loss: 1.2406, D(x): 0.59, D(G(z)): 0.39
# Epoch [154/300], Step [400/600], d_loss: 0.8751, g_loss: 1.6250, D(x): 0.66, D(G(z)): 0.27
# Epoch [154/300], Step [600/600], d_loss: 0.7817, g_loss: 1.8044, D(x): 0.72, D(G(z)): 0.25
# Saving fake_images-0155.png
# Epoch [155/300], Step [200/600], d_loss: 1.1701, g_loss: 1.2861, D(x): 0.58, D(G(z)): 0.31
# Epoch [155/300], Step [400/600], d_loss: 0.6695, g_loss: 1.6946, D(x): 0.75, D(G(z)): 0.23
# Epoch [155/300], Step [600/600], d_loss: 0.9350, g_loss: 1.1967, D(x): 0.72, D(G(z)): 0.34
# Saving fake_images-0156.png
# Epoch [156/300], Step [200/600], d_loss: 1.1514, g_loss: 1.2032, D(x): 0.58, D(G(z)): 0.34
# Epoch [156/300], Step [400/600], d_loss: 0.7267, g_loss: 1.8091, D(x): 0.74, D(G(z)): 0.26
# Epoch [156/300], Step [600/600], d_loss: 1.2265, g_loss: 1.2981, D(x): 0.65, D(G(z)): 0.39
# Saving fake_images-0157.png
# Epoch [157/300], Step [200/600], d_loss: 0.6989, g_loss: 1.7093, D(x): 0.74, D(G(z)): 0.25
# Epoch [157/300], Step [400/600], d_loss: 0.7201, g_loss: 1.7841, D(x): 0.76, D(G(z)): 0.25
# Epoch [157/300], Step [600/600], d_loss: 1.1047, g_loss: 1.3194, D(x): 0.58, D(G(z)): 0.29
# Saving fake_images-0158.png
# Epoch [158/300], Step [200/600], d_loss: 0.7961, g_loss: 1.4788, D(x): 0.72, D(G(z)): 0.29
# Epoch [158/300], Step [400/600], d_loss: 1.1808, g_loss: 1.3246, D(x): 0.67, D(G(z)): 0.43
# Epoch [158/300], Step [600/600], d_loss: 1.1342, g_loss: 1.4755, D(x): 0.62, D(G(z)): 0.34
# Saving fake_images-0159.png
# Epoch [159/300], Step [200/600], d_loss: 1.3419, g_loss: 1.2722, D(x): 0.59, D(G(z)): 0.40
# Epoch [159/300], Step [400/600], d_loss: 0.7573, g_loss: 1.6914, D(x): 0.76, D(G(z)): 0.28
# Epoch [159/300], Step [600/600], d_loss: 1.1691, g_loss: 1.2432, D(x): 0.56, D(G(z)): 0.34
# Saving fake_images-0160.png
# Epoch [160/300], Step [200/600], d_loss: 0.9873, g_loss: 1.7880, D(x): 0.69, D(G(z)): 0.31
# ...
# Epoch [247/300], Step [400/600], d_loss: 0.9779, g_loss: 1.7724, D(x): 0.62, D(G(z)): 0.24
# Epoch [247/300], Step [600/600], d_loss: 0.7494, g_loss: 1.6465, D(x): 0.76, D(G(z)): 0.27
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 0.9004, g_loss: 1.7004, D(x): 0.67, D(G(z)): 0.24
# Epoch [248/300], Step [400/600], d_loss: 0.9357, g_loss: 1.6910, D(x): 0.67, D(G(z)): 0.27
# Epoch [248/300], Step [600/600], d_loss: 0.7974, g_loss: 1.6650, D(x): 0.73, D(G(z)): 0.27
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 0.9310, g_loss: 1.4985, D(x): 0.74, D(G(z)): 0.35
# Epoch [249/300], Step [400/600], d_loss: 0.8667, g_loss: 1.5688, D(x): 0.71, D(G(z)): 0.30
# Epoch [249/300], Step [600/600], d_loss: 0.9412, g_loss: 1.6643, D(x): 0.67, D(G(z)): 0.27
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 0.9031, g_loss: 1.5574, D(x): 0.74, D(G(z)): 0.33
# Epoch [250/300], Step [400/600], d_loss: 0.9363, g_loss: 1.7958, D(x): 0.70, D(G(z)): 0.31
# Epoch [250/300], Step [600/600], d_loss: 0.8908, g_loss: 1.5159, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 0.8778, g_loss: 1.6414, D(x): 0.72, D(G(z)): 0.28
# Epoch [251/300], Step [400/600], d_loss: 0.8478, g_loss: 1.5243, D(x): 0.75, D(G(z)): 0.31
# Epoch [251/300], Step [600/600], d_loss: 0.8812, g_loss: 1.6870, D(x): 0.72, D(G(z)): 0.30
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 0.8771, g_loss: 1.6962, D(x): 0.70, D(G(z)): 0.27
# Epoch [252/300], Step [400/600], d_loss: 0.7906, g_loss: 1.4574, D(x): 0.73, D(G(z)): 0.27
# Epoch [252/300], Step [600/600], d_loss: 0.8407, g_loss: 1.7523, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 0.9349, g_loss: 1.8047, D(x): 0.66, D(G(z)): 0.24
# Epoch [253/300], Step [400/600], d_loss: 0.9733, g_loss: 1.5822, D(x): 0.64, D(G(z)): 0.25
# Epoch [253/300], Step [600/600], d_loss: 0.8754, g_loss: 1.7865, D(x): 0.66, D(G(z)): 0.25
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 0.8838, g_loss: 1.6971, D(x): 0.65, D(G(z)): 0.24
# Epoch [254/300], Step [400/600], d_loss: 0.8728, g_loss: 1.6715, D(x): 0.69, D(G(z)): 0.27
# Epoch [254/300], Step [600/600], d_loss: 0.7580, g_loss: 1.7330, D(x): 0.73, D(G(z)): 0.26
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 0.8602, g_loss: 1.7531, D(x): 0.73, D(G(z)): 0.29
# Epoch [255/300], Step [400/600], d_loss: 0.9083, g_loss: 1.5581, D(x): 0.68, D(G(z)): 0.26
# Epoch [255/300], Step [600/600], d_loss: 0.8032, g_loss: 1.6425, D(x): 0.74, D(G(z)): 0.27
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 0.8173, g_loss: 1.4868, D(x): 0.72, D(G(z)): 0.29
# Epoch [256/300], Step [400/600], d_loss: 0.9641, g_loss: 1.6519, D(x): 0.68, D(G(z)): 0.31
# Epoch [256/300], Step [600/600], d_loss: 0.9470, g_loss: 1.8488, D(x): 0.66, D(G(z)): 0.26
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 0.9284, g_loss: 1.5727, D(x): 0.72, D(G(z)): 0.34
# Epoch [257/300], Step [400/600], d_loss: 0.9951, g_loss: 1.6608, D(x): 0.71, D(G(z)): 0.33
# Epoch [257/300], Step [600/600], d_loss: 0.8101, g_loss: 1.5261, D(x): 0.74, D(G(z)): 0.28
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 0.8717, g_loss: 1.7569, D(x): 0.71, D(G(z)): 0.27
# Epoch [258/300], Step [400/600], d_loss: 1.0101, g_loss: 1.5965, D(x): 0.68, D(G(z)): 0.30
# Epoch [258/300], Step [600/600], d_loss: 0.8225, g_loss: 1.8875, D(x): 0.75, D(G(z)): 0.29
# Saving fake_images-0259.png
# Epoch [259/300], Step [200/600], d_loss: 0.8180, g_loss: 1.4407, D(x): 0.71, D(G(z)): 0.24
# Epoch [259/300], Step [400/600], d_loss: 0.8805, g_loss: 1.7667, D(x): 0.71, D(G(z)): 0.26
# Epoch [259/300], Step [600/600], d_loss: 0.8954, g_loss: 1.7740, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0260.png
# Epoch [260/300], Step [200/600], d_loss: 0.8300, g_loss: 1.7691, D(x): 0.69, D(G(z)): 0.25
# Epoch [260/300], Step [400/600], d_loss: 0.8235, g_loss: 1.6113, D(x): 0.76, D(G(z)): 0.31
# Epoch [260/300], Step [600/600], d_loss: 0.9538, g_loss: 1.4264, D(x): 0.77, D(G(z)): 0.37
# Saving fake_images-0261.png
# Epoch [261/300], Step [200/600], d_loss: 0.7928, g_loss: 1.6641, D(x): 0.71, D(G(z)): 0.25
# Epoch [261/300], Step [400/600], d_loss: 0.7110, g_loss: 1.7364, D(x): 0.78, D(G(z)): 0.27
# Epoch [261/300], Step [600/600], d_loss: 0.8065, g_loss: 1.5496, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0262.png
# Epoch [262/300], Step [200/600], d_loss: 0.8187, g_loss: 1.6068, D(x): 0.69, D(G(z)): 0.26
# Epoch [262/300], Step [400/600], d_loss: 0.9057, g_loss: 1.7667, D(x): 0.71, D(G(z)): 0.27
# Epoch [262/300], Step [600/600], d_loss: 0.7987, g_loss: 1.7733, D(x): 0.78, D(G(z)): 0.30
# Saving fake_images-0263.png
# Epoch [263/300], Step [200/600], d_loss: 0.7360, g_loss: 1.9118, D(x): 0.72, D(G(z)): 0.23
# Epoch [263/300], Step [400/600], d_loss: 0.7916, g_loss: 1.6847, D(x): 0.73, D(G(z)): 0.26
# Epoch [263/300], Step [600/600], d_loss: 0.9857, g_loss: 1.5320, D(x): 0.65, D(G(z)): 0.28
# Saving fake_images-0264.png
# Epoch [264/300], Step [200/600], d_loss: 0.8359, g_loss: 2.0242, D(x): 0.73, D(G(z)): 0.26
# Epoch [264/300], Step [400/600], d_loss: 0.9712, g_loss: 1.6497, D(x): 0.69, D(G(z)): 0.29
# Epoch [264/300], Step [600/600], d_loss: 0.8236, g_loss: 1.8234, D(x): 0.73, D(G(z)): 0.25
# Saving fake_images-0265.png
# Epoch [265/300], Step [200/600], d_loss: 0.8261, g_loss: 1.7448, D(x): 0.71, D(G(z)): 0.27
# Epoch [265/300], Step [400/600], d_loss: 0.7675, g_loss: 1.7846, D(x): 0.73, D(G(z)): 0.23
# Epoch [265/300], Step [600/600], d_loss: 1.0697, g_loss: 1.6658, D(x): 0.64, D(G(z)): 0.31
# Saving fake_images-0266.png
# Epoch [266/300], Step [200/600], d_loss: 0.9177, g_loss: 1.8165, D(x): 0.71, D(G(z)): 0.31
# Epoch [266/300], Step [400/600], d_loss: 0.8052, g_loss: 1.5240, D(x): 0.78, D(G(z)): 0.32
# Epoch [266/300], Step [600/600], d_loss: 0.8421, g_loss: 1.6489, D(x): 0.72, D(G(z)): 0.27
# Saving fake_images-0267.png
# Epoch [267/300], Step [200/600], d_loss: 0.8121, g_loss: 1.8945, D(x): 0.71, D(G(z)): 0.26
# Epoch [267/300], Step [400/600], d_loss: 0.8228, g_loss: 1.5191, D(x): 0.77, D(G(z)): 0.33
# Epoch [267/300], Step [600/600], d_loss: 0.9235, g_loss: 1.7329, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0268.png
# Epoch [268/300], Step [200/600], d_loss: 0.8678, g_loss: 1.9644, D(x): 0.63, D(G(z)): 0.20
# Epoch [268/300], Step [400/600], d_loss: 0.7938, g_loss: 1.7057, D(x): 0.72, D(G(z)): 0.25
# Epoch [268/300], Step [600/600], d_loss: 0.7886, g_loss: 1.6845, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0269.png
# Epoch [269/300], Step [200/600], d_loss: 0.8537, g_loss: 1.4438, D(x): 0.72, D(G(z)): 0.28
# Epoch [269/300], Step [400/600], d_loss: 0.7694, g_loss: 1.8086, D(x): 0.73, D(G(z)): 0.24
# Epoch [269/300], Step [600/600], d_loss: 0.7447, g_loss: 1.4556, D(x): 0.76, D(G(z)): 0.30
# Saving fake_images-0270.png
# Epoch [270/300], Step [200/600], d_loss: 0.9078, g_loss: 1.4996, D(x): 0.71, D(G(z)): 0.30
# Epoch [270/300], Step [400/600], d_loss: 0.8331, g_loss: 1.6583, D(x): 0.74, D(G(z)): 0.28
# Epoch [270/300], Step [600/600], d_loss: 0.7567, g_loss: 1.5401, D(x): 0.73, D(G(z)): 0.26
# Saving fake_images-0271.png
# Epoch [271/300], Step [200/600], d_loss: 0.8367, g_loss: 1.5069, D(x): 0.74, D(G(z)): 0.29
# Epoch [271/300], Step [400/600], d_loss: 0.7634, g_loss: 1.8056, D(x): 0.75, D(G(z)): 0.26
# Epoch [271/300], Step [600/600], d_loss: 0.9220, g_loss: 1.7825, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0272.png
# Epoch [272/300], Step [200/600], d_loss: 0.9322, g_loss: 1.8082, D(x): 0.65, D(G(z)): 0.27
# Epoch [272/300], Step [400/600], d_loss: 0.7256, g_loss: 1.5121, D(x): 0.75, D(G(z)): 0.27
# Epoch [272/300], Step [600/600], d_loss: 0.8845, g_loss: 1.7599, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0273.png
# Epoch [273/300], Step [200/600], d_loss: 0.8612, g_loss: 1.8878, D(x): 0.73, D(G(z)): 0.29
# Epoch [273/300], Step [400/600], d_loss: 0.8867, g_loss: 1.9530, D(x): 0.65, D(G(z)): 0.20
# Epoch [273/300], Step [600/600], d_loss: 0.9610, g_loss: 1.6207, D(x): 0.70, D(G(z)): 0.26
# Saving fake_images-0274.png
# Epoch [274/300], Step [200/600], d_loss: 0.7986, g_loss: 1.7161, D(x): 0.74, D(G(z)): 0.27
# Epoch [274/300], Step [400/600], d_loss: 0.8117, g_loss: 1.7762, D(x): 0.80, D(G(z)): 0.33
# Epoch [274/300], Step [600/600], d_loss: 0.7864, g_loss: 1.6144, D(x): 0.79, D(G(z)): 0.31
# Saving fake_images-0275.png
# Epoch [275/300], Step [200/600], d_loss: 0.8044, g_loss: 1.6612, D(x): 0.72, D(G(z)): 0.25
# Epoch [275/300], Step [400/600], d_loss: 0.8706, g_loss: 1.5533, D(x): 0.70, D(G(z)): 0.26
# Epoch [275/300], Step [600/600], d_loss: 0.8294, g_loss: 2.0308, D(x): 0.69, D(G(z)): 0.25
# Saving fake_images-0276.png
# Epoch [276/300], Step [200/600], d_loss: 0.9328, g_loss: 1.4955, D(x): 0.69, D(G(z)): 0.30
# Epoch [276/300], Step [400/600], d_loss: 0.9900, g_loss: 1.7405, D(x): 0.72, D(G(z)): 0.31
# Epoch [276/300], Step [600/600], d_loss: 0.9044, g_loss: 1.5165, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0277.png
# Epoch [277/300], Step [200/600], d_loss: 0.8483, g_loss: 1.8456, D(x): 0.69, D(G(z)): 0.23
# Epoch [277/300], Step [400/600], d_loss: 0.9543, g_loss: 1.8088, D(x): 0.70, D(G(z)): 0.29
# Epoch [277/300], Step [600/600], d_loss: 0.8789, g_loss: 1.6020, D(x): 0.71, D(G(z)): 0.29
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 0.6830, g_loss: 1.5396, D(x): 0.80, D(G(z)): 0.28
# Epoch [278/300], Step [400/600], d_loss: 0.7059, g_loss: 1.8614, D(x): 0.73, D(G(z)): 0.21
# Epoch [278/300], Step [600/600], d_loss: 0.9687, g_loss: 1.7119, D(x): 0.73, D(G(z)): 0.34
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 0.8463, g_loss: 1.7631, D(x): 0.71, D(G(z)): 0.26
# Epoch [279/300], Step [400/600], d_loss: 0.7727, g_loss: 1.8632, D(x): 0.73, D(G(z)): 0.24
# Epoch [279/300], Step [600/600], d_loss: 0.8709, g_loss: 1.7295, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 0.8131, g_loss: 1.6395, D(x): 0.74, D(G(z)): 0.29
# Epoch [280/300], Step [400/600], d_loss: 0.7354, g_loss: 1.6735, D(x): 0.79, D(G(z)): 0.27
# Epoch [280/300], Step [600/600], d_loss: 0.8679, g_loss: 1.6107, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 0.8723, g_loss: 1.7383, D(x): 0.68, D(G(z)): 0.22
# Epoch [281/300], Step [400/600], d_loss: 0.8111, g_loss: 1.5705, D(x): 0.74, D(G(z)): 0.27
# Epoch [281/300], Step [600/600], d_loss: 0.8172, g_loss: 1.7588, D(x): 0.74, D(G(z)): 0.28
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 0.8640, g_loss: 1.6965, D(x): 0.69, D(G(z)): 0.24
# Epoch [282/300], Step [400/600], d_loss: 0.7288, g_loss: 1.8973, D(x): 0.74, D(G(z)): 0.24
# Epoch [282/300], Step [600/600], d_loss: 0.9396, g_loss: 1.7844, D(x): 0.67, D(G(z)): 0.26
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 0.7890, g_loss: 1.8841, D(x): 0.76, D(G(z)): 0.28
# Epoch [283/300], Step [400/600], d_loss: 0.7214, g_loss: 1.6774, D(x): 0.78, D(G(z)): 0.26
# Epoch [283/300], Step [600/600], d_loss: 0.8809, g_loss: 1.7538, D(x): 0.71, D(G(z)): 0.28
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 0.7274, g_loss: 1.5426, D(x): 0.82, D(G(z)): 0.30
# Epoch [284/300], Step [400/600], d_loss: 0.9593, g_loss: 1.6550, D(x): 0.76, D(G(z)): 0.35
# Epoch [284/300], Step [600/600], d_loss: 1.0167, g_loss: 1.4450, D(x): 0.70, D(G(z)): 0.32
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 0.8572, g_loss: 1.6753, D(x): 0.72, D(G(z)): 0.28
# Epoch [285/300], Step [400/600], d_loss: 0.7381, g_loss: 1.8492, D(x): 0.72, D(G(z)): 0.22
# Epoch [285/300], Step [600/600], d_loss: 0.9172, g_loss: 1.5779, D(x): 0.68, D(G(z)): 0.29
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 0.6695, g_loss: 1.9503, D(x): 0.75, D(G(z)): 0.20
# Epoch [286/300], Step [400/600], d_loss: 0.7383, g_loss: 1.8263, D(x): 0.74, D(G(z)): 0.24
# Epoch [286/300], Step [600/600], d_loss: 0.9213, g_loss: 1.7564, D(x): 0.72, D(G(z)): 0.30
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 0.7644, g_loss: 1.7371, D(x): 0.76, D(G(z)): 0.27
# Epoch [287/300], Step [400/600], d_loss: 0.8810, g_loss: 1.6089, D(x): 0.72, D(G(z)): 0.29
# Epoch [287/300], Step [600/600], d_loss: 1.0228, g_loss: 1.6521, D(x): 0.67, D(G(z)): 0.30
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss: 0.7522, g_loss: 1.7721, D(x): 0.73, D(G(z)): 0.23
# Epoch [288/300], Step [400/600], d_loss: 0.8783, g_loss: 1.8629, D(x): 0.69, D(G(z)): 0.23
# Epoch [288/300], Step [600/600], d_loss: 0.7530, g_loss: 1.5058, D(x): 0.81, D(G(z)): 0.31
# Saving fake_images-0289.png
# Epoch [289/300], Step [200/600], d_loss: 0.8938, g_loss: 1.6634, D(x): 0.71, D(G(z)): 0.27
# Epoch [289/300], Step [400/600], d_loss: 0.9990, g_loss: 1.6892, D(x): 0.68, D(G(z)): 0.32
# Epoch [289/300], Step [600/600], d_loss: 0.7900, g_loss: 1.7272, D(x): 0.78, D(G(z)): 0.32
# Saving fake_images-0290.png
# Epoch [290/300], Step [200/600], d_loss: 0.7793, g_loss: 1.6420, D(x): 0.77, D(G(z)): 0.25
# Epoch [290/300], Step [400/600], d_loss: 0.8463, g_loss: 1.6023, D(x): 0.72, D(G(z)): 0.25
# Epoch [290/300], Step [600/600], d_loss: 0.8101, g_loss: 1.8365, D(x): 0.80, D(G(z)): 0.29
# Saving fake_images-0291.png
# Epoch [291/300], Step [200/600], d_loss: 0.7680, g_loss: 1.5741, D(x): 0.74, D(G(z)): 0.24
# Epoch [291/300], Step [400/600], d_loss: 0.6721, g_loss: 2.0168, D(x): 0.75, D(G(z)): 0.21
# Epoch [291/300], Step [600/600], d_loss: 0.8516, g_loss: 1.8424, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0292.png
# Epoch [292/300], Step [200/600], d_loss: 0.6203, g_loss: 1.8114, D(x): 0.79, D(G(z)): 0.23
# Epoch [292/300], Step [400/600], d_loss: 0.7943, g_loss: 1.7216, D(x): 0.72, D(G(z)): 0.26
# Epoch [292/300], Step [600/600], d_loss: 0.8477, g_loss: 1.7221, D(x): 0.79, D(G(z)): 0.30
# Saving fake_images-0293.png
# Epoch [293/300], Step [200/600], d_loss: 0.8644, g_loss: 1.5853, D(x): 0.76, D(G(z)): 0.31
# Epoch [293/300], Step [400/600], d_loss: 0.9370, g_loss: 1.8507, D(x): 0.70, D(G(z)): 0.26
# Epoch [293/300], Step [600/600], d_loss: 0.8664, g_loss: 1.8220, D(x): 0.74, D(G(z)): 0.28
# Saving fake_images-0294.png
# Epoch [294/300], Step [200/600], d_loss: 0.8596, g_loss: 1.6460, D(x): 0.76, D(G(z)): 0.32
# Epoch [294/300], Step [400/600], d_loss: 0.8678, g_loss: 1.4628, D(x): 0.76, D(G(z)): 0.32
# Epoch [294/300], Step [600/600], d_loss: 0.9338, g_loss: 1.6208, D(x): 0.74, D(G(z)): 0.32
# Saving fake_images-0295.png
# Epoch [295/300], Step [200/600], d_loss: 0.7792, g_loss: 1.7483, D(x): 0.78, D(G(z)): 0.30
# Epoch [295/300], Step [400/600], d_loss: 0.6904, g_loss: 1.8250, D(x): 0.75, D(G(z)): 0.21
# Epoch [295/300], Step [600/600], d_loss: 0.9417, g_loss: 1.6747, D(x): 0.74, D(G(z)): 0.34
# Saving fake_images-0296.png
# Epoch [296/300], Step [200/600], d_loss: 0.9290, g_loss: 1.6058, D(x): 0.70, D(G(z)): 0.27
# Epoch [296/300], Step [400/600], d_loss: 0.8226, g_loss: 1.7374, D(x): 0.70, D(G(z)): 0.24
# Epoch [296/300], Step [600/600], d_loss: 0.7694, g_loss: 1.8038, D(x): 0.73, D(G(z)): 0.22
# Saving fake_images-0297.png
# Epoch [297/300], Step [200/600], d_loss: 0.8717, g_loss: 1.5044, D(x): 0.73, D(G(z)): 0.28
# Epoch [297/300], Step [400/600], d_loss: 0.8621, g_loss: 1.7318, D(x): 0.73, D(G(z)): 0.27
# Epoch [297/300], Step [600/600], d_loss: 0.8866, g_loss: 1.4570, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0298.png
# Epoch [298/300], Step [200/600], d_loss: 0.7738, g_loss: 1.7567, D(x): 0.72, D(G(z)): 0.25
# Epoch [298/300], Step [400/600], d_loss: 0.8019, g_loss: 1.7399, D(x): 0.72, D(G(z)): 0.24
# Epoch [298/300], Step [600/600], d_loss: 1.0380, g_loss: 1.7984, D(x): 0.68, D(G(z)): 0.27
# Saving fake_images-0299.png
# Epoch [299/300], Step [200/600], d_loss: 0.8152, g_loss: 2.2492, D(x): 0.70, D(G(z)): 0.21
# Epoch [299/300], Step [400/600], d_loss: 0.8682, g_loss: 1.7841, D(x): 0.70, D(G(z)): 0.26
# Epoch [299/300], Step [600/600], d_loss: 0.7394, g_loss: 1.8997, D(x): 0.77, D(G(z)): 0.27
# Saving fake_images-0300.png
# CPU times: user 2h 57min 44s, sys: 35.3 s, total: 2h 58min 19s
# Wall time: 2h 59min 43s

# %% [markdown]
# Now that we have trained the models, we can save checkpoints.

# %% [markdown]
# Step3. Display at least 3 samples produced from your GAN model.

# %%
Image(os.path.join(sample_dir, 'fake_images-0050.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0150.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0250.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0300.png'))

# %% [markdown]
# It took 2h 33min 19s  and system crashes

# %%
# Save the model checkpoints
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %% [markdown]
# We can visualize the training process by combining the sample images generated
#
# ---
#
# after each epoch into a video using OpenCV.

# %%
import cv2
import os
from IPython.display import FileLink

vid_fname = 'gans_training.avi'

files = [os.path.join(sample_dir, f) for f in os.listdir(sample_dir) if 'fake_images' in f]
files.sort()

out = cv2.VideoWriter(vid_fname,cv2.VideoWriter_fourcc(*'MP4V'), 8, (302,302))
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink('gans_training.avi')
# Out:
# /content/gans_training.avi

# %% [markdown]
# You can view the animated training video here: https://www.youtube.com/watch?v=R7HTX79JlBg
#
# We can also visualize how the loss changes over time. Visualizing losses is quite useful for debugging the training process. For GANs, we expect the generator's loss to reduce over time, without the discriminator's loss getting too high.

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# #Step4. Save the model weights in the folder to be used later.

# %%
torch.save(G.state_dict(), 'generator_weights.pth')
torch.save(D.state_dict(), 'discriminator_weights.pth')

# %% [markdown]
# #Step5. Load the model using the saved weights.

# %%
G.load_state_dict(torch.load('generator_weights.pth'))
D.load_state_dict(torch.load('discriminator_weights.pth'))
# Out:
# <All keys matched successfully>

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %%
num_epochs = 50
for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        images = images.reshape(batch_size, -1).to(device)

        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        if (i+1) % 200 == 0:
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    save_fake_images(epoch+1)
# Out:
# Epoch [0/50], Step [200/600], d_loss: 0.8172, g_loss: 1.6248, D(x): 0.74, D(G(z)): 0.28
# Epoch [0/50], Step [400/600], d_loss: 0.8685, g_loss: 1.7586, D(x): 0.71, D(G(z)): 0.27
# Epoch [0/50], Step [600/600], d_loss: 0.9189, g_loss: 1.5504, D(x): 0.70, D(G(z)): 0.28
# Saving fake_images-0001.png
# Epoch [1/50], Step [200/600], d_loss: 0.8697, g_loss: 1.9861, D(x): 0.68, D(G(z)): 0.20
# Epoch [1/50], Step [400/600], d_loss: 0.7038, g_loss: 1.9634, D(x): 0.73, D(G(z)): 0.23
# Epoch [1/50], Step [600/600], d_loss: 0.8229, g_loss: 1.6258, D(x): 0.71, D(G(z)): 0.25
# Saving fake_images-0002.png
# Epoch [2/50], Step [200/600], d_loss: 0.6881, g_loss: 1.7778, D(x): 0.75, D(G(z)): 0.25
# Epoch [2/50], Step [400/600], d_loss: 0.9799, g_loss: 1.6400, D(x): 0.74, D(G(z)): 0.29
# Epoch [2/50], Step [600/600], d_loss: 0.7032, g_loss: 1.7303, D(x): 0.77, D(G(z)): 0.26
# Saving fake_images-0003.png
# Epoch [3/50], Step [200/600], d_loss: 0.9688, g_loss: 1.9461, D(x): 0.74, D(G(z)): 0.28
# Epoch [3/50], Step [400/600], d_loss: 0.8331, g_loss: 1.7329, D(x): 0.67, D(G(z)): 0.20
# Epoch [3/50], Step [600/600], d_loss: 0.8825, g_loss: 1.9302, D(x): 0.67, D(G(z)): 0.21
# Saving fake_images-0004.png
# Epoch [4/50], Step [200/600], d_loss: 0.8592, g_loss: 1.7076, D(x): 0.75, D(G(z)): 0.31
# Epoch [4/50], Step [400/600], d_loss: 0.8542, g_loss: 1.6060, D(x): 0.71, D(G(z)): 0.27
# Epoch [4/50], Step [600/600], d_loss: 0.8603, g_loss: 1.7479, D(x): 0.76, D(G(z)): 0.29
# Saving fake_images-0005.png
# Epoch [5/50], Step [200/600], d_loss: 0.7149, g_loss: 1.8744, D(x): 0.77, D(G(z)): 0.24
# Epoch [5/50], Step [400/600], d_loss: 0.8074, g_loss: 1.6239, D(x): 0.74, D(G(z)): 0.30
# Epoch [5/50], Step [600/600], d_loss: 0.9260, g_loss: 1.7628, D(x): 0.73, D(G(z)): 0.29
# Saving fake_images-0006.png
# Epoch [6/50], Step [200/600], d_loss: 0.8324, g_loss: 1.5708, D(x): 0.74, D(G(z)): 0.27
# Epoch [6/50], Step [400/600], d_loss: 0.7024, g_loss: 1.6926, D(x): 0.76, D(G(z)): 0.23
# Epoch [6/50], Step [600/600], d_loss: 0.8333, g_loss: 1.7051, D(x): 0.70, D(G(z)): 0.25
# Saving fake_images-0007.png
# Epoch [7/50], Step [200/600], d_loss: 0.7650, g_loss: 1.9455, D(x): 0.74, D(G(z)): 0.24
# Epoch [7/50], Step [400/600], d_loss: 0.9730, g_loss: 1.6161, D(x): 0.74, D(G(z)): 0.34
# Epoch [7/50], Step [600/600], d_loss: 0.8011, g_loss: 2.0061, D(x): 0.74, D(G(z)): 0.26
# Saving fake_images-0008.png
# Epoch [8/50], Step [200/600], d_loss: 0.8287, g_loss: 2.0781, D(x): 0.70, D(G(z)): 0.22
# Epoch [8/50], Step [400/600], d_loss: 0.8308, g_loss: 1.8338, D(x): 0.73, D(G(z)): 0.24
# Epoch [8/50], Step [600/600], d_loss: 0.7278, g_loss: 1.9140, D(x): 0.77, D(G(z)): 0.25
# Saving fake_images-0009.png
# Epoch [9/50], Step [200/600], d_loss: 0.8858, g_loss: 2.1307, D(x): 0.69, D(G(z)): 0.22
# Epoch [9/50], Step [400/600], d_loss: 0.6854, g_loss: 1.5479, D(x): 0.79, D(G(z)): 0.28
# Epoch [9/50], Step [600/600], d_loss: 0.7549, g_loss: 1.5492, D(x): 0.75, D(G(z)): 0.25
# Saving fake_images-0010.png
# Epoch [10/50], Step [200/600], d_loss: 0.8821, g_loss: 1.6515, D(x): 0.71, D(G(z)): 0.27
# Epoch [10/50], Step [400/600], d_loss: 0.7491, g_loss: 2.0686, D(x): 0.71, D(G(z)): 0.20
# Epoch [10/50], Step [600/600], d_loss: 0.8291, g_loss: 1.7373, D(x): 0.70, D(G(z)): 0.22
# Saving fake_images-0011.png
# Epoch [11/50], Step [200/600], d_loss: 1.0049, g_loss: 1.8560, D(x): 0.71, D(G(z)): 0.31
# Epoch [11/50], Step [400/600], d_loss: 0.6810, g_loss: 1.5025, D(x): 0.76, D(G(z)): 0.22
# Epoch [11/50], Step [600/600], d_loss: 0.8744, g_loss: 1.4894, D(x): 0.73, D(G(z)): 0.29
# Saving fake_images-0012.png
# Epoch [12/50], Step [200/600], d_loss: 0.7515, g_loss: 1.5073, D(x): 0.78, D(G(z)): 0.28
# Epoch [12/50], Step [400/600], d_loss: 0.8467, g_loss: 1.8696, D(x): 0.75, D(G(z)): 0.30
# Epoch [12/50], Step [600/600], d_loss: 0.8606, g_loss: 1.8954, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0013.png
# Epoch [13/50], Step [200/600], d_loss: 0.6933, g_loss: 1.8908, D(x): 0.76, D(G(z)): 0.25
# Epoch [13/50], Step [400/600], d_loss: 0.7737, g_loss: 1.9741, D(x): 0.75, D(G(z)): 0.26
# Epoch [13/50], Step [600/600], d_loss: 0.9248, g_loss: 1.8545, D(x): 0.71, D(G(z)): 0.27
# Saving fake_images-0014.png
# Epoch [14/50], Step [200/600], d_loss: 0.7744, g_loss: 1.8209, D(x): 0.75, D(G(z)): 0.25
# Epoch [14/50], Step [400/600], d_loss: 0.9264, g_loss: 1.5701, D(x): 0.74, D(G(z)): 0.30
# Epoch [14/50], Step [600/600], d_loss: 0.8248, g_loss: 1.7376, D(x): 0.70, D(G(z)): 0.25
# Saving fake_images-0015.png
# Epoch [15/50], Step [200/600], d_loss: 0.9148, g_loss: 1.9854, D(x): 0.74, D(G(z)): 0.33
# Epoch [15/50], Step [400/600], d_loss: 0.8568, g_loss: 1.8513, D(x): 0.72, D(G(z)): 0.28
# Epoch [15/50], Step [600/600], d_loss: 0.7923, g_loss: 1.7994, D(x): 0.77, D(G(z)): 0.27
# Saving fake_images-0016.png
# Epoch [16/50], Step [200/600], d_loss: 0.7824, g_loss: 1.8399, D(x): 0.74, D(G(z)): 0.26
# Epoch [16/50], Step [400/600], d_loss: 0.8794, g_loss: 1.7799, D(x): 0.66, D(G(z)): 0.21
# Epoch [16/50], Step [600/600], d_loss: 0.8112, g_loss: 1.7019, D(x): 0.74, D(G(z)): 0.28
# Saving fake_images-0017.png
# Epoch [17/50], Step [200/600], d_loss: 0.9234, g_loss: 1.6329, D(x): 0.74, D(G(z)): 0.31
# Epoch [17/50], Step [400/600], d_loss: 0.8559, g_loss: 1.7418, D(x): 0.71, D(G(z)): 0.26
# Epoch [17/50], Step [600/600], d_loss: 0.9419, g_loss: 1.9118, D(x): 0.67, D(G(z)): 0.26
# Saving fake_images-0018.png
# Epoch [18/50], Step [200/600], d_loss: 0.7607, g_loss: 2.2155, D(x): 0.70, D(G(z)): 0.19
# Epoch [18/50], Step [400/600], d_loss: 0.9687, g_loss: 1.6536, D(x): 0.65, D(G(z)): 0.26
# Epoch [18/50], Step [600/600], d_loss: 0.7569, g_loss: 1.7211, D(x): 0.77, D(G(z)): 0.27
# Saving fake_images-0019.png
# Epoch [19/50], Step [200/600], d_loss: 0.8844, g_loss: 1.7011, D(x): 0.74, D(G(z)): 0.32
# Epoch [19/50], Step [400/600], d_loss: 0.7759, g_loss: 1.7277, D(x): 0.73, D(G(z)): 0.25
# Epoch [19/50], Step [600/600], d_loss: 0.8732, g_loss: 1.8067, D(x): 0.72, D(G(z)): 0.27
# Saving fake_images-0020.png
# Epoch [20/50], Step [200/600], d_loss: 0.6873, g_loss: 1.8924, D(x): 0.76, D(G(z)): 0.22
# Epoch [20/50], Step [400/600], d_loss: 0.9973, g_loss: 1.8507, D(x): 0.68, D(G(z)): 0.26
# Epoch [20/50], Step [600/600], d_loss: 0.8265, g_loss: 1.9948, D(x): 0.72, D(G(z)): 0.25
# Saving fake_images-0021.png
# Epoch [21/50], Step [200/600], d_loss: 0.6200, g_loss: 1.7934, D(x): 0.76, D(G(z)): 0.20
# Epoch [21/50], Step [400/600], d_loss: 0.6852, g_loss: 1.9807, D(x): 0.75, D(G(z)): 0.22
# Epoch [21/50], Step [600/600], d_loss: 0.6938, g_loss: 1.5422, D(x): 0.74, D(G(z)): 0.23
# Saving fake_images-0022.png
# Epoch [22/50], Step [200/600], d_loss: 0.7877, g_loss: 1.7213, D(x): 0.73, D(G(z)): 0.24
# Epoch [22/50], Step [400/600], d_loss: 0.8213, g_loss: 1.8573, D(x): 0.75, D(G(z)): 0.28
# Epoch [22/50], Step [600/600], d_loss: 0.9133, g_loss: 1.7468, D(x): 0.65, D(G(z)): 0.22
# Saving fake_images-0023.png
# Epoch [23/50], Step [200/600], d_loss: 0.7015, g_loss: 1.7782, D(x): 0.77, D(G(z)): 0.26
# Epoch [23/50], Step [400/600], d_loss: 0.9497, g_loss: 1.5593, D(x): 0.73, D(G(z)): 0.32
# Epoch [23/50], Step [600/600], d_loss: 0.8568, g_loss: 1.6683, D(x): 0.74, D(G(z)): 0.29
# Saving fake_images-0024.png
# Epoch [24/50], Step [200/600], d_loss: 0.6207, g_loss: 1.7388, D(x): 0.75, D(G(z)): 0.19
# Epoch [24/50], Step [400/600], d_loss: 0.7004, g_loss: 1.9872, D(x): 0.79, D(G(z)): 0.26
# Epoch [24/50], Step [600/600], d_loss: 0.9796, g_loss: 1.7887, D(x): 0.63, D(G(z)): 0.25
# Saving fake_images-0025.png
# Epoch [25/50], Step [200/600], d_loss: 0.8127, g_loss: 1.6631, D(x): 0.73, D(G(z)): 0.28
# Epoch [25/50], Step [400/600], d_loss: 0.7893, g_loss: 1.5979, D(x): 0.72, D(G(z)): 0.24
# Epoch [25/50], Step [600/600], d_loss: 0.7528, g_loss: 1.7501, D(x): 0.77, D(G(z)): 0.26
# Saving fake_images-0026.png
# Epoch [26/50], Step [200/600], d_loss: 0.8073, g_loss: 1.8931, D(x): 0.76, D(G(z)): 0.25
# Epoch [26/50], Step [400/600], d_loss: 0.8671, g_loss: 1.8768, D(x): 0.74, D(G(z)): 0.26
# Epoch [26/50], Step [600/600], d_loss: 0.7741, g_loss: 1.9323, D(x): 0.75, D(G(z)): 0.25
# Saving fake_images-0027.png
# Epoch [27/50], Step [200/600], d_loss: 0.8926, g_loss: 1.5490, D(x): 0.75, D(G(z)): 0.31
# Epoch [27/50], Step [400/600], d_loss: 0.7960, g_loss: 2.0171, D(x): 0.73, D(G(z)): 0.24
# Epoch [27/50], Step [600/600], d_loss: 0.6625, g_loss: 1.9503, D(x): 0.76, D(G(z)): 0.23
# Saving fake_images-0028.png
# Epoch [28/50], Step [200/600], d_loss: 0.7153, g_loss: 1.7085, D(x): 0.80, D(G(z)): 0.30
# Epoch [28/50], Step [400/600], d_loss: 0.7953, g_loss: 1.9388, D(x): 0.72, D(G(z)): 0.26
# Epoch [28/50], Step [600/600], d_loss: 0.8377, g_loss: 1.7890, D(x): 0.75, D(G(z)): 0.27
# Saving fake_images-0029.png
# Epoch [29/50], Step [200/600], d_loss: 0.8102, g_loss: 1.7574, D(x): 0.81, D(G(z)): 0.33
# Epoch [29/50], Step [400/600], d_loss: 0.9205, g_loss: 1.8045, D(x): 0.68, D(G(z)): 0.25
# Epoch [29/50], Step [600/600], d_loss: 0.9315, g_loss: 1.8707, D(x): 0.71, D(G(z)): 0.26
# Saving fake_images-0030.png
# Epoch [30/50], Step [200/600], d_loss: 0.7830, g_loss: 2.0296, D(x): 0.77, D(G(z)): 0.28
# Epoch [30/50], Step [400/600], d_loss: 0.8370, g_loss: 2.1165, D(x): 0.72, D(G(z)): 0.25
# Epoch [30/50], Step [600/600], d_loss: 0.8427, g_loss: 1.5305, D(x): 0.71, D(G(z)): 0.24
# Saving fake_images-0031.png
# Epoch [31/50], Step [200/600], d_loss: 0.8604, g_loss: 1.7244, D(x): 0.70, D(G(z)): 0.26
# Epoch [31/50], Step [400/600], d_loss: 0.8986, g_loss: 1.8273, D(x): 0.72, D(G(z)): 0.29
# Epoch [31/50], Step [600/600], d_loss: 0.9164, g_loss: 1.7817, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0032.png
# Epoch [32/50], Step [200/600], d_loss: 0.8759, g_loss: 1.7984, D(x): 0.71, D(G(z)): 0.27
# Epoch [32/50], Step [400/600], d_loss: 0.8731, g_loss: 1.6016, D(x): 0.73, D(G(z)): 0.28
# Epoch [32/50], Step [600/600], d_loss: 1.0385, g_loss: 1.8143, D(x): 0.68, D(G(z)): 0.29
# Saving fake_images-0033.png
# Epoch [33/50], Step [200/600], d_loss: 0.7249, g_loss: 2.1748, D(x): 0.80, D(G(z)): 0.25
# Epoch [33/50], Step [400/600], d_loss: 0.6935, g_loss: 1.8811, D(x): 0.73, D(G(z)): 0.21
# Epoch [33/50], Step [600/600], d_loss: 0.7735, g_loss: 1.9108, D(x): 0.73, D(G(z)): 0.22
# Saving fake_images-0034.png
# Epoch [34/50], Step [200/600], d_loss: 0.7795, g_loss: 1.5867, D(x): 0.77, D(G(z)): 0.29
# Epoch [34/50], Step [400/600], d_loss: 0.7071, g_loss: 1.6628, D(x): 0.79, D(G(z)): 0.28
# Epoch [34/50], Step [600/600], d_loss: 0.9177, g_loss: 1.6917, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0035.png
# Epoch [35/50], Step [200/600], d_loss: 0.7189, g_loss: 1.8820, D(x): 0.77, D(G(z)): 0.23
# Epoch [35/50], Step [400/600], d_loss: 0.6230, g_loss: 1.7779, D(x): 0.79, D(G(z)): 0.22
# Epoch [35/50], Step [600/600], d_loss: 0.9536, g_loss: 1.8050, D(x): 0.67, D(G(z)): 0.24
# Saving fake_images-0036.png
# Epoch [36/50], Step [200/600], d_loss: 0.6969, g_loss: 2.0509, D(x): 0.79, D(G(z)): 0.27
# Epoch [36/50], Step [400/600], d_loss: 0.8942, g_loss: 1.7027, D(x): 0.77, D(G(z)): 0.32
# Epoch [36/50], Step [600/600], d_loss: 0.8365, g_loss: 1.8239, D(x): 0.75, D(G(z)): 0.26
# Saving fake_images-0037.png
# Epoch [37/50], Step [200/600], d_loss: 0.6950, g_loss: 1.9689, D(x): 0.76, D(G(z)): 0.23
# Epoch [37/50], Step [400/600], d_loss: 0.8534, g_loss: 2.0583, D(x): 0.73, D(G(z)): 0.27
# Epoch [37/50], Step [600/600], d_loss: 0.8624, g_loss: 1.6154, D(x): 0.81, D(G(z)): 0.36
# Saving fake_images-0038.png
# Epoch [38/50], Step [200/600], d_loss: 0.8006, g_loss: 1.6952, D(x): 0.73, D(G(z)): 0.25
# Epoch [38/50], Step [400/600], d_loss: 0.8673, g_loss: 1.8623, D(x): 0.71, D(G(z)): 0.23
# Epoch [38/50], Step [600/600], d_loss: 0.8425, g_loss: 1.8395, D(x): 0.71, D(G(z)): 0.25
# Saving fake_images-0039.png
# Epoch [39/50], Step [200/600], d_loss: 0.8535, g_loss: 1.9151, D(x): 0.67, D(G(z)): 0.20
# Epoch [39/50], Step [400/600], d_loss: 0.7706, g_loss: 1.8186, D(x): 0.73, D(G(z)): 0.23
# Epoch [39/50], Step [600/600], d_loss: 0.8285, g_loss: 1.7294, D(x): 0.76, D(G(z)): 0.26
# Saving fake_images-0040.png
# Epoch [40/50], Step [200/600], d_loss: 0.7372, g_loss: 1.9376, D(x): 0.73, D(G(z)): 0.21
# Epoch [40/50], Step [400/600], d_loss: 0.8685, g_loss: 1.6542, D(x): 0.72, D(G(z)): 0.26
# Epoch [40/50], Step [600/600], d_loss: 0.7868, g_loss: 1.5633, D(x): 0.73, D(G(z)): 0.25
# Saving fake_images-0041.png
# Epoch [41/50], Step [200/600], d_loss: 0.6625, g_loss: 2.0150, D(x): 0.78, D(G(z)): 0.23
# Epoch [41/50], Step [400/600], d_loss: 0.7544, g_loss: 2.0840, D(x): 0.73, D(G(z)): 0.22
# Epoch [41/50], Step [600/600], d_loss: 0.8673, g_loss: 1.6745, D(x): 0.70, D(G(z)): 0.23
# Saving fake_images-0042.png
# Epoch [42/50], Step [200/600], d_loss: 0.7953, g_loss: 1.5202, D(x): 0.74, D(G(z)): 0.25
# Epoch [42/50], Step [400/600], d_loss: 0.8249, g_loss: 1.8933, D(x): 0.77, D(G(z)): 0.31
# Epoch [42/50], Step [600/600], d_loss: 0.7150, g_loss: 1.5410, D(x): 0.81, D(G(z)): 0.27
# Saving fake_images-0043.png
# Epoch [43/50], Step [200/600], d_loss: 0.8504, g_loss: 1.8512, D(x): 0.71, D(G(z)): 0.25
# Epoch [43/50], Step [400/600], d_loss: 0.8341, g_loss: 1.8467, D(x): 0.67, D(G(z)): 0.21
# Epoch [43/50], Step [600/600], d_loss: 0.7040, g_loss: 1.8018, D(x): 0.82, D(G(z)): 0.29
# Saving fake_images-0044.png
# Epoch [44/50], Step [200/600], d_loss: 0.7846, g_loss: 1.9354, D(x): 0.75, D(G(z)): 0.23
# Epoch [44/50], Step [400/600], d_loss: 0.7936, g_loss: 1.6735, D(x): 0.73, D(G(z)): 0.26
# Epoch [44/50], Step [600/600], d_loss: 0.8350, g_loss: 1.9803, D(x): 0.70, D(G(z)): 0.23
# Saving fake_images-0045.png
# Epoch [45/50], Step [200/600], d_loss: 0.7128, g_loss: 1.9019, D(x): 0.77, D(G(z)): 0.26
# Epoch [45/50], Step [400/600], d_loss: 0.7768, g_loss: 1.8656, D(x): 0.74, D(G(z)): 0.24
# Epoch [45/50], Step [600/600], d_loss: 0.7565, g_loss: 1.6840, D(x): 0.74, D(G(z)): 0.23
# Saving fake_images-0046.png
# Epoch [46/50], Step [200/600], d_loss: 0.8438, g_loss: 1.9248, D(x): 0.73, D(G(z)): 0.23
# Epoch [46/50], Step [400/600], d_loss: 0.9856, g_loss: 1.9387, D(x): 0.72, D(G(z)): 0.28
# Epoch [46/50], Step [600/600], d_loss: 0.9402, g_loss: 1.5904, D(x): 0.71, D(G(z)): 0.29
# Saving fake_images-0047.png
# Epoch [47/50], Step [200/600], d_loss: 0.9562, g_loss: 1.7093, D(x): 0.75, D(G(z)): 0.33
# Epoch [47/50], Step [400/600], d_loss: 0.9224, g_loss: 1.7194, D(x): 0.73, D(G(z)): 0.32
# Epoch [47/50], Step [600/600], d_loss: 0.8879, g_loss: 1.7719, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0048.png
# Epoch [48/50], Step [200/600], d_loss: 0.7642, g_loss: 1.6814, D(x): 0.76, D(G(z)): 0.26
# Epoch [48/50], Step [400/600], d_loss: 0.8065, g_loss: 1.8593, D(x): 0.73, D(G(z)): 0.23
# Epoch [48/50], Step [600/600], d_loss: 0.8899, g_loss: 1.9680, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0049.png
# Epoch [49/50], Step [200/600], d_loss: 0.8033, g_loss: 1.8752, D(x): 0.72, D(G(z)): 0.23
# Epoch [49/50], Step [400/600], d_loss: 0.7168, g_loss: 1.8502, D(x): 0.77, D(G(z)): 0.23
# Epoch [49/50], Step [600/600], d_loss: 0.8873, g_loss: 1.8250, D(x): 0.69, D(G(z)): 0.24
# Saving fake_images-0050.png

# %% [markdown]
# # Step 7: Save the model weights without using checkpoints.

# %%
torch.save(G.state_dict(), 'generator_weights_no_checkpoint.pth')
torch.save(D.state_dict(), 'discriminator_weights_no_checkpoint.pth')

# %% [markdown]
# #Step 8: Load the model weights without using checkpoints.

# %%
G_no_checkpoint = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),  # Additional layer
    nn.ReLU(),  # Activation function
    nn.Linear(hidden_size, hidden_size),  # Additional layer
    nn.ReLU(),  # Activation function
    nn.Linear(hidden_size, image_size),
    nn.Tanh()

)

D_no_checkpoint = nn.Sequential(
   nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),  # Additional layer
    nn.LeakyReLU(0.2),  # Activation function
    nn.Linear(hidden_size, hidden_size),  # Additional layer
    nn.LeakyReLU(0.2),  # Activation function
    nn.Linear(hidden_size, 1),
    nn.Sigmoid()
)

G_no_checkpoint.load_state_dict(torch.load('generator_weights_no_checkpoint.pth'))
D_no_checkpoint.load_state_dict(torch.load('discriminator_weights_no_checkpoint.pth'))
# Out:
# <All keys matched successfully>

# %%
Image(os.path.join(sample_dir, 'fake_images-0001.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0015.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0030.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0050.png'))

# %% [markdown]
# The output the images is improved and is close to the original image

# %%
Image(os.path.join(sample_dir, 'real_images.png'))
