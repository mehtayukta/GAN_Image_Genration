# %% [markdown]
# #LS-GAN

# %% [markdown]
# #Step1. Load the Fashion MNIST dataset
#
# ## Load the Data
#
# We begin by downloading and importing the data as a PyTorch dataset using the `Fashion MNIST` helper class from `torchvision.datasets`.

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import FashionMNIST

mnist = FashionMNIST(root='data',
              train=True,
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:01<00:00, 13375174.21it/s]
# Extracting data/FashionMNIST/raw/train-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 272036.01it/s]
# Extracting data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:00<00:00, 4955101.89it/s]
# Extracting data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 4801484.77it/s]
# Extracting data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw

# %% [markdown]
# Note that we are are transforming the pixel values from the range `[0, 1]` to the range `[-1, 1]`. The reason for doing this will become clear when define the generator network. Let's look at a sample tensor from the data.

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  9
# tensor([[[-1.0000, -1.0000, -1.0000,  0.5137,  0.7882],
#          [-0.9765, -1.0000, -0.9059,  0.7176,  0.7255],
#          [-0.9529, -1.0000, -0.2235,  0.9137,  0.7412],
#          [-1.0000, -1.0000, -0.5686,  0.8510,  0.7882],
#          [-1.0000, -1.0000,  0.8588,  0.7725,  0.7020]]])
# (tensor(-1.), tensor(1.))

# %% [markdown]
# There are total 9 classes
#
# As expected, the pixel values range from -1 to 1. Let's define a helper to denormalize and view the images. This function will also be useful for viewing the generated images.
#
# (tensor(-1.), tensor(1.))

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 9

# %% [markdown]
# Finally, let's create a dataloader to load the images in batches.

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([3, 7, 3, 5, 6, 2, 8, 7, 4, 3, 2, 4, 8, 8, 6, 0, 5, 1, 0, 2, 4, 3, 0, 8,
#         7, 4, 5, 4, 0, 2, 1, 9, 2, 9, 9, 6, 4, 1, 7, 3, 1, 8, 9, 9, 5, 6, 7, 4,
#         6, 5, 5, 1, 0, 6, 0, 3, 0, 8, 9, 0, 6, 4, 2, 0, 8, 1, 8, 3, 6, 9, 2, 4,
#         4, 9, 4, 5, 6, 2, 0, 1, 9, 6, 7, 4, 0, 7, 4, 7, 6, 0, 5, 8, 5, 9, 9, 2,
#         2, 7, 0, 2])

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## Discriminator Network
#
# The discriminator takes an image as input, and tries to classify it as "real" or "generated". In this sense, it's like any other neural network. While we can use a CNN for the discriminator, we'll use a simple feedforward network with 3 linear layers to keep things since. We'll treat each 28x28 image as a vector of size 784.

# %%
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %% [markdown]
# We use the Leaky ReLU activation for the discriminator.
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*ypsvQH7kvtI2BhzR2eT_Sw.png" width="420">
#
#
# >  Different from the regular ReLU function, Leaky ReLU allows the pass of a small gradient signal for negative values. As a result, it makes the gradients from the discriminator flows stronger into the generator. Instead of passing a gradient (slope) of 0 in the back-prop pass, it passes a small negative gradient.  - [Source](https://sthalles.github.io/advanced_gans/)
#
# Just like any other binary classification model, the output of the discriminator is a single number between 0 and 1, which can be interpreted as the probability of the input image being fake i.e. generated.
#
# Let's move the discriminator model to the chosen device.
#
# In the context of PyTorch or similar deep learning frameworks, the expression D.to(device) is used to move a tensor or a model to a specific device for computation, such as a CPU or a GPU. Let me break it down for you:
#
# Tensor or Model: D represents either a tensor (data) or a model (neural network) object in PyTorch.
#
# .to(device): This is a method in PyTorch that allows you to specify the device where you want to perform computations. The device argument specifies the target device, which can be a CPU or a GPU. For example:
#
# device='cpu': Indicates that computations should be performed on the CPU.
# device='cuda:0' or device='cuda:1': Indicates that computations should be performed on a specific GPU. The number after cuda: refers to the GPU index.

# %%
D.to(device);

# %% [markdown]
# ## Generator Network
#
# The input to the generator is typically a vector or a matrix which is used as a seed for generating an image. Once again, to keep things simple, we'll use a feedfoward neural network with 3 layers, and the output will be a vector of size 784, which can be transformed to a 28x28 px image.

# %% [markdown]
# Generative Adversarial Networks (GANs), the term latent_size = 64 typically refers to the dimensionality of the latent space.
#
# Latent Space: The latent space is a lower-dimensional space where the model learns to represent the underlying structure or features of the input data in a more compact form. In VAEs and GANs, the latent space represents the space of encoded or generated data points.
#
# The latent_size = 64 statement indicates that the dimensionality of the latent space is 64. This means that each data point in the latent space is represented by a vector of 64 numbers.

# %%
latent_size = 64

# %%
G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %% [markdown]
# We use the TanH activation function for the output layer of the generator.
#
# <img src="https://nic.schraudolph.org/teach/NNcourse/figs/tanh.gif" width="420" >
#
# > "The ReLU activation (Nair & Hinton, 2010) is used in the generator with the exception of the output layer which uses the Tanh function. We observed that using a bounded activation allowed the model to learn more quickly to saturate and cover the color space of the training distribution. Within the discriminator we found the leaky rectified activation (Maas et al., 2013) (Xu et al., 2015) to work well, especially for higher resolution modeling." - [Source](https://stackoverflow.com/questions/41489907/generative-adversarial-networks-tanh)
#
#
# Note that since the outputs of the TanH activation lie in the range `[-1,1]`, we have applied the same transformation to the images in the training dataset. Let's generate an output vector using the generator and view it as an image by transforming and denormalizing the output.

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %% [markdown]
# As one might expect, the output from the generator is basically random noise. Let's define a helper function which can save a batch of outputs from the generator to a file.
#
# Let's move the generator to the chosen device.

# %%
G.to(device);

# %%
criterion = nn.MSELoss() # LSGAN uses MSE
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %% [markdown]
# Let's define helper functions to reset gradients and  train the discriminator.

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)

    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()

    return d_loss, real_score, fake_score

# %% [markdown]
# # Step2. Train the LS GAN model to produce images in this new domain.

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# ## Training the Model
#
# Let's create a directory where we can save intermediate outputs from the generator to visually inspect the progress of the model

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break

Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# We'll also define a helper function to save a batch of generated images to disk at the end of every epoch. We'll use a fixed set of input vectors to the generator to see how the individual generated images evolve over time as we train the model.

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)

# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# We are now ready to train the model. In each epoch, we train the discriminator first, and then the generator. The training might take a while if you're not using a GPU.

# %%
# %%time

num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)

        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.0166, g_loss: 0.8607, D(x): 0.97, D(G(z)): 0.11
# Epoch [0/300], Step [400/600], d_loss: 0.0060, g_loss: 0.9647, D(x): 0.99, D(G(z)): 0.05
# Epoch [0/300], Step [600/600], d_loss: 0.0236, g_loss: 0.9349, D(x): 0.95, D(G(z)): 0.09
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.0135, g_loss: 0.9795, D(x): 0.97, D(G(z)): 0.01
# Epoch [1/300], Step [400/600], d_loss: 0.0040, g_loss: 0.9652, D(x): 0.99, D(G(z)): 0.04
# Epoch [1/300], Step [600/600], d_loss: 0.0026, g_loss: 0.9631, D(x): 0.99, D(G(z)): 0.02
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.0081, g_loss: 0.9689, D(x): 0.99, D(G(z)): 0.05
# Epoch [2/300], Step [400/600], d_loss: 0.0021, g_loss: 0.9626, D(x): 1.00, D(G(z)): 0.03
# Epoch [2/300], Step [600/600], d_loss: 0.0031, g_loss: 0.9986, D(x): 0.99, D(G(z)): 0.00
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 0.0001, g_loss: 0.9954, D(x): 1.00, D(G(z)): 0.00
# Epoch [3/300], Step [400/600], d_loss: 0.0118, g_loss: 0.9941, D(x): 0.98, D(G(z)): 0.01
# Epoch [3/300], Step [600/600], d_loss: 0.0060, g_loss: 0.9922, D(x): 0.98, D(G(z)): 0.01
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.0199, g_loss: 0.9435, D(x): 1.00, D(G(z)): 0.07
# Epoch [4/300], Step [400/600], d_loss: 0.0616, g_loss: 0.9652, D(x): 0.91, D(G(z)): 0.03
# Epoch [4/300], Step [600/600], d_loss: 0.0055, g_loss: 0.9862, D(x): 0.99, D(G(z)): 0.03
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.0436, g_loss: 0.9513, D(x): 0.94, D(G(z)): 0.07
# Epoch [5/300], Step [400/600], d_loss: 0.0634, g_loss: 0.9881, D(x): 0.91, D(G(z)): 0.01
# Epoch [5/300], Step [600/600], d_loss: 0.0725, g_loss: 0.9346, D(x): 0.92, D(G(z)): 0.05
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.0258, g_loss: 0.9761, D(x): 0.95, D(G(z)): 0.03
# Epoch [6/300], Step [400/600], d_loss: 0.0375, g_loss: 0.9814, D(x): 0.94, D(G(z)): 0.00
# Epoch [6/300], Step [600/600], d_loss: 0.0879, g_loss: 0.9103, D(x): 0.95, D(G(z)): 0.15
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.0512, g_loss: 0.9554, D(x): 0.96, D(G(z)): 0.07
# Epoch [7/300], Step [400/600], d_loss: 0.0542, g_loss: 0.8709, D(x): 0.98, D(G(z)): 0.08
# Epoch [7/300], Step [600/600], d_loss: 0.0283, g_loss: 0.9461, D(x): 0.96, D(G(z)): 0.03
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.1106, g_loss: 0.9314, D(x): 0.91, D(G(z)): 0.07
# Epoch [8/300], Step [400/600], d_loss: 0.0898, g_loss: 0.9427, D(x): 0.89, D(G(z)): 0.06
# Epoch [8/300], Step [600/600], d_loss: 0.0687, g_loss: 0.8850, D(x): 0.95, D(G(z)): 0.10
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.0769, g_loss: 0.9567, D(x): 0.93, D(G(z)): 0.12
# Epoch [9/300], Step [400/600], d_loss: 0.0633, g_loss: 0.9552, D(x): 0.93, D(G(z)): 0.08
# Epoch [9/300], Step [600/600], d_loss: 0.0516, g_loss: 0.8863, D(x): 0.95, D(G(z)): 0.08
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.2001, g_loss: 0.9431, D(x): 0.85, D(G(z)): 0.14
# Epoch [10/300], Step [400/600], d_loss: 0.0614, g_loss: 0.9816, D(x): 0.91, D(G(z)): 0.06
# Epoch [10/300], Step [600/600], d_loss: 0.0812, g_loss: 0.9294, D(x): 0.91, D(G(z)): 0.07
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.0576, g_loss: 0.9836, D(x): 0.91, D(G(z)): 0.05
# Epoch [11/300], Step [400/600], d_loss: 0.0817, g_loss: 0.8945, D(x): 0.94, D(G(z)): 0.14
# Epoch [11/300], Step [600/600], d_loss: 0.0960, g_loss: 0.9082, D(x): 0.90, D(G(z)): 0.08
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.0657, g_loss: 0.9562, D(x): 0.92, D(G(z)): 0.08
# Epoch [12/300], Step [400/600], d_loss: 0.0912, g_loss: 0.8535, D(x): 0.90, D(G(z)): 0.10
# Epoch [12/300], Step [600/600], d_loss: 0.0377, g_loss: 0.9097, D(x): 0.96, D(G(z)): 0.06
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.0511, g_loss: 0.9134, D(x): 0.93, D(G(z)): 0.05
# Epoch [13/300], Step [400/600], d_loss: 0.0954, g_loss: 0.8320, D(x): 0.90, D(G(z)): 0.10
# Epoch [13/300], Step [600/600], d_loss: 0.1592, g_loss: 0.7505, D(x): 0.86, D(G(z)): 0.14
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.1403, g_loss: 0.8912, D(x): 0.81, D(G(z)): 0.07
# Epoch [14/300], Step [400/600], d_loss: 0.1305, g_loss: 0.8313, D(x): 0.84, D(G(z)): 0.08
# Epoch [14/300], Step [600/600], d_loss: 0.2032, g_loss: 0.8787, D(x): 0.84, D(G(z)): 0.18
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.0816, g_loss: 0.9267, D(x): 0.91, D(G(z)): 0.10
# Epoch [15/300], Step [400/600], d_loss: 0.0894, g_loss: 0.8046, D(x): 0.91, D(G(z)): 0.12
# Epoch [15/300], Step [600/600], d_loss: 0.1107, g_loss: 0.9404, D(x): 0.87, D(G(z)): 0.09
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.0602, g_loss: 0.9371, D(x): 0.95, D(G(z)): 0.11
# Epoch [16/300], Step [400/600], d_loss: 0.1182, g_loss: 0.8100, D(x): 0.86, D(G(z)): 0.11
# Epoch [16/300], Step [600/600], d_loss: 0.1331, g_loss: 0.8410, D(x): 0.90, D(G(z)): 0.17
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.1589, g_loss: 0.9029, D(x): 0.81, D(G(z)): 0.11
# Epoch [17/300], Step [400/600], d_loss: 0.1614, g_loss: 0.7798, D(x): 0.87, D(G(z)): 0.19
# Epoch [17/300], Step [600/600], d_loss: 0.1696, g_loss: 0.8703, D(x): 0.85, D(G(z)): 0.17
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.2673, g_loss: 0.8749, D(x): 0.70, D(G(z)): 0.12
# Epoch [18/300], Step [400/600], d_loss: 0.0923, g_loss: 0.8562, D(x): 0.88, D(G(z)): 0.12
# Epoch [18/300], Step [600/600], d_loss: 0.3270, g_loss: 0.7408, D(x): 0.73, D(G(z)): 0.22
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.1864, g_loss: 0.7213, D(x): 0.87, D(G(z)): 0.19
# Epoch [19/300], Step [400/600], d_loss: 0.1713, g_loss: 0.8618, D(x): 0.79, D(G(z)): 0.10
# Epoch [19/300], Step [600/600], d_loss: 0.2390, g_loss: 0.8403, D(x): 0.69, D(G(z)): 0.07
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.0950, g_loss: 0.9039, D(x): 0.88, D(G(z)): 0.06
# Epoch [20/300], Step [400/600], d_loss: 0.1413, g_loss: 0.8621, D(x): 0.86, D(G(z)): 0.15
# Epoch [20/300], Step [600/600], d_loss: 0.1662, g_loss: 0.7418, D(x): 0.84, D(G(z)): 0.17
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.1831, g_loss: 0.8498, D(x): 0.80, D(G(z)): 0.16
# Epoch [21/300], Step [400/600], d_loss: 0.1664, g_loss: 0.9307, D(x): 0.76, D(G(z)): 0.04
# Epoch [21/300], Step [600/600], d_loss: 0.1179, g_loss: 0.8860, D(x): 0.87, D(G(z)): 0.12
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.1650, g_loss: 0.9006, D(x): 0.83, D(G(z)): 0.14
# Epoch [22/300], Step [400/600], d_loss: 0.1453, g_loss: 0.8119, D(x): 0.83, D(G(z)): 0.13
# Epoch [22/300], Step [600/600], d_loss: 0.1839, g_loss: 0.9229, D(x): 0.79, D(G(z)): 0.10
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.1442, g_loss: 0.7376, D(x): 0.94, D(G(z)): 0.20
# Epoch [23/300], Step [400/600], d_loss: 0.2029, g_loss: 0.8615, D(x): 0.75, D(G(z)): 0.13
# Epoch [23/300], Step [600/600], d_loss: 0.0553, g_loss: 0.8941, D(x): 0.92, D(G(z)): 0.11
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.1489, g_loss: 0.8430, D(x): 0.81, D(G(z)): 0.10
# Epoch [24/300], Step [400/600], d_loss: 0.1148, g_loss: 0.8722, D(x): 0.95, D(G(z)): 0.19
# Epoch [24/300], Step [600/600], d_loss: 0.0684, g_loss: 0.8146, D(x): 0.91, D(G(z)): 0.12
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.1972, g_loss: 0.8025, D(x): 0.83, D(G(z)): 0.14
# Epoch [25/300], Step [400/600], d_loss: 0.1622, g_loss: 0.7445, D(x): 0.85, D(G(z)): 0.15
# Epoch [25/300], Step [600/600], d_loss: 0.0769, g_loss: 0.7536, D(x): 0.89, D(G(z)): 0.11
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.1641, g_loss: 0.7789, D(x): 0.82, D(G(z)): 0.15
# Epoch [26/300], Step [400/600], d_loss: 0.1388, g_loss: 0.8090, D(x): 0.90, D(G(z)): 0.18
# Epoch [26/300], Step [600/600], d_loss: 0.1969, g_loss: 0.8563, D(x): 0.78, D(G(z)): 0.13
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.1794, g_loss: 0.8490, D(x): 0.83, D(G(z)): 0.19
# Epoch [27/300], Step [400/600], d_loss: 0.1526, g_loss: 0.8815, D(x): 0.80, D(G(z)): 0.12
# Epoch [27/300], Step [600/600], d_loss: 0.1186, g_loss: 0.8434, D(x): 0.85, D(G(z)): 0.10
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.1431, g_loss: 0.8294, D(x): 0.86, D(G(z)): 0.16
# Epoch [28/300], Step [400/600], d_loss: 0.2798, g_loss: 0.7327, D(x): 0.74, D(G(z)): 0.20
# Epoch [28/300], Step [600/600], d_loss: 0.1988, g_loss: 0.7701, D(x): 0.82, D(G(z)): 0.19
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.1517, g_loss: 0.8307, D(x): 0.82, D(G(z)): 0.14
# Epoch [29/300], Step [400/600], d_loss: 0.1325, g_loss: 0.7725, D(x): 0.87, D(G(z)): 0.14
# Epoch [29/300], Step [600/600], d_loss: 0.1916, g_loss: 0.7626, D(x): 0.85, D(G(z)): 0.21
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.1481, g_loss: 0.9005, D(x): 0.80, D(G(z)): 0.10
# Epoch [30/300], Step [400/600], d_loss: 0.3233, g_loss: 0.7048, D(x): 0.65, D(G(z)): 0.21
# Epoch [30/300], Step [600/600], d_loss: 0.1429, g_loss: 0.8506, D(x): 0.80, D(G(z)): 0.09
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.1987, g_loss: 0.8042, D(x): 0.82, D(G(z)): 0.23
# Epoch [31/300], Step [400/600], d_loss: 0.1325, g_loss: 0.7561, D(x): 0.84, D(G(z)): 0.17
# Epoch [31/300], Step [600/600], d_loss: 0.2672, g_loss: 0.5807, D(x): 0.74, D(G(z)): 0.20
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.1972, g_loss: 0.7607, D(x): 0.85, D(G(z)): 0.23
# Epoch [32/300], Step [400/600], d_loss: 0.3090, g_loss: 0.6392, D(x): 0.78, D(G(z)): 0.30
# Epoch [32/300], Step [600/600], d_loss: 0.2461, g_loss: 0.7540, D(x): 0.83, D(G(z)): 0.27
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.1962, g_loss: 0.7341, D(x): 0.83, D(G(z)): 0.23
# Epoch [33/300], Step [400/600], d_loss: 0.2053, g_loss: 0.7185, D(x): 0.90, D(G(z)): 0.26
# Epoch [33/300], Step [600/600], d_loss: 0.2108, g_loss: 0.7600, D(x): 0.84, D(G(z)): 0.26
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.1683, g_loss: 0.7823, D(x): 0.79, D(G(z)): 0.11
# Epoch [34/300], Step [400/600], d_loss: 0.2500, g_loss: 0.7469, D(x): 0.70, D(G(z)): 0.19
# Epoch [34/300], Step [600/600], d_loss: 0.1199, g_loss: 0.8177, D(x): 0.83, D(G(z)): 0.12
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.1828, g_loss: 0.8439, D(x): 0.79, D(G(z)): 0.12
# Epoch [35/300], Step [400/600], d_loss: 0.3397, g_loss: 0.7169, D(x): 0.68, D(G(z)): 0.26
# Epoch [35/300], Step [600/600], d_loss: 0.1190, g_loss: 0.7256, D(x): 0.87, D(G(z)): 0.17
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.1329, g_loss: 0.8055, D(x): 0.79, D(G(z)): 0.09
# Epoch [36/300], Step [400/600], d_loss: 0.1842, g_loss: 0.7585, D(x): 0.81, D(G(z)): 0.21
# Epoch [36/300], Step [600/600], d_loss: 0.2119, g_loss: 0.8308, D(x): 0.79, D(G(z)): 0.19
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.1908, g_loss: 0.6713, D(x): 0.81, D(G(z)): 0.21
# Epoch [37/300], Step [400/600], d_loss: 0.1061, g_loss: 0.7963, D(x): 0.86, D(G(z)): 0.10
# Epoch [37/300], Step [600/600], d_loss: 0.2951, g_loss: 0.6016, D(x): 0.69, D(G(z)): 0.21
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.2088, g_loss: 0.6764, D(x): 0.75, D(G(z)): 0.20
# Epoch [38/300], Step [400/600], d_loss: 0.2084, g_loss: 0.7545, D(x): 0.81, D(G(z)): 0.23
# Epoch [38/300], Step [600/600], d_loss: 0.1818, g_loss: 0.7479, D(x): 0.80, D(G(z)): 0.20
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.1509, g_loss: 0.8557, D(x): 0.82, D(G(z)): 0.14
# Epoch [39/300], Step [400/600], d_loss: 0.2064, g_loss: 0.8805, D(x): 0.77, D(G(z)): 0.14
# Epoch [39/300], Step [600/600], d_loss: 0.1728, g_loss: 0.8493, D(x): 0.81, D(G(z)): 0.15
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.2243, g_loss: 0.7847, D(x): 0.78, D(G(z)): 0.23
# Epoch [40/300], Step [400/600], d_loss: 0.2299, g_loss: 0.7807, D(x): 0.74, D(G(z)): 0.18
# Epoch [40/300], Step [600/600], d_loss: 0.2871, g_loss: 0.5289, D(x): 0.70, D(G(z)): 0.24
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.3267, g_loss: 0.6903, D(x): 0.75, D(G(z)): 0.31
# Epoch [41/300], Step [400/600], d_loss: 0.2283, g_loss: 0.6334, D(x): 0.78, D(G(z)): 0.26
# Epoch [41/300], Step [600/600], d_loss: 0.3635, g_loss: 0.5131, D(x): 0.69, D(G(z)): 0.29
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.2458, g_loss: 0.6149, D(x): 0.79, D(G(z)): 0.29
# Epoch [42/300], Step [400/600], d_loss: 0.2595, g_loss: 0.7340, D(x): 0.83, D(G(z)): 0.29
# Epoch [42/300], Step [600/600], d_loss: 0.2755, g_loss: 0.7380, D(x): 0.74, D(G(z)): 0.27
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.2013, g_loss: 0.8219, D(x): 0.77, D(G(z)): 0.17
# Epoch [43/300], Step [400/600], d_loss: 0.3137, g_loss: 0.6505, D(x): 0.68, D(G(z)): 0.23
# Epoch [43/300], Step [600/600], d_loss: 0.1884, g_loss: 0.7098, D(x): 0.79, D(G(z)): 0.18
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.2118, g_loss: 0.7707, D(x): 0.80, D(G(z)): 0.20
# Epoch [44/300], Step [400/600], d_loss: 0.1470, g_loss: 0.8011, D(x): 0.80, D(G(z)): 0.14
# Epoch [44/300], Step [600/600], d_loss: 0.3331, g_loss: 0.7282, D(x): 0.65, D(G(z)): 0.24
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.1951, g_loss: 0.7335, D(x): 0.79, D(G(z)): 0.18
# Epoch [45/300], Step [400/600], d_loss: 0.3205, g_loss: 0.6774, D(x): 0.71, D(G(z)): 0.27
# Epoch [45/300], Step [600/600], d_loss: 0.2097, g_loss: 0.7604, D(x): 0.79, D(G(z)): 0.22
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.2668, g_loss: 0.6456, D(x): 0.70, D(G(z)): 0.20
# Epoch [46/300], Step [400/600], d_loss: 0.3535, g_loss: 0.6449, D(x): 0.70, D(G(z)): 0.30
# Epoch [46/300], Step [600/600], d_loss: 0.2814, g_loss: 0.6819, D(x): 0.72, D(G(z)): 0.24
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.2208, g_loss: 0.6606, D(x): 0.72, D(G(z)): 0.17
# Epoch [47/300], Step [400/600], d_loss: 0.2074, g_loss: 0.8140, D(x): 0.75, D(G(z)): 0.15
# Epoch [47/300], Step [600/600], d_loss: 0.1186, g_loss: 0.7485, D(x): 0.90, D(G(z)): 0.21
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.3359, g_loss: 0.6616, D(x): 0.81, D(G(z)): 0.39
# Epoch [48/300], Step [400/600], d_loss: 0.2174, g_loss: 0.7428, D(x): 0.75, D(G(z)): 0.18
# Epoch [48/300], Step [600/600], d_loss: 0.3005, g_loss: 0.6648, D(x): 0.70, D(G(z)): 0.25
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.3318, g_loss: 0.5969, D(x): 0.65, D(G(z)): 0.27
# Epoch [49/300], Step [400/600], d_loss: 0.3173, g_loss: 0.5941, D(x): 0.71, D(G(z)): 0.31
# Epoch [49/300], Step [600/600], d_loss: 0.2618, g_loss: 0.8125, D(x): 0.74, D(G(z)): 0.23
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.2828, g_loss: 0.5136, D(x): 0.80, D(G(z)): 0.31
# Epoch [50/300], Step [400/600], d_loss: 0.2153, g_loss: 0.6176, D(x): 0.81, D(G(z)): 0.26
# Epoch [50/300], Step [600/600], d_loss: 0.4097, g_loss: 0.5891, D(x): 0.65, D(G(z)): 0.34
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.2186, g_loss: 0.6946, D(x): 0.75, D(G(z)): 0.22
# Epoch [51/300], Step [400/600], d_loss: 0.1842, g_loss: 0.6787, D(x): 0.78, D(G(z)): 0.21
# Epoch [51/300], Step [600/600], d_loss: 0.2799, g_loss: 0.6347, D(x): 0.70, D(G(z)): 0.25
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.3144, g_loss: 0.5751, D(x): 0.75, D(G(z)): 0.34
# Epoch [52/300], Step [400/600], d_loss: 0.2461, g_loss: 0.6646, D(x): 0.77, D(G(z)): 0.26
# Epoch [52/300], Step [600/600], d_loss: 0.1992, g_loss: 0.6948, D(x): 0.77, D(G(z)): 0.20
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.2448, g_loss: 0.6834, D(x): 0.73, D(G(z)): 0.25
# Epoch [53/300], Step [400/600], d_loss: 0.2859, g_loss: 0.6074, D(x): 0.72, D(G(z)): 0.24
# Epoch [53/300], Step [600/600], d_loss: 0.2581, g_loss: 0.6020, D(x): 0.73, D(G(z)): 0.26
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.3133, g_loss: 0.7316, D(x): 0.60, D(G(z)): 0.18
# Epoch [54/300], Step [400/600], d_loss: 0.4121, g_loss: 0.5625, D(x): 0.65, D(G(z)): 0.35
# Epoch [54/300], Step [600/600], d_loss: 0.2498, g_loss: 0.7688, D(x): 0.72, D(G(z)): 0.22
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.1753, g_loss: 0.7695, D(x): 0.79, D(G(z)): 0.17
# Epoch [55/300], Step [400/600], d_loss: 0.2115, g_loss: 0.7510, D(x): 0.79, D(G(z)): 0.24
# Epoch [55/300], Step [600/600], d_loss: 0.2071, g_loss: 0.6369, D(x): 0.75, D(G(z)): 0.25
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.4138, g_loss: 0.5545, D(x): 0.65, D(G(z)): 0.38
# Epoch [56/300], Step [400/600], d_loss: 0.3902, g_loss: 0.6211, D(x): 0.62, D(G(z)): 0.30
# Epoch [56/300], Step [600/600], d_loss: 0.3617, g_loss: 0.5625, D(x): 0.71, D(G(z)): 0.37
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.2327, g_loss: 0.6700, D(x): 0.77, D(G(z)): 0.28
# Epoch [57/300], Step [400/600], d_loss: 0.2002, g_loss: 0.6734, D(x): 0.74, D(G(z)): 0.20
# Epoch [57/300], Step [600/600], d_loss: 0.1624, g_loss: 0.6841, D(x): 0.81, D(G(z)): 0.23
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.2408, g_loss: 0.6516, D(x): 0.71, D(G(z)): 0.20
# Epoch [58/300], Step [400/600], d_loss: 0.3277, g_loss: 0.5582, D(x): 0.70, D(G(z)): 0.30
# Epoch [58/300], Step [600/600], d_loss: 0.3622, g_loss: 0.5779, D(x): 0.66, D(G(z)): 0.31
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 0.3262, g_loss: 0.4630, D(x): 0.70, D(G(z)): 0.33
# Epoch [59/300], Step [400/600], d_loss: 0.2074, g_loss: 0.6407, D(x): 0.74, D(G(z)): 0.20
# Epoch [59/300], Step [600/600], d_loss: 0.2959, g_loss: 0.5963, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.2646, g_loss: 0.7249, D(x): 0.70, D(G(z)): 0.20
# Epoch [60/300], Step [400/600], d_loss: 0.3558, g_loss: 0.7095, D(x): 0.64, D(G(z)): 0.27
# Epoch [60/300], Step [600/600], d_loss: 0.2805, g_loss: 0.6050, D(x): 0.76, D(G(z)): 0.31
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.2811, g_loss: 0.7325, D(x): 0.70, D(G(z)): 0.24
# Epoch [61/300], Step [400/600], d_loss: 0.3993, g_loss: 0.6931, D(x): 0.61, D(G(z)): 0.29
# Epoch [61/300], Step [600/600], d_loss: 0.3209, g_loss: 0.5889, D(x): 0.85, D(G(z)): 0.45
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.3134, g_loss: 0.5358, D(x): 0.70, D(G(z)): 0.29
# Epoch [62/300], Step [400/600], d_loss: 0.3430, g_loss: 0.6768, D(x): 0.66, D(G(z)): 0.28
# Epoch [62/300], Step [600/600], d_loss: 0.2331, g_loss: 0.6958, D(x): 0.70, D(G(z)): 0.21
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.3154, g_loss: 0.6240, D(x): 0.73, D(G(z)): 0.34
# Epoch [63/300], Step [400/600], d_loss: 0.2319, g_loss: 0.6560, D(x): 0.71, D(G(z)): 0.22
# Epoch [63/300], Step [600/600], d_loss: 0.3054, g_loss: 0.5540, D(x): 0.72, D(G(z)): 0.33
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.2974, g_loss: 0.6295, D(x): 0.69, D(G(z)): 0.27
# Epoch [64/300], Step [400/600], d_loss: 0.2738, g_loss: 0.5822, D(x): 0.74, D(G(z)): 0.31
# Epoch [64/300], Step [600/600], d_loss: 0.2357, g_loss: 0.6214, D(x): 0.79, D(G(z)): 0.31
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 0.2738, g_loss: 0.6713, D(x): 0.71, D(G(z)): 0.27
# Epoch [65/300], Step [400/600], d_loss: 0.3665, g_loss: 0.5898, D(x): 0.62, D(G(z)): 0.26
# Epoch [65/300], Step [600/600], d_loss: 0.2835, g_loss: 0.7074, D(x): 0.67, D(G(z)): 0.19
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.2553, g_loss: 0.6918, D(x): 0.72, D(G(z)): 0.27
# Epoch [66/300], Step [400/600], d_loss: 0.3323, g_loss: 0.5747, D(x): 0.59, D(G(z)): 0.22
# Epoch [66/300], Step [600/600], d_loss: 0.3704, g_loss: 0.5808, D(x): 0.66, D(G(z)): 0.34
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.3698, g_loss: 0.7059, D(x): 0.60, D(G(z)): 0.25
# Epoch [67/300], Step [400/600], d_loss: 0.2465, g_loss: 0.6628, D(x): 0.78, D(G(z)): 0.30
# Epoch [67/300], Step [600/600], d_loss: 0.3512, g_loss: 0.3969, D(x): 0.74, D(G(z)): 0.40
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.2686, g_loss: 0.5258, D(x): 0.79, D(G(z)): 0.33
# Epoch [68/300], Step [400/600], d_loss: 0.4278, g_loss: 0.5860, D(x): 0.66, D(G(z)): 0.40
# Epoch [68/300], Step [600/600], d_loss: 0.4646, g_loss: 0.5424, D(x): 0.56, D(G(z)): 0.33
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 0.2520, g_loss: 0.7428, D(x): 0.74, D(G(z)): 0.24
# Epoch [69/300], Step [400/600], d_loss: 0.3903, g_loss: 0.5039, D(x): 0.67, D(G(z)): 0.38
# Epoch [69/300], Step [600/600], d_loss: 0.2663, g_loss: 0.7101, D(x): 0.70, D(G(z)): 0.25
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 0.1582, g_loss: 0.6844, D(x): 0.80, D(G(z)): 0.21
# Epoch [70/300], Step [400/600], d_loss: 0.2694, g_loss: 0.5597, D(x): 0.77, D(G(z)): 0.33
# Epoch [70/300], Step [600/600], d_loss: 0.2907, g_loss: 0.5245, D(x): 0.75, D(G(z)): 0.31
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.3111, g_loss: 0.5616, D(x): 0.64, D(G(z)): 0.27
# Epoch [71/300], Step [400/600], d_loss: 0.1859, g_loss: 0.6948, D(x): 0.74, D(G(z)): 0.20
# Epoch [71/300], Step [600/600], d_loss: 0.2208, g_loss: 0.6167, D(x): 0.82, D(G(z)): 0.30
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.3965, g_loss: 0.5789, D(x): 0.63, D(G(z)): 0.37
# Epoch [72/300], Step [400/600], d_loss: 0.2553, g_loss: 0.6696, D(x): 0.77, D(G(z)): 0.31
# Epoch [72/300], Step [600/600], d_loss: 0.2922, g_loss: 0.6525, D(x): 0.71, D(G(z)): 0.27
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.3511, g_loss: 0.6446, D(x): 0.63, D(G(z)): 0.29
# Epoch [73/300], Step [400/600], d_loss: 0.3544, g_loss: 0.5568, D(x): 0.65, D(G(z)): 0.31
# Epoch [73/300], Step [600/600], d_loss: 0.4164, g_loss: 0.5152, D(x): 0.64, D(G(z)): 0.35
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.3625, g_loss: 0.6395, D(x): 0.66, D(G(z)): 0.31
# Epoch [74/300], Step [400/600], d_loss: 0.3455, g_loss: 0.5737, D(x): 0.69, D(G(z)): 0.34
# Epoch [74/300], Step [600/600], d_loss: 0.2846, g_loss: 0.5777, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 0.5433, g_loss: 0.5042, D(x): 0.63, D(G(z)): 0.49
# Epoch [75/300], Step [400/600], d_loss: 0.3087, g_loss: 0.5931, D(x): 0.63, D(G(z)): 0.24
# Epoch [75/300], Step [600/600], d_loss: 0.2592, g_loss: 0.6713, D(x): 0.71, D(G(z)): 0.25
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.4582, g_loss: 0.5547, D(x): 0.55, D(G(z)): 0.31
# Epoch [76/300], Step [400/600], d_loss: 0.2302, g_loss: 0.7116, D(x): 0.76, D(G(z)): 0.26
# Epoch [76/300], Step [600/600], d_loss: 0.2959, g_loss: 0.5554, D(x): 0.73, D(G(z)): 0.34
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.2869, g_loss: 0.6639, D(x): 0.71, D(G(z)): 0.31
# Epoch [77/300], Step [400/600], d_loss: 0.2969, g_loss: 0.5518, D(x): 0.76, D(G(z)): 0.33
# Epoch [77/300], Step [600/600], d_loss: 0.3170, g_loss: 0.5686, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.2492, g_loss: 0.6914, D(x): 0.74, D(G(z)): 0.24
# Epoch [78/300], Step [400/600], d_loss: 0.3823, g_loss: 0.6198, D(x): 0.59, D(G(z)): 0.29
# Epoch [78/300], Step [600/600], d_loss: 0.2565, g_loss: 0.6208, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 0.2535, g_loss: 0.6064, D(x): 0.72, D(G(z)): 0.26
# Epoch [79/300], Step [400/600], d_loss: 0.3758, g_loss: 0.4006, D(x): 0.66, D(G(z)): 0.37
# Epoch [79/300], Step [600/600], d_loss: 0.4033, g_loss: 0.6256, D(x): 0.56, D(G(z)): 0.26
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 0.4063, g_loss: 0.5363, D(x): 0.61, D(G(z)): 0.33
# Epoch [80/300], Step [400/600], d_loss: 0.2953, g_loss: 0.6456, D(x): 0.80, D(G(z)): 0.37
# Epoch [80/300], Step [600/600], d_loss: 0.2808, g_loss: 0.6115, D(x): 0.71, D(G(z)): 0.29
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 0.1857, g_loss: 0.6313, D(x): 0.79, D(G(z)): 0.21
# Epoch [81/300], Step [400/600], d_loss: 0.2535, g_loss: 0.4995, D(x): 0.78, D(G(z)): 0.31
# Epoch [81/300], Step [600/600], d_loss: 0.4124, g_loss: 0.5307, D(x): 0.61, D(G(z)): 0.37
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 0.3224, g_loss: 0.6715, D(x): 0.64, D(G(z)): 0.25
# Epoch [82/300], Step [400/600], d_loss: 0.2805, g_loss: 0.6834, D(x): 0.77, D(G(z)): 0.30
# Epoch [82/300], Step [600/600], d_loss: 0.4519, g_loss: 0.4806, D(x): 0.55, D(G(z)): 0.35
# Saving fake_images-0083.png
# Epoch [83/300], Step [200/600], d_loss: 0.3251, g_loss: 0.6159, D(x): 0.64, D(G(z)): 0.28
# Epoch [83/300], Step [400/600], d_loss: 0.2738, g_loss: 0.6100, D(x): 0.76, D(G(z)): 0.32
# Epoch [83/300], Step [600/600], d_loss: 0.2917, g_loss: 0.5555, D(x): 0.69, D(G(z)): 0.31
# Saving fake_images-0084.png
# Epoch [84/300], Step [200/600], d_loss: 0.3368, g_loss: 0.5666, D(x): 0.67, D(G(z)): 0.30
# Epoch [84/300], Step [400/600], d_loss: 0.3050, g_loss: 0.5991, D(x): 0.70, D(G(z)): 0.27
# Epoch [84/300], Step [600/600], d_loss: 0.3645, g_loss: 0.4933, D(x): 0.71, D(G(z)): 0.40
# Saving fake_images-0085.png
# Epoch [85/300], Step [200/600], d_loss: 0.3403, g_loss: 0.4966, D(x): 0.63, D(G(z)): 0.27
# Epoch [85/300], Step [400/600], d_loss: 0.4670, g_loss: 0.5200, D(x): 0.60, D(G(z)): 0.36
# Epoch [85/300], Step [600/600], d_loss: 0.3849, g_loss: 0.5027, D(x): 0.68, D(G(z)): 0.35
# Saving fake_images-0086.png
# Epoch [86/300], Step [200/600], d_loss: 0.3647, g_loss: 0.6048, D(x): 0.64, D(G(z)): 0.30
# Epoch [86/300], Step [400/600], d_loss: 0.3138, g_loss: 0.6545, D(x): 0.62, D(G(z)): 0.22
# Epoch [86/300], Step [600/600], d_loss: 0.4806, g_loss: 0.4994, D(x): 0.56, D(G(z)): 0.35
# Saving fake_images-0087.png
# Epoch [87/300], Step [200/600], d_loss: 0.2544, g_loss: 0.6238, D(x): 0.73, D(G(z)): 0.31
# Epoch [87/300], Step [400/600], d_loss: 0.3826, g_loss: 0.5669, D(x): 0.58, D(G(z)): 0.28
# Epoch [87/300], Step [600/600], d_loss: 0.3623, g_loss: 0.5228, D(x): 0.66, D(G(z)): 0.32
# Saving fake_images-0088.png
# Epoch [88/300], Step [200/600], d_loss: 0.4144, g_loss: 0.5177, D(x): 0.65, D(G(z)): 0.38
# Epoch [88/300], Step [400/600], d_loss: 0.3524, g_loss: 0.4983, D(x): 0.68, D(G(z)): 0.37
# Epoch [88/300], Step [600/600], d_loss: 0.3406, g_loss: 0.5355, D(x): 0.76, D(G(z)): 0.41
# Saving fake_images-0089.png
# Epoch [89/300], Step [200/600], d_loss: 0.4063, g_loss: 0.3969, D(x): 0.69, D(G(z)): 0.41
# Epoch [89/300], Step [400/600], d_loss: 0.2656, g_loss: 0.6549, D(x): 0.76, D(G(z)): 0.28
# Epoch [89/300], Step [600/600], d_loss: 0.3137, g_loss: 0.6055, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0090.png
# Epoch [90/300], Step [200/600], d_loss: 0.2706, g_loss: 0.5815, D(x): 0.70, D(G(z)): 0.29
# Epoch [90/300], Step [400/600], d_loss: 0.4270, g_loss: 0.5624, D(x): 0.54, D(G(z)): 0.27
# Epoch [90/300], Step [600/600], d_loss: 0.4037, g_loss: 0.5906, D(x): 0.54, D(G(z)): 0.28
# Saving fake_images-0091.png
# Epoch [91/300], Step [200/600], d_loss: 0.3922, g_loss: 0.5385, D(x): 0.63, D(G(z)): 0.35
# Epoch [91/300], Step [400/600], d_loss: 0.1741, g_loss: 0.6929, D(x): 0.81, D(G(z)): 0.27
# Epoch [91/300], Step [600/600], d_loss: 0.3873, g_loss: 0.6337, D(x): 0.66, D(G(z)): 0.36
# Saving fake_images-0092.png
# Epoch [92/300], Step [200/600], d_loss: 0.3685, g_loss: 0.5811, D(x): 0.63, D(G(z)): 0.32
# Epoch [92/300], Step [400/600], d_loss: 0.4048, g_loss: 0.5475, D(x): 0.57, D(G(z)): 0.30
# Epoch [92/300], Step [600/600], d_loss: 0.4290, g_loss: 0.4156, D(x): 0.64, D(G(z)): 0.41
# Saving fake_images-0093.png
# Epoch [93/300], Step [200/600], d_loss: 0.2690, g_loss: 0.6324, D(x): 0.76, D(G(z)): 0.31
# Epoch [93/300], Step [400/600], d_loss: 0.2732, g_loss: 0.6001, D(x): 0.70, D(G(z)): 0.27
# Epoch [93/300], Step [600/600], d_loss: 0.3045, g_loss: 0.6109, D(x): 0.70, D(G(z)): 0.31
# Saving fake_images-0094.png
# Epoch [94/300], Step [200/600], d_loss: 0.3478, g_loss: 0.4856, D(x): 0.71, D(G(z)): 0.38
# Epoch [94/300], Step [400/600], d_loss: 0.4732, g_loss: 0.4282, D(x): 0.63, D(G(z)): 0.44
# Epoch [94/300], Step [600/600], d_loss: 0.3721, g_loss: 0.5362, D(x): 0.60, D(G(z)): 0.29
# Saving fake_images-0095.png
# Epoch [95/300], Step [200/600], d_loss: 0.4152, g_loss: 0.4777, D(x): 0.61, D(G(z)): 0.36
# Epoch [95/300], Step [400/600], d_loss: 0.5547, g_loss: 0.4003, D(x): 0.65, D(G(z)): 0.51
# Epoch [95/300], Step [600/600], d_loss: 0.3089, g_loss: 0.5856, D(x): 0.65, D(G(z)): 0.27
# Saving fake_images-0096.png
# Epoch [96/300], Step [200/600], d_loss: 0.1994, g_loss: 0.7363, D(x): 0.79, D(G(z)): 0.24
# Epoch [96/300], Step [400/600], d_loss: 0.4606, g_loss: 0.6071, D(x): 0.52, D(G(z)): 0.30
# Epoch [96/300], Step [600/600], d_loss: 0.4744, g_loss: 0.3810, D(x): 0.62, D(G(z)): 0.44
# Saving fake_images-0097.png
# Epoch [97/300], Step [200/600], d_loss: 0.3300, g_loss: 0.6394, D(x): 0.66, D(G(z)): 0.30
# Epoch [97/300], Step [400/600], d_loss: 0.2887, g_loss: 0.6660, D(x): 0.64, D(G(z)): 0.23
# Epoch [97/300], Step [600/600], d_loss: 0.4008, g_loss: 0.6252, D(x): 0.69, D(G(z)): 0.42
# Saving fake_images-0098.png
# Epoch [98/300], Step [200/600], d_loss: 0.3226, g_loss: 0.6720, D(x): 0.69, D(G(z)): 0.28
# Epoch [98/300], Step [400/600], d_loss: 0.3246, g_loss: 0.4974, D(x): 0.61, D(G(z)): 0.25
# Epoch [98/300], Step [600/600], d_loss: 0.2927, g_loss: 0.5831, D(x): 0.64, D(G(z)): 0.25
# Saving fake_images-0099.png
# Epoch [99/300], Step [200/600], d_loss: 0.3747, g_loss: 0.4896, D(x): 0.61, D(G(z)): 0.32
# Epoch [99/300], Step [400/600], d_loss: 0.2830, g_loss: 0.5704, D(x): 0.75, D(G(z)): 0.35
# Epoch [99/300], Step [600/600], d_loss: 0.2065, g_loss: 0.6765, D(x): 0.75, D(G(z)): 0.22
# Saving fake_images-0100.png
# Epoch [100/300], Step [200/600], d_loss: 0.2728, g_loss: 0.6746, D(x): 0.66, D(G(z)): 0.21
# Epoch [100/300], Step [400/600], d_loss: 0.2646, g_loss: 0.6338, D(x): 0.74, D(G(z)): 0.26
# Epoch [100/300], Step [600/600], d_loss: 0.2549, g_loss: 0.5730, D(x): 0.80, D(G(z)): 0.30
# Saving fake_images-0101.png
# Epoch [101/300], Step [200/600], d_loss: 0.3328, g_loss: 0.5736, D(x): 0.61, D(G(z)): 0.25
# Epoch [101/300], Step [400/600], d_loss: 0.3941, g_loss: 0.3890, D(x): 0.69, D(G(z)): 0.44
# Epoch [101/300], Step [600/600], d_loss: 0.4352, g_loss: 0.5438, D(x): 0.64, D(G(z)): 0.38
# Saving fake_images-0102.png
# Epoch [102/300], Step [200/600], d_loss: 0.5453, g_loss: 0.4922, D(x): 0.63, D(G(z)): 0.49
# Epoch [102/300], Step [400/600], d_loss: 0.3130, g_loss: 0.4369, D(x): 0.65, D(G(z)): 0.31
# Epoch [102/300], Step [600/600], d_loss: 0.2978, g_loss: 0.5210, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0103.png
# Epoch [103/300], Step [200/600], d_loss: 0.4312, g_loss: 0.5264, D(x): 0.58, D(G(z)): 0.34
# Epoch [103/300], Step [400/600], d_loss: 0.3853, g_loss: 0.5700, D(x): 0.60, D(G(z)): 0.32
# Epoch [103/300], Step [600/600], d_loss: 0.2539, g_loss: 0.5821, D(x): 0.71, D(G(z)): 0.26
# Saving fake_images-0104.png
# Epoch [104/300], Step [200/600], d_loss: 0.3469, g_loss: 0.5834, D(x): 0.64, D(G(z)): 0.31
# Epoch [104/300], Step [400/600], d_loss: 0.3232, g_loss: 0.4842, D(x): 0.67, D(G(z)): 0.33
# Epoch [104/300], Step [600/600], d_loss: 0.4337, g_loss: 0.5016, D(x): 0.59, D(G(z)): 0.36
# Saving fake_images-0105.png
# Epoch [105/300], Step [200/600], d_loss: 0.3068, g_loss: 0.5992, D(x): 0.67, D(G(z)): 0.28
# Epoch [105/300], Step [400/600], d_loss: 0.2780, g_loss: 0.4518, D(x): 0.75, D(G(z)): 0.35
# Epoch [105/300], Step [600/600], d_loss: 0.3379, g_loss: 0.6309, D(x): 0.60, D(G(z)): 0.27
# Saving fake_images-0106.png
# Epoch [106/300], Step [200/600], d_loss: 0.3402, g_loss: 0.5464, D(x): 0.64, D(G(z)): 0.32
# Epoch [106/300], Step [400/600], d_loss: 0.3228, g_loss: 0.5250, D(x): 0.69, D(G(z)): 0.33
# Epoch [106/300], Step [600/600], d_loss: 0.4430, g_loss: 0.5521, D(x): 0.53, D(G(z)): 0.32
# Saving fake_images-0107.png
# Epoch [107/300], Step [200/600], d_loss: 0.3151, g_loss: 0.5682, D(x): 0.64, D(G(z)): 0.26
# Epoch [107/300], Step [400/600], d_loss: 0.5715, g_loss: 0.4665, D(x): 0.57, D(G(z)): 0.47
# Epoch [107/300], Step [600/600], d_loss: 0.3962, g_loss: 0.4958, D(x): 0.62, D(G(z)): 0.35
# Saving fake_images-0108.png
# Epoch [108/300], Step [200/600], d_loss: 0.2690, g_loss: 0.5119, D(x): 0.66, D(G(z)): 0.23
# Epoch [108/300], Step [400/600], d_loss: 0.5314, g_loss: 0.5493, D(x): 0.56, D(G(z)): 0.45
# Epoch [108/300], Step [600/600], d_loss: 0.2643, g_loss: 0.7122, D(x): 0.71, D(G(z)): 0.26
# Saving fake_images-0109.png
# Epoch [109/300], Step [200/600], d_loss: 0.3063, g_loss: 0.4607, D(x): 0.70, D(G(z)): 0.32
# Epoch [109/300], Step [400/600], d_loss: 0.3071, g_loss: 0.4784, D(x): 0.72, D(G(z)): 0.34
# Epoch [109/300], Step [600/600], d_loss: 0.2950, g_loss: 0.6326, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0110.png
# Epoch [110/300], Step [200/600], d_loss: 0.2074, g_loss: 0.6400, D(x): 0.71, D(G(z)): 0.19
# Epoch [110/300], Step [400/600], d_loss: 0.4015, g_loss: 0.5293, D(x): 0.60, D(G(z)): 0.32
# Epoch [110/300], Step [600/600], d_loss: 0.3418, g_loss: 0.5137, D(x): 0.66, D(G(z)): 0.34
# Saving fake_images-0111.png
# Epoch [111/300], Step [200/600], d_loss: 0.2971, g_loss: 0.5630, D(x): 0.67, D(G(z)): 0.29
# Epoch [111/300], Step [400/600], d_loss: 0.4185, g_loss: 0.5352, D(x): 0.64, D(G(z)): 0.39
# Epoch [111/300], Step [600/600], d_loss: 0.3149, g_loss: 0.5754, D(x): 0.65, D(G(z)): 0.29
# Saving fake_images-0112.png
# Epoch [112/300], Step [200/600], d_loss: 0.4975, g_loss: 0.4394, D(x): 0.57, D(G(z)): 0.42
# Epoch [112/300], Step [400/600], d_loss: 0.3582, g_loss: 0.4865, D(x): 0.69, D(G(z)): 0.36
# Epoch [112/300], Step [600/600], d_loss: 0.3591, g_loss: 0.4534, D(x): 0.69, D(G(z)): 0.39
# Saving fake_images-0113.png
# Epoch [113/300], Step [200/600], d_loss: 0.2859, g_loss: 0.5382, D(x): 0.69, D(G(z)): 0.31
# Epoch [113/300], Step [400/600], d_loss: 0.3256, g_loss: 0.3866, D(x): 0.67, D(G(z)): 0.33
# Epoch [113/300], Step [600/600], d_loss: 0.4837, g_loss: 0.4176, D(x): 0.62, D(G(z)): 0.43
# Saving fake_images-0114.png
# Epoch [114/300], Step [200/600], d_loss: 0.3326, g_loss: 0.4740, D(x): 0.69, D(G(z)): 0.36
# Epoch [114/300], Step [400/600], d_loss: 0.3382, g_loss: 0.5549, D(x): 0.64, D(G(z)): 0.30
# Epoch [114/300], Step [600/600], d_loss: 0.3174, g_loss: 0.6413, D(x): 0.68, D(G(z)): 0.29
# Saving fake_images-0115.png
# Epoch [115/300], Step [200/600], d_loss: 0.4397, g_loss: 0.4880, D(x): 0.57, D(G(z)): 0.34
# Epoch [115/300], Step [400/600], d_loss: 0.3649, g_loss: 0.4470, D(x): 0.70, D(G(z)): 0.42
# Epoch [115/300], Step [600/600], d_loss: 0.3338, g_loss: 0.5877, D(x): 0.60, D(G(z)): 0.28
# Saving fake_images-0116.png
# Epoch [116/300], Step [200/600], d_loss: 0.4904, g_loss: 0.5679, D(x): 0.50, D(G(z)): 0.33
# Epoch [116/300], Step [400/600], d_loss: 0.2974, g_loss: 0.5671, D(x): 0.67, D(G(z)): 0.29
# Epoch [116/300], Step [600/600], d_loss: 0.3531, g_loss: 0.4991, D(x): 0.69, D(G(z)): 0.37
# Saving fake_images-0117.png
# Epoch [117/300], Step [200/600], d_loss: 0.4064, g_loss: 0.4642, D(x): 0.63, D(G(z)): 0.38
# Epoch [117/300], Step [400/600], d_loss: 0.3600, g_loss: 0.5264, D(x): 0.65, D(G(z)): 0.32
# Epoch [117/300], Step [600/600], d_loss: 0.3493, g_loss: 0.6295, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0118.png
# Epoch [118/300], Step [200/600], d_loss: 0.2022, g_loss: 0.5908, D(x): 0.77, D(G(z)): 0.28
# Epoch [118/300], Step [400/600], d_loss: 0.2612, g_loss: 0.5720, D(x): 0.73, D(G(z)): 0.29
# Epoch [118/300], Step [600/600], d_loss: 0.3953, g_loss: 0.5099, D(x): 0.65, D(G(z)): 0.38
# Saving fake_images-0119.png
# Epoch [119/300], Step [200/600], d_loss: 0.3572, g_loss: 0.4917, D(x): 0.63, D(G(z)): 0.33
# Epoch [119/300], Step [400/600], d_loss: 0.4957, g_loss: 0.3568, D(x): 0.63, D(G(z)): 0.45
# Epoch [119/300], Step [600/600], d_loss: 0.5345, g_loss: 0.4168, D(x): 0.52, D(G(z)): 0.41
# Saving fake_images-0120.png
# Epoch [120/300], Step [200/600], d_loss: 0.5584, g_loss: 0.3571, D(x): 0.61, D(G(z)): 0.52
# Epoch [120/300], Step [400/600], d_loss: 0.3832, g_loss: 0.4822, D(x): 0.64, D(G(z)): 0.36
# Epoch [120/300], Step [600/600], d_loss: 0.2498, g_loss: 0.4900, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0121.png
# Epoch [121/300], Step [200/600], d_loss: 0.5022, g_loss: 0.3239, D(x): 0.58, D(G(z)): 0.41
# Epoch [121/300], Step [400/600], d_loss: 0.3376, g_loss: 0.4798, D(x): 0.71, D(G(z)): 0.38
# Epoch [121/300], Step [600/600], d_loss: 0.2640, g_loss: 0.5601, D(x): 0.68, D(G(z)): 0.27
# Saving fake_images-0122.png
# Epoch [122/300], Step [200/600], d_loss: 0.1772, g_loss: 0.6659, D(x): 0.76, D(G(z)): 0.20
# Epoch [122/300], Step [400/600], d_loss: 0.3529, g_loss: 0.5105, D(x): 0.72, D(G(z)): 0.39
# Epoch [122/300], Step [600/600], d_loss: 0.3661, g_loss: 0.5064, D(x): 0.62, D(G(z)): 0.29
# Saving fake_images-0123.png
# Epoch [123/300], Step [200/600], d_loss: 0.3448, g_loss: 0.4596, D(x): 0.63, D(G(z)): 0.32
# Epoch [123/300], Step [400/600], d_loss: 0.3787, g_loss: 0.5436, D(x): 0.65, D(G(z)): 0.36
# Epoch [123/300], Step [600/600], d_loss: 0.4342, g_loss: 0.5058, D(x): 0.63, D(G(z)): 0.38
# Saving fake_images-0124.png
# Epoch [124/300], Step [200/600], d_loss: 0.4319, g_loss: 0.5683, D(x): 0.59, D(G(z)): 0.36
# Epoch [124/300], Step [400/600], d_loss: 0.3281, g_loss: 0.4739, D(x): 0.65, D(G(z)): 0.30
# Epoch [124/300], Step [600/600], d_loss: 0.4464, g_loss: 0.4177, D(x): 0.59, D(G(z)): 0.40
# Saving fake_images-0125.png
# Epoch [125/300], Step [200/600], d_loss: 0.2969, g_loss: 0.6536, D(x): 0.70, D(G(z)): 0.31
# Epoch [125/300], Step [400/600], d_loss: 0.3317, g_loss: 0.5136, D(x): 0.66, D(G(z)): 0.32
# Epoch [125/300], Step [600/600], d_loss: 0.3604, g_loss: 0.4949, D(x): 0.64, D(G(z)): 0.31
# Saving fake_images-0126.png
# Epoch [126/300], Step [200/600], d_loss: 0.2130, g_loss: 0.5897, D(x): 0.75, D(G(z)): 0.27
# Epoch [126/300], Step [400/600], d_loss: 0.4538, g_loss: 0.4088, D(x): 0.53, D(G(z)): 0.34
# Epoch [126/300], Step [600/600], d_loss: 0.4189, g_loss: 0.5088, D(x): 0.62, D(G(z)): 0.39
# Saving fake_images-0127.png
# Epoch [127/300], Step [200/600], d_loss: 0.3066, g_loss: 0.5819, D(x): 0.68, D(G(z)): 0.32
# Epoch [127/300], Step [400/600], d_loss: 0.4495, g_loss: 0.5616, D(x): 0.55, D(G(z)): 0.33
# Epoch [127/300], Step [600/600], d_loss: 0.3825, g_loss: 0.3977, D(x): 0.64, D(G(z)): 0.38
# Saving fake_images-0128.png
# Epoch [128/300], Step [200/600], d_loss: 0.2299, g_loss: 0.5881, D(x): 0.77, D(G(z)): 0.29
# Epoch [128/300], Step [400/600], d_loss: 0.4447, g_loss: 0.4389, D(x): 0.62, D(G(z)): 0.42
# Epoch [128/300], Step [600/600], d_loss: 0.4618, g_loss: 0.4529, D(x): 0.55, D(G(z)): 0.36
# Saving fake_images-0129.png
# Epoch [129/300], Step [200/600], d_loss: 0.3029, g_loss: 0.5167, D(x): 0.68, D(G(z)): 0.32
# Epoch [129/300], Step [400/600], d_loss: 0.4104, g_loss: 0.3983, D(x): 0.69, D(G(z)): 0.43
# Epoch [129/300], Step [600/600], d_loss: 0.4725, g_loss: 0.4091, D(x): 0.56, D(G(z)): 0.38
# Saving fake_images-0130.png
# Epoch [130/300], Step [200/600], d_loss: 0.4833, g_loss: 0.3779, D(x): 0.54, D(G(z)): 0.39
# Epoch [130/300], Step [400/600], d_loss: 0.4085, g_loss: 0.4890, D(x): 0.63, D(G(z)): 0.39
# Epoch [130/300], Step [600/600], d_loss: 0.4191, g_loss: 0.4242, D(x): 0.59, D(G(z)): 0.36
# Saving fake_images-0131.png
# Epoch [131/300], Step [200/600], d_loss: 0.3747, g_loss: 0.4557, D(x): 0.69, D(G(z)): 0.43
# Epoch [131/300], Step [400/600], d_loss: 0.4135, g_loss: 0.3817, D(x): 0.74, D(G(z)): 0.49
# Epoch [131/300], Step [600/600], d_loss: 0.3447, g_loss: 0.5011, D(x): 0.59, D(G(z)): 0.28
# Saving fake_images-0132.png
# Epoch [132/300], Step [200/600], d_loss: 0.3353, g_loss: 0.5537, D(x): 0.63, D(G(z)): 0.29
# Epoch [132/300], Step [400/600], d_loss: 0.3734, g_loss: 0.4944, D(x): 0.69, D(G(z)): 0.38
# Epoch [132/300], Step [600/600], d_loss: 0.4020, g_loss: 0.4898, D(x): 0.68, D(G(z)): 0.39
# Saving fake_images-0133.png
# Epoch [133/300], Step [200/600], d_loss: 0.3551, g_loss: 0.4412, D(x): 0.64, D(G(z)): 0.34
# Epoch [133/300], Step [400/600], d_loss: 0.3140, g_loss: 0.5997, D(x): 0.64, D(G(z)): 0.28
# Epoch [133/300], Step [600/600], d_loss: 0.5713, g_loss: 0.5274, D(x): 0.48, D(G(z)): 0.40
# Saving fake_images-0134.png
# Epoch [134/300], Step [200/600], d_loss: 0.3443, g_loss: 0.4537, D(x): 0.66, D(G(z)): 0.34
# Epoch [134/300], Step [400/600], d_loss: 0.3543, g_loss: 0.5206, D(x): 0.68, D(G(z)): 0.36
# Epoch [134/300], Step [600/600], d_loss: 0.4141, g_loss: 0.4892, D(x): 0.64, D(G(z)): 0.39
# Saving fake_images-0135.png
# Epoch [135/300], Step [200/600], d_loss: 0.4386, g_loss: 0.5448, D(x): 0.61, D(G(z)): 0.41
# Epoch [135/300], Step [400/600], d_loss: 0.3075, g_loss: 0.4892, D(x): 0.69, D(G(z)): 0.33
# Epoch [135/300], Step [600/600], d_loss: 0.4453, g_loss: 0.3540, D(x): 0.65, D(G(z)): 0.43
# Saving fake_images-0136.png
# Epoch [136/300], Step [200/600], d_loss: 0.4779, g_loss: 0.4082, D(x): 0.59, D(G(z)): 0.41
# Epoch [136/300], Step [400/600], d_loss: 0.3664, g_loss: 0.4351, D(x): 0.72, D(G(z)): 0.44
# Epoch [136/300], Step [600/600], d_loss: 0.3764, g_loss: 0.5476, D(x): 0.58, D(G(z)): 0.30
# Saving fake_images-0137.png
# Epoch [137/300], Step [200/600], d_loss: 0.3777, g_loss: 0.4049, D(x): 0.69, D(G(z)): 0.44
# Epoch [137/300], Step [400/600], d_loss: 0.3572, g_loss: 0.5379, D(x): 0.63, D(G(z)): 0.34
# Epoch [137/300], Step [600/600], d_loss: 0.2611, g_loss: 0.5408, D(x): 0.78, D(G(z)): 0.36
# Saving fake_images-0138.png
# Epoch [138/300], Step [200/600], d_loss: 0.2605, g_loss: 0.4827, D(x): 0.73, D(G(z)): 0.31
# Epoch [138/300], Step [400/600], d_loss: 0.2767, g_loss: 0.6155, D(x): 0.65, D(G(z)): 0.26
# Epoch [138/300], Step [600/600], d_loss: 0.4271, g_loss: 0.4318, D(x): 0.58, D(G(z)): 0.39
# Saving fake_images-0139.png
# Epoch [139/300], Step [200/600], d_loss: 0.2966, g_loss: 0.5170, D(x): 0.69, D(G(z)): 0.33
# Epoch [139/300], Step [400/600], d_loss: 0.3142, g_loss: 0.4765, D(x): 0.68, D(G(z)): 0.33
# Epoch [139/300], Step [600/600], d_loss: 0.4927, g_loss: 0.5110, D(x): 0.54, D(G(z)): 0.38
# Saving fake_images-0140.png
# Epoch [140/300], Step [200/600], d_loss: 0.2949, g_loss: 0.6550, D(x): 0.69, D(G(z)): 0.31
# Epoch [140/300], Step [400/600], d_loss: 0.3044, g_loss: 0.5281, D(x): 0.66, D(G(z)): 0.32
# Epoch [140/300], Step [600/600], d_loss: 0.2821, g_loss: 0.6053, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0141.png
# Epoch [141/300], Step [200/600], d_loss: 0.4502, g_loss: 0.5641, D(x): 0.58, D(G(z)): 0.39
# Epoch [141/300], Step [400/600], d_loss: 0.4393, g_loss: 0.4708, D(x): 0.53, D(G(z)): 0.30
# Epoch [141/300], Step [600/600], d_loss: 0.4515, g_loss: 0.5296, D(x): 0.61, D(G(z)): 0.41
# Saving fake_images-0142.png
# Epoch [142/300], Step [200/600], d_loss: 0.3395, g_loss: 0.5496, D(x): 0.63, D(G(z)): 0.32
# Epoch [142/300], Step [400/600], d_loss: 0.3580, g_loss: 0.6126, D(x): 0.59, D(G(z)): 0.26
# Epoch [142/300], Step [600/600], d_loss: 0.2663, g_loss: 0.6562, D(x): 0.72, D(G(z)): 0.28
# Saving fake_images-0143.png
# Epoch [143/300], Step [200/600], d_loss: 0.3744, g_loss: 0.5189, D(x): 0.59, D(G(z)): 0.34
# Epoch [143/300], Step [400/600], d_loss: 0.3657, g_loss: 0.5006, D(x): 0.61, D(G(z)): 0.33
# Epoch [143/300], Step [600/600], d_loss: 0.3335, g_loss: 0.4208, D(x): 0.65, D(G(z)): 0.36
# Saving fake_images-0144.png
# Epoch [144/300], Step [200/600], d_loss: 0.3959, g_loss: 0.4170, D(x): 0.63, D(G(z)): 0.39
# Epoch [144/300], Step [400/600], d_loss: 0.5813, g_loss: 0.4337, D(x): 0.51, D(G(z)): 0.47
# Epoch [144/300], Step [600/600], d_loss: 0.3356, g_loss: 0.4951, D(x): 0.68, D(G(z)): 0.38
# Saving fake_images-0145.png
# Epoch [145/300], Step [200/600], d_loss: 0.4132, g_loss: 0.5740, D(x): 0.54, D(G(z)): 0.30
# Epoch [145/300], Step [400/600], d_loss: 0.5398, g_loss: 0.4484, D(x): 0.52, D(G(z)): 0.42
# Epoch [145/300], Step [600/600], d_loss: 0.3532, g_loss: 0.5641, D(x): 0.65, D(G(z)): 0.35
# Saving fake_images-0146.png
# Epoch [146/300], Step [200/600], d_loss: 0.5048, g_loss: 0.3873, D(x): 0.53, D(G(z)): 0.41
# Epoch [146/300], Step [400/600], d_loss: 0.3508, g_loss: 0.5190, D(x): 0.66, D(G(z)): 0.36
# Epoch [146/300], Step [600/600], d_loss: 0.3525, g_loss: 0.4317, D(x): 0.67, D(G(z)): 0.37
# Saving fake_images-0147.png
# Epoch [147/300], Step [200/600], d_loss: 0.4132, g_loss: 0.4667, D(x): 0.62, D(G(z)): 0.40
# Epoch [147/300], Step [400/600], d_loss: 0.2022, g_loss: 0.6521, D(x): 0.73, D(G(z)): 0.24
# Epoch [147/300], Step [600/600], d_loss: 0.4878, g_loss: 0.4531, D(x): 0.62, D(G(z)): 0.46
# Saving fake_images-0148.png
# Epoch [148/300], Step [200/600], d_loss: 0.3340, g_loss: 0.5133, D(x): 0.67, D(G(z)): 0.34
# Epoch [148/300], Step [400/600], d_loss: 0.4943, g_loss: 0.3405, D(x): 0.62, D(G(z)): 0.49
# Epoch [148/300], Step [600/600], d_loss: 0.3063, g_loss: 0.5821, D(x): 0.68, D(G(z)): 0.32
# Saving fake_images-0149.png
# Epoch [149/300], Step [200/600], d_loss: 0.3710, g_loss: 0.4726, D(x): 0.63, D(G(z)): 0.36
# Epoch [149/300], Step [400/600], d_loss: 0.3487, g_loss: 0.5497, D(x): 0.63, D(G(z)): 0.31
# Epoch [149/300], Step [600/600], d_loss: 0.2840, g_loss: 0.5493, D(x): 0.66, D(G(z)): 0.29
# Saving fake_images-0150.png
# Epoch [150/300], Step [200/600], d_loss: 0.4090, g_loss: 0.4794, D(x): 0.70, D(G(z)): 0.46
# Epoch [150/300], Step [400/600], d_loss: 0.3342, g_loss: 0.4943, D(x): 0.69, D(G(z)): 0.37
# Epoch [150/300], Step [600/600], d_loss: 0.3487, g_loss: 0.5216, D(x): 0.65, D(G(z)): 0.34
# Saving fake_images-0151.png
# Epoch [151/300], Step [200/600], d_loss: 0.2585, g_loss: 0.5886, D(x): 0.76, D(G(z)): 0.30
# Epoch [151/300], Step [400/600], d_loss: 0.3591, g_loss: 0.5286, D(x): 0.65, D(G(z)): 0.35
# Epoch [151/300], Step [600/600], d_loss: 0.3207, g_loss: 0.4928, D(x): 0.66, D(G(z)): 0.31
# Saving fake_images-0152.png
# Epoch [152/300], Step [200/600], d_loss: 0.3841, g_loss: 0.4901, D(x): 0.58, D(G(z)): 0.34
# Epoch [152/300], Step [400/600], d_loss: 0.4297, g_loss: 0.4651, D(x): 0.57, D(G(z)): 0.35
# Epoch [152/300], Step [600/600], d_loss: 0.4164, g_loss: 0.4647, D(x): 0.54, D(G(z)): 0.31
# Saving fake_images-0153.png
# Epoch [153/300], Step [200/600], d_loss: 0.3928, g_loss: 0.4345, D(x): 0.60, D(G(z)): 0.33
# Epoch [153/300], Step [400/600], d_loss: 0.3905, g_loss: 0.4864, D(x): 0.64, D(G(z)): 0.35
# Epoch [153/300], Step [600/600], d_loss: 0.3869, g_loss: 0.5177, D(x): 0.71, D(G(z)): 0.43
# Saving fake_images-0154.png
# Epoch [154/300], Step [200/600], d_loss: 0.3976, g_loss: 0.4007, D(x): 0.63, D(G(z)): 0.37
# Epoch [154/300], Step [400/600], d_loss: 0.2589, g_loss: 0.6222, D(x): 0.70, D(G(z)): 0.29
# Epoch [154/300], Step [600/600], d_loss: 0.3950, g_loss: 0.4403, D(x): 0.58, D(G(z)): 0.31
# Saving fake_images-0155.png
# Epoch [155/300], Step [200/600], d_loss: 0.2907, g_loss: 0.4779, D(x): 0.71, D(G(z)): 0.34
# Epoch [155/300], Step [400/600], d_loss: 0.4309, g_loss: 0.3778, D(x): 0.62, D(G(z)): 0.42
# Epoch [155/300], Step [600/600], d_loss: 0.4418, g_loss: 0.4101, D(x): 0.59, D(G(z)): 0.40
# Saving fake_images-0156.png
# Epoch [156/300], Step [200/600], d_loss: 0.4100, g_loss: 0.5347, D(x): 0.59, D(G(z)): 0.34
# Epoch [156/300], Step [400/600], d_loss: 0.3470, g_loss: 0.5456, D(x): 0.64, D(G(z)): 0.32
# Epoch [156/300], Step [600/600], d_loss: 0.3797, g_loss: 0.4511, D(x): 0.67, D(G(z)): 0.40
# Saving fake_images-0157.png
# Epoch [157/300], Step [200/600], d_loss: 0.3208, g_loss: 0.5615, D(x): 0.66, D(G(z)): 0.32
# Epoch [157/300], Step [400/600], d_loss: 0.3213, g_loss: 0.5445, D(x): 0.64, D(G(z)): 0.32
# Epoch [157/300], Step [600/600], d_loss: 0.3220, g_loss: 0.5856, D(x): 0.64, D(G(z)): 0.28
# Saving fake_images-0158.png
# Epoch [158/300], Step [200/600], d_loss: 0.2483, g_loss: 0.4861, D(x): 0.74, D(G(z)): 0.32
# Epoch [158/300], Step [400/600], d_loss: 0.4977, g_loss: 0.3790, D(x): 0.61, D(G(z)): 0.45
# Epoch [158/300], Step [600/600], d_loss: 0.3664, g_loss: 0.4770, D(x): 0.60, D(G(z)): 0.32
# Saving fake_images-0159.png
# Epoch [159/300], Step [200/600], d_loss: 0.3596, g_loss: 0.4172, D(x): 0.65, D(G(z)): 0.36
# Epoch [159/300], Step [400/600], d_loss: 0.4847, g_loss: 0.3944, D(x): 0.57, D(G(z)): 0.41
# Epoch [159/300], Step [600/600], d_loss: 0.3156, g_loss: 0.6067, D(x): 0.67, D(G(z)): 0.32
# Saving fake_images-0160.png
# Epoch [160/300], Step [200/600], d_loss: 0.4236, g_loss: 0.4773, D(x): 0.64, D(G(z)): 0.41
# ...
# Epoch [247/300], Step [400/600], d_loss: 0.3497, g_loss: 0.4041, D(x): 0.63, D(G(z)): 0.34
# Epoch [247/300], Step [600/600], d_loss: 0.4034, g_loss: 0.3926, D(x): 0.61, D(G(z)): 0.39
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 0.5313, g_loss: 0.4071, D(x): 0.58, D(G(z)): 0.48
# Epoch [248/300], Step [400/600], d_loss: 0.3890, g_loss: 0.5078, D(x): 0.60, D(G(z)): 0.35
# Epoch [248/300], Step [600/600], d_loss: 0.5223, g_loss: 0.3803, D(x): 0.58, D(G(z)): 0.46
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 0.4745, g_loss: 0.3723, D(x): 0.59, D(G(z)): 0.46
# Epoch [249/300], Step [400/600], d_loss: 0.3771, g_loss: 0.4578, D(x): 0.61, D(G(z)): 0.36
# Epoch [249/300], Step [600/600], d_loss: 0.5856, g_loss: 0.3653, D(x): 0.50, D(G(z)): 0.47
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 0.4626, g_loss: 0.4529, D(x): 0.58, D(G(z)): 0.42
# Epoch [250/300], Step [400/600], d_loss: 0.3002, g_loss: 0.4840, D(x): 0.70, D(G(z)): 0.34
# Epoch [250/300], Step [600/600], d_loss: 0.4341, g_loss: 0.4869, D(x): 0.55, D(G(z)): 0.34
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 0.2340, g_loss: 0.5809, D(x): 0.73, D(G(z)): 0.28
# Epoch [251/300], Step [400/600], d_loss: 0.3334, g_loss: 0.4398, D(x): 0.64, D(G(z)): 0.34
# Epoch [251/300], Step [600/600], d_loss: 0.3099, g_loss: 0.5639, D(x): 0.63, D(G(z)): 0.28
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 0.2550, g_loss: 0.4952, D(x): 0.69, D(G(z)): 0.30
# Epoch [252/300], Step [400/600], d_loss: 0.3220, g_loss: 0.5180, D(x): 0.70, D(G(z)): 0.37
# Epoch [252/300], Step [600/600], d_loss: 0.3162, g_loss: 0.5193, D(x): 0.67, D(G(z)): 0.34
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 0.3769, g_loss: 0.4947, D(x): 0.63, D(G(z)): 0.37
# Epoch [253/300], Step [400/600], d_loss: 0.4262, g_loss: 0.3546, D(x): 0.59, D(G(z)): 0.40
# Epoch [253/300], Step [600/600], d_loss: 0.2793, g_loss: 0.5019, D(x): 0.66, D(G(z)): 0.29
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 0.4799, g_loss: 0.4773, D(x): 0.57, D(G(z)): 0.43
# Epoch [254/300], Step [400/600], d_loss: 0.5105, g_loss: 0.3804, D(x): 0.60, D(G(z)): 0.48
# Epoch [254/300], Step [600/600], d_loss: 0.3330, g_loss: 0.5554, D(x): 0.66, D(G(z)): 0.34
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 0.3552, g_loss: 0.4838, D(x): 0.68, D(G(z)): 0.41
# Epoch [255/300], Step [400/600], d_loss: 0.3083, g_loss: 0.4658, D(x): 0.71, D(G(z)): 0.36
# Epoch [255/300], Step [600/600], d_loss: 0.3189, g_loss: 0.4991, D(x): 0.67, D(G(z)): 0.33
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 0.3001, g_loss: 0.5358, D(x): 0.67, D(G(z)): 0.30
# Epoch [256/300], Step [400/600], d_loss: 0.2569, g_loss: 0.5270, D(x): 0.72, D(G(z)): 0.28
# Epoch [256/300], Step [600/600], d_loss: 0.3397, g_loss: 0.4375, D(x): 0.63, D(G(z)): 0.31
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 0.2479, g_loss: 0.5431, D(x): 0.69, D(G(z)): 0.28
# Epoch [257/300], Step [400/600], d_loss: 0.4459, g_loss: 0.3950, D(x): 0.59, D(G(z)): 0.40
# Epoch [257/300], Step [600/600], d_loss: 0.3242, g_loss: 0.4558, D(x): 0.66, D(G(z)): 0.33
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 0.3483, g_loss: 0.4650, D(x): 0.71, D(G(z)): 0.42
# Epoch [258/300], Step [400/600], d_loss: 0.2793, g_loss: 0.5625, D(x): 0.68, D(G(z)): 0.28
# Epoch [258/300], Step [600/600], d_loss: 0.2850, g_loss: 0.5280, D(x): 0.70, D(G(z)): 0.33
# Saving fake_images-0259.png
# Epoch [259/300], Step [200/600], d_loss: 0.4609, g_loss: 0.3565, D(x): 0.63, D(G(z)): 0.45
# Epoch [259/300], Step [400/600], d_loss: 0.3250, g_loss: 0.4866, D(x): 0.69, D(G(z)): 0.37
# Epoch [259/300], Step [600/600], d_loss: 0.3882, g_loss: 0.4269, D(x): 0.61, D(G(z)): 0.38
# Saving fake_images-0260.png
# Epoch [260/300], Step [200/600], d_loss: 0.3051, g_loss: 0.4884, D(x): 0.66, D(G(z)): 0.31
# Epoch [260/300], Step [400/600], d_loss: 0.3984, g_loss: 0.4958, D(x): 0.64, D(G(z)): 0.39
# Epoch [260/300], Step [600/600], d_loss: 0.2416, g_loss: 0.5685, D(x): 0.72, D(G(z)): 0.28
# Saving fake_images-0261.png
# Epoch [261/300], Step [200/600], d_loss: 0.3376, g_loss: 0.5184, D(x): 0.66, D(G(z)): 0.34
# Epoch [261/300], Step [400/600], d_loss: 0.3015, g_loss: 0.5421, D(x): 0.66, D(G(z)): 0.32
# Epoch [261/300], Step [600/600], d_loss: 0.2663, g_loss: 0.4927, D(x): 0.72, D(G(z)): 0.32
# Saving fake_images-0262.png
# Epoch [262/300], Step [200/600], d_loss: 0.4197, g_loss: 0.5346, D(x): 0.60, D(G(z)): 0.40
# Epoch [262/300], Step [400/600], d_loss: 0.2789, g_loss: 0.5207, D(x): 0.68, D(G(z)): 0.29
# Epoch [262/300], Step [600/600], d_loss: 0.2834, g_loss: 0.4966, D(x): 0.69, D(G(z)): 0.31
# Saving fake_images-0263.png
# Epoch [263/300], Step [200/600], d_loss: 0.2273, g_loss: 0.6057, D(x): 0.71, D(G(z)): 0.25
# Epoch [263/300], Step [400/600], d_loss: 0.3595, g_loss: 0.4614, D(x): 0.63, D(G(z)): 0.35
# Epoch [263/300], Step [600/600], d_loss: 0.3272, g_loss: 0.4981, D(x): 0.69, D(G(z)): 0.38
# Saving fake_images-0264.png
# Epoch [264/300], Step [200/600], d_loss: 0.3911, g_loss: 0.4508, D(x): 0.64, D(G(z)): 0.40
# Epoch [264/300], Step [400/600], d_loss: 0.4151, g_loss: 0.4650, D(x): 0.58, D(G(z)): 0.37
# Epoch [264/300], Step [600/600], d_loss: 0.3744, g_loss: 0.4435, D(x): 0.60, D(G(z)): 0.35
# Saving fake_images-0265.png
# Epoch [265/300], Step [200/600], d_loss: 0.4481, g_loss: 0.4384, D(x): 0.55, D(G(z)): 0.37
# Epoch [265/300], Step [400/600], d_loss: 0.3736, g_loss: 0.5202, D(x): 0.62, D(G(z)): 0.35
# Epoch [265/300], Step [600/600], d_loss: 0.4219, g_loss: 0.4439, D(x): 0.65, D(G(z)): 0.43
# Saving fake_images-0266.png
# Epoch [266/300], Step [200/600], d_loss: 0.4144, g_loss: 0.4893, D(x): 0.55, D(G(z)): 0.33
# Epoch [266/300], Step [400/600], d_loss: 0.3023, g_loss: 0.5284, D(x): 0.67, D(G(z)): 0.33
# Epoch [266/300], Step [600/600], d_loss: 0.3264, g_loss: 0.4486, D(x): 0.69, D(G(z)): 0.37
# Saving fake_images-0267.png
# Epoch [267/300], Step [200/600], d_loss: 0.3559, g_loss: 0.4241, D(x): 0.69, D(G(z)): 0.39
# Epoch [267/300], Step [400/600], d_loss: 0.5500, g_loss: 0.4225, D(x): 0.62, D(G(z)): 0.51
# Epoch [267/300], Step [600/600], d_loss: 0.4194, g_loss: 0.5144, D(x): 0.54, D(G(z)): 0.31
# Saving fake_images-0268.png
# Epoch [268/300], Step [200/600], d_loss: 0.4425, g_loss: 0.3870, D(x): 0.58, D(G(z)): 0.37
# Epoch [268/300], Step [400/600], d_loss: 0.4032, g_loss: 0.4678, D(x): 0.62, D(G(z)): 0.41
# Epoch [268/300], Step [600/600], d_loss: 0.3428, g_loss: 0.4752, D(x): 0.66, D(G(z)): 0.35
# Saving fake_images-0269.png
# Epoch [269/300], Step [200/600], d_loss: 0.4054, g_loss: 0.4087, D(x): 0.67, D(G(z)): 0.43
# Epoch [269/300], Step [400/600], d_loss: 0.4099, g_loss: 0.5297, D(x): 0.59, D(G(z)): 0.37
# Epoch [269/300], Step [600/600], d_loss: 0.3894, g_loss: 0.5243, D(x): 0.60, D(G(z)): 0.32
# Saving fake_images-0270.png
# Epoch [270/300], Step [200/600], d_loss: 0.4324, g_loss: 0.3991, D(x): 0.60, D(G(z)): 0.41
# Epoch [270/300], Step [400/600], d_loss: 0.3839, g_loss: 0.5163, D(x): 0.59, D(G(z)): 0.35
# Epoch [270/300], Step [600/600], d_loss: 0.4717, g_loss: 0.4483, D(x): 0.55, D(G(z)): 0.41
# Saving fake_images-0271.png
# Epoch [271/300], Step [200/600], d_loss: 0.4023, g_loss: 0.4744, D(x): 0.58, D(G(z)): 0.34
# Epoch [271/300], Step [400/600], d_loss: 0.2220, g_loss: 0.5710, D(x): 0.75, D(G(z)): 0.30
# Epoch [271/300], Step [600/600], d_loss: 0.3037, g_loss: 0.4530, D(x): 0.74, D(G(z)): 0.39
# Saving fake_images-0272.png
# Epoch [272/300], Step [200/600], d_loss: 0.4396, g_loss: 0.4104, D(x): 0.61, D(G(z)): 0.41
# Epoch [272/300], Step [400/600], d_loss: 0.4680, g_loss: 0.3557, D(x): 0.58, D(G(z)): 0.44
# Epoch [272/300], Step [600/600], d_loss: 0.4650, g_loss: 0.3306, D(x): 0.59, D(G(z)): 0.43
# Saving fake_images-0273.png
# Epoch [273/300], Step [200/600], d_loss: 0.2333, g_loss: 0.5874, D(x): 0.68, D(G(z)): 0.23
# Epoch [273/300], Step [400/600], d_loss: 0.3569, g_loss: 0.4690, D(x): 0.65, D(G(z)): 0.38
# Epoch [273/300], Step [600/600], d_loss: 0.3153, g_loss: 0.4856, D(x): 0.67, D(G(z)): 0.33
# Saving fake_images-0274.png
# Epoch [274/300], Step [200/600], d_loss: 0.3632, g_loss: 0.4704, D(x): 0.56, D(G(z)): 0.29
# Epoch [274/300], Step [400/600], d_loss: 0.2615, g_loss: 0.6573, D(x): 0.68, D(G(z)): 0.25
# Epoch [274/300], Step [600/600], d_loss: 0.3438, g_loss: 0.5269, D(x): 0.58, D(G(z)): 0.30
# Saving fake_images-0275.png
# Epoch [275/300], Step [200/600], d_loss: 0.4109, g_loss: 0.3484, D(x): 0.70, D(G(z)): 0.47
# Epoch [275/300], Step [400/600], d_loss: 0.3741, g_loss: 0.4191, D(x): 0.71, D(G(z)): 0.43
# Epoch [275/300], Step [600/600], d_loss: 0.3389, g_loss: 0.4447, D(x): 0.66, D(G(z)): 0.37
# Saving fake_images-0276.png
# Epoch [276/300], Step [200/600], d_loss: 0.3899, g_loss: 0.4338, D(x): 0.66, D(G(z)): 0.40
# Epoch [276/300], Step [400/600], d_loss: 0.3068, g_loss: 0.5002, D(x): 0.68, D(G(z)): 0.34
# Epoch [276/300], Step [600/600], d_loss: 0.3762, g_loss: 0.4364, D(x): 0.63, D(G(z)): 0.36
# Saving fake_images-0277.png
# Epoch [277/300], Step [200/600], d_loss: 0.2820, g_loss: 0.5130, D(x): 0.72, D(G(z)): 0.34
# Epoch [277/300], Step [400/600], d_loss: 0.3530, g_loss: 0.5390, D(x): 0.65, D(G(z)): 0.36
# Epoch [277/300], Step [600/600], d_loss: 0.3620, g_loss: 0.5421, D(x): 0.60, D(G(z)): 0.31
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 0.3264, g_loss: 0.4697, D(x): 0.66, D(G(z)): 0.34
# Epoch [278/300], Step [400/600], d_loss: 0.3967, g_loss: 0.5802, D(x): 0.59, D(G(z)): 0.34
# Epoch [278/300], Step [600/600], d_loss: 0.3367, g_loss: 0.4891, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 0.2700, g_loss: 0.5661, D(x): 0.72, D(G(z)): 0.33
# Epoch [279/300], Step [400/600], d_loss: 0.3095, g_loss: 0.5260, D(x): 0.71, D(G(z)): 0.38
# Epoch [279/300], Step [600/600], d_loss: 0.3719, g_loss: 0.5295, D(x): 0.65, D(G(z)): 0.37
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 0.2968, g_loss: 0.5564, D(x): 0.67, D(G(z)): 0.32
# Epoch [280/300], Step [400/600], d_loss: 0.3440, g_loss: 0.4399, D(x): 0.67, D(G(z)): 0.38
# Epoch [280/300], Step [600/600], d_loss: 0.3441, g_loss: 0.4841, D(x): 0.64, D(G(z)): 0.34
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 0.4130, g_loss: 0.4631, D(x): 0.58, D(G(z)): 0.37
# Epoch [281/300], Step [400/600], d_loss: 0.3749, g_loss: 0.3943, D(x): 0.70, D(G(z)): 0.41
# Epoch [281/300], Step [600/600], d_loss: 0.4281, g_loss: 0.3775, D(x): 0.61, D(G(z)): 0.41
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 0.3860, g_loss: 0.4533, D(x): 0.61, D(G(z)): 0.38
# Epoch [282/300], Step [400/600], d_loss: 0.3627, g_loss: 0.4552, D(x): 0.65, D(G(z)): 0.39
# Epoch [282/300], Step [600/600], d_loss: 0.2683, g_loss: 0.5755, D(x): 0.70, D(G(z)): 0.32
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 0.2772, g_loss: 0.4790, D(x): 0.71, D(G(z)): 0.30
# Epoch [283/300], Step [400/600], d_loss: 0.4569, g_loss: 0.4732, D(x): 0.60, D(G(z)): 0.42
# Epoch [283/300], Step [600/600], d_loss: 0.2887, g_loss: 0.4739, D(x): 0.66, D(G(z)): 0.30
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 0.3357, g_loss: 0.3951, D(x): 0.70, D(G(z)): 0.37
# Epoch [284/300], Step [400/600], d_loss: 0.4239, g_loss: 0.3999, D(x): 0.67, D(G(z)): 0.46
# Epoch [284/300], Step [600/600], d_loss: 0.3994, g_loss: 0.4398, D(x): 0.61, D(G(z)): 0.38
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 0.4278, g_loss: 0.4143, D(x): 0.56, D(G(z)): 0.34
# Epoch [285/300], Step [400/600], d_loss: 0.4596, g_loss: 0.4687, D(x): 0.55, D(G(z)): 0.37
# Epoch [285/300], Step [600/600], d_loss: 0.4002, g_loss: 0.4646, D(x): 0.60, D(G(z)): 0.36
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 0.2696, g_loss: 0.4845, D(x): 0.69, D(G(z)): 0.28
# Epoch [286/300], Step [400/600], d_loss: 0.3033, g_loss: 0.4386, D(x): 0.73, D(G(z)): 0.38
# Epoch [286/300], Step [600/600], d_loss: 0.3237, g_loss: 0.4520, D(x): 0.67, D(G(z)): 0.34
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 0.2828, g_loss: 0.5518, D(x): 0.65, D(G(z)): 0.28
# Epoch [287/300], Step [400/600], d_loss: 0.2906, g_loss: 0.5341, D(x): 0.66, D(G(z)): 0.28
# Epoch [287/300], Step [600/600], d_loss: 0.3488, g_loss: 0.4444, D(x): 0.68, D(G(z)): 0.39
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss: 0.3075, g_loss: 0.4573, D(x): 0.69, D(G(z)): 0.35
# Epoch [288/300], Step [400/600], d_loss: 0.3896, g_loss: 0.4978, D(x): 0.65, D(G(z)): 0.42
# Epoch [288/300], Step [600/600], d_loss: 0.4287, g_loss: 0.4420, D(x): 0.56, D(G(z)): 0.37
# Saving fake_images-0289.png
# Epoch [289/300], Step [200/600], d_loss: 0.3676, g_loss: 0.4747, D(x): 0.66, D(G(z)): 0.40
# Epoch [289/300], Step [400/600], d_loss: 0.4255, g_loss: 0.4250, D(x): 0.53, D(G(z)): 0.31
# Epoch [289/300], Step [600/600], d_loss: 0.4246, g_loss: 0.4901, D(x): 0.62, D(G(z)): 0.42
# Saving fake_images-0290.png
# Epoch [290/300], Step [200/600], d_loss: 0.3360, g_loss: 0.4544, D(x): 0.63, D(G(z)): 0.31
# Epoch [290/300], Step [400/600], d_loss: 0.3323, g_loss: 0.3852, D(x): 0.66, D(G(z)): 0.36
# Epoch [290/300], Step [600/600], d_loss: 0.3600, g_loss: 0.5198, D(x): 0.58, D(G(z)): 0.28
# Saving fake_images-0291.png
# Epoch [291/300], Step [200/600], d_loss: 0.4212, g_loss: 0.4190, D(x): 0.69, D(G(z)): 0.46
# Epoch [291/300], Step [400/600], d_loss: 0.3754, g_loss: 0.4915, D(x): 0.61, D(G(z)): 0.36
# Epoch [291/300], Step [600/600], d_loss: 0.4264, g_loss: 0.4404, D(x): 0.55, D(G(z)): 0.34
# Saving fake_images-0292.png
# Epoch [292/300], Step [200/600], d_loss: 0.3625, g_loss: 0.4745, D(x): 0.63, D(G(z)): 0.35
# Epoch [292/300], Step [400/600], d_loss: 0.3842, g_loss: 0.4286, D(x): 0.66, D(G(z)): 0.39
# Epoch [292/300], Step [600/600], d_loss: 0.3738, g_loss: 0.4535, D(x): 0.59, D(G(z)): 0.32
# Saving fake_images-0293.png
# Epoch [293/300], Step [200/600], d_loss: 0.3479, g_loss: 0.4276, D(x): 0.68, D(G(z)): 0.37
# Epoch [293/300], Step [400/600], d_loss: 0.3594, g_loss: 0.5323, D(x): 0.60, D(G(z)): 0.30
# Epoch [293/300], Step [600/600], d_loss: 0.3943, g_loss: 0.4622, D(x): 0.67, D(G(z)): 0.42
# Saving fake_images-0294.png
# Epoch [294/300], Step [200/600], d_loss: 0.4111, g_loss: 0.4483, D(x): 0.62, D(G(z)): 0.39
# Epoch [294/300], Step [400/600], d_loss: 0.4129, g_loss: 0.3886, D(x): 0.64, D(G(z)): 0.41
# Epoch [294/300], Step [600/600], d_loss: 0.4229, g_loss: 0.4583, D(x): 0.59, D(G(z)): 0.37
# Saving fake_images-0295.png
# Epoch [295/300], Step [200/600], d_loss: 0.3910, g_loss: 0.4397, D(x): 0.63, D(G(z)): 0.37
# Epoch [295/300], Step [400/600], d_loss: 0.3517, g_loss: 0.4615, D(x): 0.66, D(G(z)): 0.35
# Epoch [295/300], Step [600/600], d_loss: 0.2571, g_loss: 0.5094, D(x): 0.81, D(G(z)): 0.37
# Saving fake_images-0296.png
# Epoch [296/300], Step [200/600], d_loss: 0.3073, g_loss: 0.5410, D(x): 0.63, D(G(z)): 0.28
# Epoch [296/300], Step [400/600], d_loss: 0.3237, g_loss: 0.4826, D(x): 0.67, D(G(z)): 0.34
# Epoch [296/300], Step [600/600], d_loss: 0.4396, g_loss: 0.4795, D(x): 0.54, D(G(z)): 0.36
# Saving fake_images-0297.png
# Epoch [297/300], Step [200/600], d_loss: 0.4302, g_loss: 0.4810, D(x): 0.56, D(G(z)): 0.37
# Epoch [297/300], Step [400/600], d_loss: 0.3171, g_loss: 0.5082, D(x): 0.67, D(G(z)): 0.34
# Epoch [297/300], Step [600/600], d_loss: 0.4398, g_loss: 0.4600, D(x): 0.52, D(G(z)): 0.34
# Saving fake_images-0298.png
# Epoch [298/300], Step [200/600], d_loss: 0.4700, g_loss: 0.4983, D(x): 0.54, D(G(z)): 0.37
# Epoch [298/300], Step [400/600], d_loss: 0.4678, g_loss: 0.4359, D(x): 0.54, D(G(z)): 0.36
# Epoch [298/300], Step [600/600], d_loss: 0.4451, g_loss: 0.4490, D(x): 0.59, D(G(z)): 0.41
# Saving fake_images-0299.png
# Epoch [299/300], Step [200/600], d_loss: 0.2740, g_loss: 0.4620, D(x): 0.73, D(G(z)): 0.34
# Epoch [299/300], Step [400/600], d_loss: 0.3992, g_loss: 0.5184, D(x): 0.56, D(G(z)): 0.33
# Epoch [299/300], Step [600/600], d_loss: 0.4299, g_loss: 0.3856, D(x): 0.61, D(G(z)): 0.42
# Saving fake_images-0300.png
# CPU times: user 2h 44min 11s, sys: 41.6 s, total: 2h 44min 52s
# Wall time: 2h 46min 34s

# %% [markdown]
# Now that we have trained the models, we can save checkpoints.

# %% [markdown]
# Step3. Display at least 3 samples produced from your GAN model.

# %%
Image(os.path.join(sample_dir, 'fake_images-0050.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0150.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0250.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0300.png'))

# %% [markdown]
# It took 2h 33min 19s  and system crashes

# %%
# Save the model checkpoints
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %% [markdown]
# We can visualize the training process by combining the sample images generated
#
# ---
#
# after each epoch into a video using OpenCV.

# %%
import cv2
import os
from IPython.display import FileLink

vid_fname = 'gans_training.avi'

files = [os.path.join(sample_dir, f) for f in os.listdir(sample_dir) if 'fake_images' in f]
files.sort()

out = cv2.VideoWriter(vid_fname,cv2.VideoWriter_fourcc(*'MP4V'), 8, (302,302))
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink('gans_training.avi')
# Out:
# /content/gans_training.avi

# %% [markdown]
# You can view the animated training video here: https://www.youtube.com/watch?v=R7HTX79JlBg
#
# We can also visualize how the loss changes over time. Visualizing losses is quite useful for debugging the training process. For GANs, we expect the generator's loss to reduce over time, without the discriminator's loss getting too high.

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# #Step4. Save the model weights in the folder to be used later.

# %%
torch.save(G.state_dict(), 'generator_weights.pth')
torch.save(D.state_dict(), 'discriminator_weights.pth')

# %% [markdown]
# #Step5. Load the model using the saved weights.

# %%
G.load_state_dict(torch.load('generator_weights.pth'))
D.load_state_dict(torch.load('discriminator_weights.pth'))
# Out:
# <All keys matched successfully>

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %%
num_epochs = 50
for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        images = images.reshape(batch_size, -1).to(device)

        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        if (i+1) % 200 == 0:
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    save_fake_images(epoch+1)
# Out:
# Epoch [0/50], Step [200/600], d_loss: 0.2700, g_loss: 0.5555, D(x): 0.68, D(G(z)): 0.29
# Epoch [0/50], Step [400/600], d_loss: 0.4639, g_loss: 0.4320, D(x): 0.56, D(G(z)): 0.39
# Epoch [0/50], Step [600/600], d_loss: 0.2620, g_loss: 0.5423, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0001.png
# Epoch [1/50], Step [200/600], d_loss: 0.4494, g_loss: 0.3884, D(x): 0.58, D(G(z)): 0.40
# Epoch [1/50], Step [400/600], d_loss: 0.3738, g_loss: 0.4515, D(x): 0.66, D(G(z)): 0.40
# Epoch [1/50], Step [600/600], d_loss: 0.3836, g_loss: 0.4726, D(x): 0.63, D(G(z)): 0.39
# Saving fake_images-0002.png
# Epoch [2/50], Step [200/600], d_loss: 0.4470, g_loss: 0.4599, D(x): 0.58, D(G(z)): 0.37
# Epoch [2/50], Step [400/600], d_loss: 0.2653, g_loss: 0.4756, D(x): 0.73, D(G(z)): 0.35
# Epoch [2/50], Step [600/600], d_loss: 0.4166, g_loss: 0.4265, D(x): 0.63, D(G(z)): 0.40
# Saving fake_images-0003.png
# Epoch [3/50], Step [200/600], d_loss: 0.3230, g_loss: 0.4824, D(x): 0.69, D(G(z)): 0.37
# Epoch [3/50], Step [400/600], d_loss: 0.3104, g_loss: 0.4734, D(x): 0.64, D(G(z)): 0.29
# Epoch [3/50], Step [600/600], d_loss: 0.4969, g_loss: 0.4454, D(x): 0.50, D(G(z)): 0.38
# Saving fake_images-0004.png
# Epoch [4/50], Step [200/600], d_loss: 0.2692, g_loss: 0.5698, D(x): 0.63, D(G(z)): 0.24
# Epoch [4/50], Step [400/600], d_loss: 0.4016, g_loss: 0.4537, D(x): 0.58, D(G(z)): 0.35
# Epoch [4/50], Step [600/600], d_loss: 0.4611, g_loss: 0.3770, D(x): 0.59, D(G(z)): 0.45
# Saving fake_images-0005.png
# Epoch [5/50], Step [200/600], d_loss: 0.2646, g_loss: 0.5688, D(x): 0.69, D(G(z)): 0.29
# Epoch [5/50], Step [400/600], d_loss: 0.3695, g_loss: 0.4341, D(x): 0.62, D(G(z)): 0.38
# Epoch [5/50], Step [600/600], d_loss: 0.4619, g_loss: 0.3880, D(x): 0.59, D(G(z)): 0.43
# Saving fake_images-0006.png
# Epoch [6/50], Step [200/600], d_loss: 0.4200, g_loss: 0.4321, D(x): 0.60, D(G(z)): 0.39
# Epoch [6/50], Step [400/600], d_loss: 0.2716, g_loss: 0.5880, D(x): 0.66, D(G(z)): 0.23
# Epoch [6/50], Step [600/600], d_loss: 0.2651, g_loss: 0.5678, D(x): 0.75, D(G(z)): 0.33
# Saving fake_images-0007.png
# Epoch [7/50], Step [200/600], d_loss: 0.4251, g_loss: 0.4712, D(x): 0.59, D(G(z)): 0.38
# Epoch [7/50], Step [400/600], d_loss: 0.3875, g_loss: 0.4091, D(x): 0.56, D(G(z)): 0.33
# Epoch [7/50], Step [600/600], d_loss: 0.2819, g_loss: 0.4927, D(x): 0.71, D(G(z)): 0.34
# Saving fake_images-0008.png
# Epoch [8/50], Step [200/600], d_loss: 0.3828, g_loss: 0.4374, D(x): 0.61, D(G(z)): 0.37
# Epoch [8/50], Step [400/600], d_loss: 0.4966, g_loss: 0.4542, D(x): 0.53, D(G(z)): 0.41
# Epoch [8/50], Step [600/600], d_loss: 0.3335, g_loss: 0.4706, D(x): 0.64, D(G(z)): 0.32
# Saving fake_images-0009.png
# Epoch [9/50], Step [200/600], d_loss: 0.3391, g_loss: 0.5256, D(x): 0.64, D(G(z)): 0.35
# Epoch [9/50], Step [400/600], d_loss: 0.2702, g_loss: 0.4545, D(x): 0.74, D(G(z)): 0.35
# Epoch [9/50], Step [600/600], d_loss: 0.3698, g_loss: 0.4513, D(x): 0.60, D(G(z)): 0.33
# Saving fake_images-0010.png
# Epoch [10/50], Step [200/600], d_loss: 0.4606, g_loss: 0.3856, D(x): 0.54, D(G(z)): 0.38
# Epoch [10/50], Step [400/600], d_loss: 0.4653, g_loss: 0.4748, D(x): 0.56, D(G(z)): 0.40
# Epoch [10/50], Step [600/600], d_loss: 0.2858, g_loss: 0.4522, D(x): 0.71, D(G(z)): 0.35
# Saving fake_images-0011.png
# Epoch [11/50], Step [200/600], d_loss: 0.3270, g_loss: 0.5656, D(x): 0.67, D(G(z)): 0.33
# Epoch [11/50], Step [400/600], d_loss: 0.2625, g_loss: 0.5322, D(x): 0.71, D(G(z)): 0.33
# Epoch [11/50], Step [600/600], d_loss: 0.3322, g_loss: 0.4158, D(x): 0.65, D(G(z)): 0.34
# Saving fake_images-0012.png
# Epoch [12/50], Step [200/600], d_loss: 0.4760, g_loss: 0.3781, D(x): 0.62, D(G(z)): 0.46
# Epoch [12/50], Step [400/600], d_loss: 0.3901, g_loss: 0.4202, D(x): 0.66, D(G(z)): 0.42
# Epoch [12/50], Step [600/600], d_loss: 0.2824, g_loss: 0.4903, D(x): 0.70, D(G(z)): 0.32
# Saving fake_images-0013.png
# Epoch [13/50], Step [200/600], d_loss: 0.4528, g_loss: 0.4390, D(x): 0.60, D(G(z)): 0.44
# Epoch [13/50], Step [400/600], d_loss: 0.2945, g_loss: 0.5002, D(x): 0.67, D(G(z)): 0.32
# Epoch [13/50], Step [600/600], d_loss: 0.3836, g_loss: 0.4986, D(x): 0.57, D(G(z)): 0.29
# Saving fake_images-0014.png
# Epoch [14/50], Step [200/600], d_loss: 0.3430, g_loss: 0.4589, D(x): 0.61, D(G(z)): 0.32
# Epoch [14/50], Step [400/600], d_loss: 0.3214, g_loss: 0.4770, D(x): 0.63, D(G(z)): 0.30
# Epoch [14/50], Step [600/600], d_loss: 0.2871, g_loss: 0.5141, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0015.png
# Epoch [15/50], Step [200/600], d_loss: 0.4390, g_loss: 0.4356, D(x): 0.61, D(G(z)): 0.41
# Epoch [15/50], Step [400/600], d_loss: 0.4115, g_loss: 0.4281, D(x): 0.61, D(G(z)): 0.38
# Epoch [15/50], Step [600/600], d_loss: 0.3398, g_loss: 0.4971, D(x): 0.64, D(G(z)): 0.35
# Saving fake_images-0016.png
# Epoch [16/50], Step [200/600], d_loss: 0.3298, g_loss: 0.5189, D(x): 0.66, D(G(z)): 0.33
# Epoch [16/50], Step [400/600], d_loss: 0.4945, g_loss: 0.3620, D(x): 0.55, D(G(z)): 0.42
# Epoch [16/50], Step [600/600], d_loss: 0.2933, g_loss: 0.4755, D(x): 0.69, D(G(z)): 0.35
# Saving fake_images-0017.png
# Epoch [17/50], Step [200/600], d_loss: 0.4374, g_loss: 0.4643, D(x): 0.58, D(G(z)): 0.37
# Epoch [17/50], Step [400/600], d_loss: 0.5375, g_loss: 0.3935, D(x): 0.51, D(G(z)): 0.43
# Epoch [17/50], Step [600/600], d_loss: 0.3174, g_loss: 0.5562, D(x): 0.63, D(G(z)): 0.29
# Saving fake_images-0018.png
# Epoch [18/50], Step [200/600], d_loss: 0.3234, g_loss: 0.5532, D(x): 0.65, D(G(z)): 0.33
# Epoch [18/50], Step [400/600], d_loss: 0.3560, g_loss: 0.4182, D(x): 0.65, D(G(z)): 0.37
# Epoch [18/50], Step [600/600], d_loss: 0.4086, g_loss: 0.4919, D(x): 0.62, D(G(z)): 0.37
# Saving fake_images-0019.png
# Epoch [19/50], Step [200/600], d_loss: 0.5004, g_loss: 0.3660, D(x): 0.56, D(G(z)): 0.46
# Epoch [19/50], Step [400/600], d_loss: 0.3595, g_loss: 0.4635, D(x): 0.66, D(G(z)): 0.38
# Epoch [19/50], Step [600/600], d_loss: 0.2990, g_loss: 0.5383, D(x): 0.62, D(G(z)): 0.27
# Saving fake_images-0020.png
# Epoch [20/50], Step [200/600], d_loss: 0.3865, g_loss: 0.4199, D(x): 0.66, D(G(z)): 0.39
# Epoch [20/50], Step [400/600], d_loss: 0.3266, g_loss: 0.4874, D(x): 0.66, D(G(z)): 0.33
# Epoch [20/50], Step [600/600], d_loss: 0.4867, g_loss: 0.4021, D(x): 0.56, D(G(z)): 0.41
# Saving fake_images-0021.png
# Epoch [21/50], Step [200/600], d_loss: 0.3791, g_loss: 0.4427, D(x): 0.63, D(G(z)): 0.38
# Epoch [21/50], Step [400/600], d_loss: 0.3283, g_loss: 0.4397, D(x): 0.73, D(G(z)): 0.38
# Epoch [21/50], Step [600/600], d_loss: 0.4351, g_loss: 0.4935, D(x): 0.58, D(G(z)): 0.39
# Saving fake_images-0022.png
# Epoch [22/50], Step [200/600], d_loss: 0.3855, g_loss: 0.4438, D(x): 0.62, D(G(z)): 0.35
# Epoch [22/50], Step [400/600], d_loss: 0.3424, g_loss: 0.5864, D(x): 0.57, D(G(z)): 0.25
# Epoch [22/50], Step [600/600], d_loss: 0.3165, g_loss: 0.4984, D(x): 0.64, D(G(z)): 0.31
# Saving fake_images-0023.png
# Epoch [23/50], Step [200/600], d_loss: 0.5354, g_loss: 0.4728, D(x): 0.51, D(G(z)): 0.40
# Epoch [23/50], Step [400/600], d_loss: 0.2606, g_loss: 0.5691, D(x): 0.67, D(G(z)): 0.26
# Epoch [23/50], Step [600/600], d_loss: 0.3709, g_loss: 0.4624, D(x): 0.64, D(G(z)): 0.36
# Saving fake_images-0024.png
# Epoch [24/50], Step [200/600], d_loss: 0.4043, g_loss: 0.4091, D(x): 0.66, D(G(z)): 0.43
# Epoch [24/50], Step [400/600], d_loss: 0.3233, g_loss: 0.5102, D(x): 0.68, D(G(z)): 0.33
# Epoch [24/50], Step [600/600], d_loss: 0.3709, g_loss: 0.5505, D(x): 0.63, D(G(z)): 0.36
# Saving fake_images-0025.png
# Epoch [25/50], Step [200/600], d_loss: 0.5405, g_loss: 0.4078, D(x): 0.50, D(G(z)): 0.44
# Epoch [25/50], Step [400/600], d_loss: 0.3696, g_loss: 0.5121, D(x): 0.64, D(G(z)): 0.36
# Epoch [25/50], Step [600/600], d_loss: 0.3458, g_loss: 0.5145, D(x): 0.61, D(G(z)): 0.31
# Saving fake_images-0026.png
# Epoch [26/50], Step [200/600], d_loss: 0.3697, g_loss: 0.4551, D(x): 0.64, D(G(z)): 0.39
# Epoch [26/50], Step [400/600], d_loss: 0.4382, g_loss: 0.4045, D(x): 0.57, D(G(z)): 0.39
# Epoch [26/50], Step [600/600], d_loss: 0.3066, g_loss: 0.5309, D(x): 0.64, D(G(z)): 0.30
# Saving fake_images-0027.png
# Epoch [27/50], Step [200/600], d_loss: 0.3028, g_loss: 0.5617, D(x): 0.66, D(G(z)): 0.31
# Epoch [27/50], Step [400/600], d_loss: 0.5545, g_loss: 0.4452, D(x): 0.47, D(G(z)): 0.41
# Epoch [27/50], Step [600/600], d_loss: 0.2749, g_loss: 0.5060, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0028.png
# Epoch [28/50], Step [200/600], d_loss: 0.3172, g_loss: 0.5033, D(x): 0.65, D(G(z)): 0.33
# Epoch [28/50], Step [400/600], d_loss: 0.3754, g_loss: 0.4986, D(x): 0.62, D(G(z)): 0.34
# Epoch [28/50], Step [600/600], d_loss: 0.3586, g_loss: 0.4282, D(x): 0.62, D(G(z)): 0.32
# Saving fake_images-0029.png
# Epoch [29/50], Step [200/600], d_loss: 0.2806, g_loss: 0.4527, D(x): 0.71, D(G(z)): 0.32
# Epoch [29/50], Step [400/600], d_loss: 0.4514, g_loss: 0.5154, D(x): 0.54, D(G(z)): 0.36
# Epoch [29/50], Step [600/600], d_loss: 0.3763, g_loss: 0.4016, D(x): 0.63, D(G(z)): 0.37
# Saving fake_images-0030.png
# Epoch [30/50], Step [200/600], d_loss: 0.3944, g_loss: 0.4308, D(x): 0.59, D(G(z)): 0.37
# Epoch [30/50], Step [400/600], d_loss: 0.3105, g_loss: 0.4034, D(x): 0.67, D(G(z)): 0.33
# Epoch [30/50], Step [600/600], d_loss: 0.4196, g_loss: 0.4525, D(x): 0.54, D(G(z)): 0.33
# Saving fake_images-0031.png
# Epoch [31/50], Step [200/600], d_loss: 0.3957, g_loss: 0.4628, D(x): 0.65, D(G(z)): 0.39
# Epoch [31/50], Step [400/600], d_loss: 0.4036, g_loss: 0.4688, D(x): 0.63, D(G(z)): 0.39
# Epoch [31/50], Step [600/600], d_loss: 0.3509, g_loss: 0.5196, D(x): 0.70, D(G(z)): 0.40
# Saving fake_images-0032.png
# Epoch [32/50], Step [200/600], d_loss: 0.3950, g_loss: 0.4205, D(x): 0.62, D(G(z)): 0.39
# Epoch [32/50], Step [400/600], d_loss: 0.3620, g_loss: 0.5283, D(x): 0.63, D(G(z)): 0.34
# Epoch [32/50], Step [600/600], d_loss: 0.3934, g_loss: 0.4485, D(x): 0.60, D(G(z)): 0.37
# Saving fake_images-0033.png
# Epoch [33/50], Step [200/600], d_loss: 0.4238, g_loss: 0.4195, D(x): 0.58, D(G(z)): 0.36
# Epoch [33/50], Step [400/600], d_loss: 0.2536, g_loss: 0.5358, D(x): 0.71, D(G(z)): 0.30
# Epoch [33/50], Step [600/600], d_loss: 0.4699, g_loss: 0.3326, D(x): 0.59, D(G(z)): 0.43
# Saving fake_images-0034.png
# Epoch [34/50], Step [200/600], d_loss: 0.2734, g_loss: 0.5196, D(x): 0.72, D(G(z)): 0.32
# Epoch [34/50], Step [400/600], d_loss: 0.4044, g_loss: 0.5592, D(x): 0.56, D(G(z)): 0.34
# Epoch [34/50], Step [600/600], d_loss: 0.4560, g_loss: 0.4348, D(x): 0.53, D(G(z)): 0.36
# Saving fake_images-0035.png
# Epoch [35/50], Step [200/600], d_loss: 0.3094, g_loss: 0.5355, D(x): 0.66, D(G(z)): 0.32
# Epoch [35/50], Step [400/600], d_loss: 0.3429, g_loss: 0.5259, D(x): 0.64, D(G(z)): 0.32
# Epoch [35/50], Step [600/600], d_loss: 0.4391, g_loss: 0.4837, D(x): 0.56, D(G(z)): 0.36
# Saving fake_images-0036.png
# Epoch [36/50], Step [200/600], d_loss: 0.2988, g_loss: 0.5297, D(x): 0.64, D(G(z)): 0.29
# Epoch [36/50], Step [400/600], d_loss: 0.4125, g_loss: 0.4446, D(x): 0.62, D(G(z)): 0.41
# Epoch [36/50], Step [600/600], d_loss: 0.3324, g_loss: 0.4890, D(x): 0.62, D(G(z)): 0.30
# Saving fake_images-0037.png
# Epoch [37/50], Step [200/600], d_loss: 0.4082, g_loss: 0.4647, D(x): 0.61, D(G(z)): 0.37
# Epoch [37/50], Step [400/600], d_loss: 0.3403, g_loss: 0.4590, D(x): 0.68, D(G(z)): 0.38
# Epoch [37/50], Step [600/600], d_loss: 0.3564, g_loss: 0.5512, D(x): 0.63, D(G(z)): 0.33
# Saving fake_images-0038.png
# Epoch [38/50], Step [200/600], d_loss: 0.3589, g_loss: 0.4963, D(x): 0.61, D(G(z)): 0.34
# Epoch [38/50], Step [400/600], d_loss: 0.3793, g_loss: 0.4528, D(x): 0.63, D(G(z)): 0.37
# Epoch [38/50], Step [600/600], d_loss: 0.2215, g_loss: 0.5331, D(x): 0.71, D(G(z)): 0.25
# Saving fake_images-0039.png
# Epoch [39/50], Step [200/600], d_loss: 0.4309, g_loss: 0.3861, D(x): 0.55, D(G(z)): 0.36
# Epoch [39/50], Step [400/600], d_loss: 0.3535, g_loss: 0.4796, D(x): 0.67, D(G(z)): 0.38
# Epoch [39/50], Step [600/600], d_loss: 0.4414, g_loss: 0.4712, D(x): 0.56, D(G(z)): 0.37
# Saving fake_images-0040.png
# Epoch [40/50], Step [200/600], d_loss: 0.3431, g_loss: 0.5528, D(x): 0.62, D(G(z)): 0.31
# Epoch [40/50], Step [400/600], d_loss: 0.4140, g_loss: 0.4216, D(x): 0.60, D(G(z)): 0.37
# Epoch [40/50], Step [600/600], d_loss: 0.3164, g_loss: 0.5009, D(x): 0.68, D(G(z)): 0.34
# Saving fake_images-0041.png
# Epoch [41/50], Step [200/600], d_loss: 0.3230, g_loss: 0.4814, D(x): 0.62, D(G(z)): 0.29
# Epoch [41/50], Step [400/600], d_loss: 0.4565, g_loss: 0.4539, D(x): 0.57, D(G(z)): 0.39
# Epoch [41/50], Step [600/600], d_loss: 0.3424, g_loss: 0.4307, D(x): 0.67, D(G(z)): 0.37
# Saving fake_images-0042.png
# Epoch [42/50], Step [200/600], d_loss: 0.3433, g_loss: 0.4716, D(x): 0.67, D(G(z)): 0.37
# Epoch [42/50], Step [400/600], d_loss: 0.4175, g_loss: 0.4259, D(x): 0.64, D(G(z)): 0.42
# Epoch [42/50], Step [600/600], d_loss: 0.2887, g_loss: 0.5515, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0043.png
# Epoch [43/50], Step [200/600], d_loss: 0.4468, g_loss: 0.4781, D(x): 0.61, D(G(z)): 0.43
# Epoch [43/50], Step [400/600], d_loss: 0.3583, g_loss: 0.4647, D(x): 0.63, D(G(z)): 0.33
# Epoch [43/50], Step [600/600], d_loss: 0.3488, g_loss: 0.5535, D(x): 0.63, D(G(z)): 0.31
# Saving fake_images-0044.png
# Epoch [44/50], Step [200/600], d_loss: 0.3311, g_loss: 0.4556, D(x): 0.68, D(G(z)): 0.35
# Epoch [44/50], Step [400/600], d_loss: 0.3744, g_loss: 0.5216, D(x): 0.62, D(G(z)): 0.34
# Epoch [44/50], Step [600/600], d_loss: 0.3290, g_loss: 0.4728, D(x): 0.69, D(G(z)): 0.36
# Saving fake_images-0045.png
# Epoch [45/50], Step [200/600], d_loss: 0.3409, g_loss: 0.4715, D(x): 0.64, D(G(z)): 0.35
# Epoch [45/50], Step [400/600], d_loss: 0.2875, g_loss: 0.5252, D(x): 0.66, D(G(z)): 0.30
# Epoch [45/50], Step [600/600], d_loss: 0.3769, g_loss: 0.4438, D(x): 0.68, D(G(z)): 0.42
# Saving fake_images-0046.png
# Epoch [46/50], Step [200/600], d_loss: 0.3822, g_loss: 0.4328, D(x): 0.68, D(G(z)): 0.42
# Epoch [46/50], Step [400/600], d_loss: 0.3554, g_loss: 0.4933, D(x): 0.60, D(G(z)): 0.32
# Epoch [46/50], Step [600/600], d_loss: 0.3559, g_loss: 0.5019, D(x): 0.64, D(G(z)): 0.34
# Saving fake_images-0047.png
# Epoch [47/50], Step [200/600], d_loss: 0.3507, g_loss: 0.5387, D(x): 0.60, D(G(z)): 0.31
# Epoch [47/50], Step [400/600], d_loss: 0.3992, g_loss: 0.5072, D(x): 0.59, D(G(z)): 0.33
# Epoch [47/50], Step [600/600], d_loss: 0.3678, g_loss: 0.4806, D(x): 0.61, D(G(z)): 0.33
# Saving fake_images-0048.png
# Epoch [48/50], Step [200/600], d_loss: 0.2629, g_loss: 0.5559, D(x): 0.67, D(G(z)): 0.28
# Epoch [48/50], Step [400/600], d_loss: 0.2937, g_loss: 0.4899, D(x): 0.64, D(G(z)): 0.29
# Epoch [48/50], Step [600/600], d_loss: 0.4514, g_loss: 0.4041, D(x): 0.63, D(G(z)): 0.45
# Saving fake_images-0049.png
# Epoch [49/50], Step [200/600], d_loss: 0.2824, g_loss: 0.5775, D(x): 0.67, D(G(z)): 0.29
# Epoch [49/50], Step [400/600], d_loss: 0.3245, g_loss: 0.5176, D(x): 0.61, D(G(z)): 0.28
# Epoch [49/50], Step [600/600], d_loss: 0.3301, g_loss: 0.4709, D(x): 0.65, D(G(z)): 0.32
# Saving fake_images-0050.png

# %% [markdown]
# # Step 7: Save the model weights without using checkpoints.

# %%
torch.save(G.state_dict(), 'generator_weights_no_checkpoint.pth')
torch.save(D.state_dict(), 'discriminator_weights_no_checkpoint.pth')

# %% [markdown]
# #Step 8: Load the model weights without using checkpoints.

# %%
G_no_checkpoint = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh()
)

D_no_checkpoint = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid()
)

G_no_checkpoint.load_state_dict(torch.load('generator_weights_no_checkpoint.pth'))
D_no_checkpoint.load_state_dict(torch.load('discriminator_weights_no_checkpoint.pth'))
# Out:
# <All keys matched successfully>

# %%
Image(os.path.join(sample_dir, 'fake_images-0001.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0015.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0030.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0050.png'))

# %% [markdown]
# The output the images is improved and is close to the original image

# %%
Image(os.path.join(sample_dir, 'real_images.png'))
