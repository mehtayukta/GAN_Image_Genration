# %% [markdown]
# #GAN
#
# # Generative Adverserial Networks in PyTorch
#
# Deep neural networks are used mainly for supervised learning: classification or regression. Generative Adverserial Networks or GANs, however, use neural networks for a very different purpose: Generative modeling
#
# > Generative modeling is an unsupervised learning task in machine learning that involves automatically discovering and learning the regularities or patterns in input data in such a way that the model can be used to generate or output new examples that plausibly could have been drawn from the original dataset. - [Source](https://machinelearningmastery.com/what-are-generative-adversarial-networks-gans/)
#
# While there are many approaches used for generative modeling, a Generative Adverserial Network takes the following approach:
#
# ![GAN Flowchart](https://i.imgur.com/6NMdO9u.png)
#
# There are two neural networks: a *Generator* and a *Discriminator*. The generator generates a "fake" sample given a random vector/matrix, and the discriminator attempts to detect whether a given sample is "real" (picked from the training data) or "fake" (generated by the generator). Training happens in tandem: we train the discriminator for a few epochs, then train the generator for a few epochs, and repeat. This way both the generator and the discriminator get better at doing their jobs. This rather simple approach can lead to some astounding results. The following images ([source](https://machinelearningmastery.com/resources-for-getting-started-with-generative-adversarial-networks/)), for instances, were all generated using GANs:
#
# <img src="https://3qeqpr26caki16dnhd19sv6by6v-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Example-of-Photorealistic-Human-Faces-Generated-by-a-GAN.png" alt="gans_results" width="480">
#
#
# GANs however, can be notoriously difficult to train, and are extremely sensitive to hyperparameters, activation functions and regularization. In this tutorial, we'll train a GAN to generate images of handwritten digits similar to those from the Fashion MNIST database.
#
# <img src="https://datasets.activeloop.ai/wp-content/uploads/2022/09/Fashion-MNIST-dataset-Activeloop-Platform-visualization-image.webp" width="360" >
#
# Most of the code for this tutorial has been borrowed for this excellent repository of PyTorch tutorials: [github.com/yunjey/pytorch-tutorial](https://github.com/yunjey/pytorch-tutorial). Here's what we're going to do:
#
# * Define the problem statement
# * Load the data (with transforms and normalization)
#     * Denormalize for visual inspection of samples
# * Define the Discriminator network
#     * Study the activation function: Leaky ReLU
# * Define the Generator network
#     * Explain the output activation function: TanH
#     * Look at some sample outputs
# * Define losses, optimizers and helper functions for training
#     * For discriminator
#     * For generator
# * Train the model
#     * Save intermediate generated images to file
# * Look at some outputs
# * Save the models
# * Commit to Jovian.ml

# %% [markdown]
# #Step1. Load the Fashion MNIST dataset
#
# ## Load the Data
#
# We begin by downloading and importing the data as a PyTorch dataset using the `MNIST` helper class from `torchvision.datasets`.

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import FashionMNIST

mnist = FashionMNIST(root='data',
              train=True,
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:02<00:00, 12535506.30it/s]
# Extracting data/FashionMNIST/raw/train-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 209130.99it/s]
# Extracting data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:01<00:00, 3879244.18it/s]
# Extracting data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 3449796.61it/s]
# Extracting data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw

# %% [markdown]
# Note that we are are transforming the pixel values from the range `[0, 1]` to the range `[-1, 1]`. The reason for doing this will become clear when define the generator network. Let's look at a sample tensor from the data.

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  9
# tensor([[[-1.0000, -1.0000, -1.0000,  0.5137,  0.7882],
#          [-0.9765, -1.0000, -0.9059,  0.7176,  0.7255],
#          [-0.9529, -1.0000, -0.2235,  0.9137,  0.7412],
#          [-1.0000, -1.0000, -0.5686,  0.8510,  0.7882],
#          [-1.0000, -1.0000,  0.8588,  0.7725,  0.7020]]])
# (tensor(-1.), tensor(1.))

# %% [markdown]
# There are total 9 classes
#
# As expected, the pixel values range from -1 to 1. Let's define a helper to denormalize and view the images. This function will also be useful for viewing the generated images.
#
# (tensor(-1.), tensor(1.))

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 9

# %% [markdown]
# Finally, let's create a dataloader to load the images in batches.

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([0, 1, 4, 7, 5, 6, 0, 1, 6, 3, 7, 9, 6, 9, 4, 5, 1, 9, 4, 3, 0, 5, 6, 3,
#         6, 1, 1, 2, 3, 0, 8, 9, 4, 6, 8, 7, 1, 7, 0, 1, 7, 6, 7, 0, 5, 9, 4, 4,
#         4, 1, 0, 6, 0, 4, 3, 8, 6, 4, 8, 0, 8, 4, 2, 7, 4, 1, 4, 6, 8, 0, 9, 6,
#         5, 0, 4, 5, 7, 1, 2, 1, 5, 4, 3, 7, 4, 9, 4, 9, 2, 9, 6, 3, 6, 5, 2, 8,
#         7, 6, 8, 4])

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## Discriminator Network
#
# The discriminator takes an image as input, and tries to classify it as "real" or "generated". In this sense, it's like any other neural network. While we can use a CNN for the discriminator, we'll use a simple feedforward network with 3 linear layers to keep things since. We'll treat each 28x28 image as a vector of size 784.

# %%
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %% [markdown]
# We use the Leaky ReLU activation for the discriminator.
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*ypsvQH7kvtI2BhzR2eT_Sw.png" width="420">
#
#
# >  Different from the regular ReLU function, Leaky ReLU allows the pass of a small gradient signal for negative values. As a result, it makes the gradients from the discriminator flows stronger into the generator. Instead of passing a gradient (slope) of 0 in the back-prop pass, it passes a small negative gradient.  - [Source](https://sthalles.github.io/advanced_gans/)
#
# Just like any other binary classification model, the output of the discriminator is a single number between 0 and 1, which can be interpreted as the probability of the input image being fake i.e. generated.
#
# Let's move the discriminator model to the chosen device.
#
# In the context of PyTorch or similar deep learning frameworks, the expression D.to(device) is used to move a tensor or a model to a specific device for computation, such as a CPU or a GPU. Let me break it down for you:
#
# Tensor or Model: D represents either a tensor (data) or a model (neural network) object in PyTorch.
#
# .to(device): This is a method in PyTorch that allows you to specify the device where you want to perform computations. The device argument specifies the target device, which can be a CPU or a GPU. For example:
#
# device='cpu': Indicates that computations should be performed on the CPU.
# device='cuda:0' or device='cuda:1': Indicates that computations should be performed on a specific GPU. The number after cuda: refers to the GPU index.

# %%
D.to(device);

# %% [markdown]
# ## Generator Network
#
# The input to the generator is typically a vector or a matrix which is used as a seed for generating an image. Once again, to keep things simple, we'll use a feedfoward neural network with 3 layers, and the output will be a vector of size 784, which can be transformed to a 28x28 px image.

# %% [markdown]
# Generative Adversarial Networks (GANs), the term latent_size = 64 typically refers to the dimensionality of the latent space.
#
# Latent Space: The latent space is a lower-dimensional space where the model learns to represent the underlying structure or features of the input data in a more compact form. In VAEs and GANs, the latent space represents the space of encoded or generated data points.
#
# The latent_size = 64 statement indicates that the dimensionality of the latent space is 64. This means that each data point in the latent space is represented by a vector of 64 numbers.

# %%
latent_size = 64

# %%
G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %% [markdown]
# We use the TanH activation function for the output layer of the generator.
#
# <img src="https://nic.schraudolph.org/teach/NNcourse/figs/tanh.gif" width="420" >
#
# > "The ReLU activation (Nair & Hinton, 2010) is used in the generator with the exception of the output layer which uses the Tanh function. We observed that using a bounded activation allowed the model to learn more quickly to saturate and cover the color space of the training distribution. Within the discriminator we found the leaky rectified activation (Maas et al., 2013) (Xu et al., 2015) to work well, especially for higher resolution modeling." - [Source](https://stackoverflow.com/questions/41489907/generative-adversarial-networks-tanh)
#
#
# Note that since the outputs of the TanH activation lie in the range `[-1,1]`, we have applied the same transformation to the images in the training dataset. Let's generate an output vector using the generator and view it as an image by transforming and denormalizing the output.

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %% [markdown]
# As one might expect, the output from the generator is basically random noise. Let's define a helper function which can save a batch of outputs from the generator to a file.
#
# Let's move the generator to the chosen device.

# %%
G.to(device);

# %% [markdown]
# ## Discriminator Training
#
# Since the discriminator is a binary classification model, we can use the binary cross entropy loss function to quantify how well it is able to differentiate between real and generated images.
#
# <img src="https://image.slidesharecdn.com/chrishokamp-dublinnlp3-160805110319/95/task-based-learning-for-nlp-going-beyond-cross-entropy-chris-hokamp-10-638.jpg?cb=1470395213" width="420" >

# %%
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %% [markdown]
# Let's define helper functions to reset gradients and  train the discriminator.

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)

    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()

    return d_loss, real_score, fake_score

# %% [markdown]
# Here are the steps involved in training the discriminator.
#
# - We expect the discriminator to output 1 if the image was picked from the real MNIST dataset, and 0 if it was generated.
#
# - We first pass a batch of real images, and compute the loss, setting the target labels to 1.
#
# - Then, we generate a batch of fake images using the generator, pass them into the discriminator, and compute the loss, setting the target labels to 0.
#
# - Finally we add the two losses and use the overall loss to perform gradient descent to adjust the weights of the discriminator.
#
# It's important to note that we don't change the weights of the generator model while training the discriminator (`d_optimizer` only affects the `D.parameters()`)

# %% [markdown]
# # Step2. Train the GAN model to produce images in this new domain.

# %% [markdown]
# ## Generator Training
#
# Since the outputs of the generator are images, it's not obvious how we can train the generator. This is where we employ a rather elegant trick, which is to use the discriminator as a part of the loss function. Here's how it works:
#
# - We generate a batch of images using the generator, pass the into the discriminator.
#
# - We calculate the loss by setting the target labels to 1 i.e. real. We do this because the generator's objective is to "fool" the discriminator.
#
# - We use the loss to perform gradient descent i.e. change the weights of the generator, so it gets better at generating real-like images.
#
# Here's what this looks like in code.

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# ## Training the Model
#
# Let's create a directory where we can save intermediate outputs from the generator to visually inspect the progress of the model

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break

Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# We'll also define a helper function to save a batch of generated images to disk at the end of every epoch. We'll use a fixed set of input vectors to the generator to see how the individual generated images evolve over time as we train the model.

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)

# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# We are now ready to train the model. In each epoch, we train the discriminator first, and then the generator. The training might take a while if you're not using a GPU.

# %%
# %%time

num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)

        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.0504, g_loss: 4.5076, D(x): 0.99, D(G(z)): 0.04
# Epoch [0/300], Step [400/600], d_loss: 0.0977, g_loss: 5.1522, D(x): 0.96, D(G(z)): 0.04
# Epoch [0/300], Step [600/600], d_loss: 0.0600, g_loss: 4.4560, D(x): 0.98, D(G(z)): 0.03
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.0405, g_loss: 4.5677, D(x): 0.99, D(G(z)): 0.02
# Epoch [1/300], Step [400/600], d_loss: 0.0537, g_loss: 5.0806, D(x): 0.98, D(G(z)): 0.01
# Epoch [1/300], Step [600/600], d_loss: 0.0289, g_loss: 6.2339, D(x): 0.99, D(G(z)): 0.00
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.0143, g_loss: 7.0586, D(x): 0.99, D(G(z)): 0.00
# Epoch [2/300], Step [400/600], d_loss: 0.0681, g_loss: 6.5366, D(x): 1.00, D(G(z)): 0.05
# Epoch [2/300], Step [600/600], d_loss: 0.1108, g_loss: 6.6069, D(x): 0.95, D(G(z)): 0.02
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 0.1249, g_loss: 5.2713, D(x): 0.98, D(G(z)): 0.04
# Epoch [3/300], Step [400/600], d_loss: 0.0706, g_loss: 6.5211, D(x): 0.96, D(G(z)): 0.02
# Epoch [3/300], Step [600/600], d_loss: 0.1313, g_loss: 5.5473, D(x): 0.96, D(G(z)): 0.03
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.1211, g_loss: 5.6639, D(x): 0.96, D(G(z)): 0.02
# Epoch [4/300], Step [400/600], d_loss: 0.2130, g_loss: 6.1261, D(x): 0.97, D(G(z)): 0.04
# Epoch [4/300], Step [600/600], d_loss: 0.0340, g_loss: 6.2161, D(x): 0.99, D(G(z)): 0.02
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.1222, g_loss: 7.9533, D(x): 0.97, D(G(z)): 0.01
# Epoch [5/300], Step [400/600], d_loss: 0.1485, g_loss: 4.1486, D(x): 0.93, D(G(z)): 0.02
# Epoch [5/300], Step [600/600], d_loss: 0.1946, g_loss: 6.2327, D(x): 0.95, D(G(z)): 0.04
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.3049, g_loss: 5.8541, D(x): 0.95, D(G(z)): 0.14
# Epoch [6/300], Step [400/600], d_loss: 0.2558, g_loss: 5.3405, D(x): 0.96, D(G(z)): 0.10
# Epoch [6/300], Step [600/600], d_loss: 0.1683, g_loss: 4.9940, D(x): 0.94, D(G(z)): 0.04
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.3505, g_loss: 5.2722, D(x): 0.99, D(G(z)): 0.17
# Epoch [7/300], Step [400/600], d_loss: 0.1434, g_loss: 4.8585, D(x): 0.97, D(G(z)): 0.07
# Epoch [7/300], Step [600/600], d_loss: 0.1998, g_loss: 5.2227, D(x): 0.93, D(G(z)): 0.03
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.1443, g_loss: 4.8024, D(x): 0.97, D(G(z)): 0.08
# Epoch [8/300], Step [400/600], d_loss: 0.2896, g_loss: 5.1227, D(x): 0.95, D(G(z)): 0.08
# Epoch [8/300], Step [600/600], d_loss: 0.0738, g_loss: 7.3926, D(x): 0.96, D(G(z)): 0.01
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.2595, g_loss: 4.8908, D(x): 0.90, D(G(z)): 0.03
# Epoch [9/300], Step [400/600], d_loss: 0.3056, g_loss: 5.4079, D(x): 0.91, D(G(z)): 0.06
# Epoch [9/300], Step [600/600], d_loss: 0.1751, g_loss: 5.1736, D(x): 0.93, D(G(z)): 0.03
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.2737, g_loss: 4.6386, D(x): 0.93, D(G(z)): 0.09
# Epoch [10/300], Step [400/600], d_loss: 0.4061, g_loss: 3.6701, D(x): 0.93, D(G(z)): 0.18
# Epoch [10/300], Step [600/600], d_loss: 0.5436, g_loss: 5.6594, D(x): 0.86, D(G(z)): 0.06
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.3187, g_loss: 5.4616, D(x): 0.90, D(G(z)): 0.03
# Epoch [11/300], Step [400/600], d_loss: 0.3645, g_loss: 4.2749, D(x): 0.89, D(G(z)): 0.02
# Epoch [11/300], Step [600/600], d_loss: 0.1936, g_loss: 4.3759, D(x): 0.94, D(G(z)): 0.06
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.3610, g_loss: 3.3209, D(x): 0.91, D(G(z)): 0.11
# Epoch [12/300], Step [400/600], d_loss: 0.3802, g_loss: 4.3459, D(x): 0.92, D(G(z)): 0.13
# Epoch [12/300], Step [600/600], d_loss: 0.2622, g_loss: 3.9962, D(x): 0.93, D(G(z)): 0.12
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.4762, g_loss: 3.3471, D(x): 0.86, D(G(z)): 0.14
# Epoch [13/300], Step [400/600], d_loss: 0.2305, g_loss: 3.9659, D(x): 0.94, D(G(z)): 0.09
# Epoch [13/300], Step [600/600], d_loss: 0.4212, g_loss: 4.7519, D(x): 0.93, D(G(z)): 0.09
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.4293, g_loss: 4.0824, D(x): 0.89, D(G(z)): 0.10
# Epoch [14/300], Step [400/600], d_loss: 0.3970, g_loss: 5.0696, D(x): 0.87, D(G(z)): 0.06
# Epoch [14/300], Step [600/600], d_loss: 0.4668, g_loss: 4.1579, D(x): 0.85, D(G(z)): 0.06
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.3875, g_loss: 3.7598, D(x): 0.90, D(G(z)): 0.08
# Epoch [15/300], Step [400/600], d_loss: 0.5729, g_loss: 3.4862, D(x): 0.86, D(G(z)): 0.19
# Epoch [15/300], Step [600/600], d_loss: 0.5305, g_loss: 3.7141, D(x): 0.97, D(G(z)): 0.32
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.3690, g_loss: 3.8241, D(x): 0.86, D(G(z)): 0.07
# Epoch [16/300], Step [400/600], d_loss: 0.2991, g_loss: 4.5193, D(x): 0.93, D(G(z)): 0.09
# Epoch [16/300], Step [600/600], d_loss: 0.4494, g_loss: 2.8615, D(x): 0.93, D(G(z)): 0.23
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.1925, g_loss: 3.8815, D(x): 0.92, D(G(z)): 0.06
# Epoch [17/300], Step [400/600], d_loss: 0.3748, g_loss: 3.7705, D(x): 0.89, D(G(z)): 0.11
# Epoch [17/300], Step [600/600], d_loss: 0.3793, g_loss: 3.3657, D(x): 0.87, D(G(z)): 0.07
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.7654, g_loss: 4.2775, D(x): 0.80, D(G(z)): 0.07
# Epoch [18/300], Step [400/600], d_loss: 0.3740, g_loss: 2.9315, D(x): 0.87, D(G(z)): 0.10
# Epoch [18/300], Step [600/600], d_loss: 0.3391, g_loss: 3.5581, D(x): 0.92, D(G(z)): 0.14
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.6684, g_loss: 2.7883, D(x): 0.86, D(G(z)): 0.21
# Epoch [19/300], Step [400/600], d_loss: 0.4933, g_loss: 3.2692, D(x): 0.84, D(G(z)): 0.08
# Epoch [19/300], Step [600/600], d_loss: 0.3729, g_loss: 3.3488, D(x): 0.89, D(G(z)): 0.13
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.3964, g_loss: 3.0617, D(x): 0.85, D(G(z)): 0.07
# Epoch [20/300], Step [400/600], d_loss: 0.4940, g_loss: 3.6229, D(x): 0.82, D(G(z)): 0.07
# Epoch [20/300], Step [600/600], d_loss: 0.2764, g_loss: 3.4046, D(x): 0.93, D(G(z)): 0.10
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.2970, g_loss: 3.4192, D(x): 0.87, D(G(z)): 0.09
# Epoch [21/300], Step [400/600], d_loss: 0.3213, g_loss: 2.5768, D(x): 0.92, D(G(z)): 0.16
# Epoch [21/300], Step [600/600], d_loss: 0.4225, g_loss: 3.4372, D(x): 0.90, D(G(z)): 0.16
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.2779, g_loss: 3.8853, D(x): 0.91, D(G(z)): 0.10
# Epoch [22/300], Step [400/600], d_loss: 0.4200, g_loss: 3.0853, D(x): 0.88, D(G(z)): 0.15
# Epoch [22/300], Step [600/600], d_loss: 0.4079, g_loss: 2.8966, D(x): 0.87, D(G(z)): 0.13
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.6113, g_loss: 3.8153, D(x): 0.81, D(G(z)): 0.08
# Epoch [23/300], Step [400/600], d_loss: 0.3842, g_loss: 3.1328, D(x): 0.88, D(G(z)): 0.13
# Epoch [23/300], Step [600/600], d_loss: 0.4489, g_loss: 2.8307, D(x): 0.85, D(G(z)): 0.13
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.4838, g_loss: 2.9368, D(x): 0.90, D(G(z)): 0.21
# Epoch [24/300], Step [400/600], d_loss: 0.6795, g_loss: 2.2889, D(x): 0.79, D(G(z)): 0.15
# Epoch [24/300], Step [600/600], d_loss: 0.5143, g_loss: 3.3010, D(x): 0.88, D(G(z)): 0.21
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.2943, g_loss: 3.5940, D(x): 0.89, D(G(z)): 0.09
# Epoch [25/300], Step [400/600], d_loss: 0.6290, g_loss: 2.2982, D(x): 0.80, D(G(z)): 0.18
# Epoch [25/300], Step [600/600], d_loss: 0.4689, g_loss: 2.5914, D(x): 0.86, D(G(z)): 0.16
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.5516, g_loss: 2.9952, D(x): 0.88, D(G(z)): 0.20
# Epoch [26/300], Step [400/600], d_loss: 0.5297, g_loss: 4.1704, D(x): 0.81, D(G(z)): 0.07
# Epoch [26/300], Step [600/600], d_loss: 0.5761, g_loss: 1.9962, D(x): 0.86, D(G(z)): 0.22
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.5114, g_loss: 3.5025, D(x): 0.83, D(G(z)): 0.15
# Epoch [27/300], Step [400/600], d_loss: 0.5011, g_loss: 2.5338, D(x): 0.85, D(G(z)): 0.18
# Epoch [27/300], Step [600/600], d_loss: 0.3951, g_loss: 2.0911, D(x): 0.84, D(G(z)): 0.12
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.6470, g_loss: 2.9966, D(x): 0.80, D(G(z)): 0.17
# Epoch [28/300], Step [400/600], d_loss: 0.4692, g_loss: 2.8627, D(x): 0.91, D(G(z)): 0.23
# Epoch [28/300], Step [600/600], d_loss: 0.5035, g_loss: 2.1628, D(x): 0.85, D(G(z)): 0.16
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.6765, g_loss: 3.5967, D(x): 0.81, D(G(z)): 0.17
# Epoch [29/300], Step [400/600], d_loss: 0.4367, g_loss: 4.3220, D(x): 0.83, D(G(z)): 0.07
# Epoch [29/300], Step [600/600], d_loss: 0.5248, g_loss: 3.3237, D(x): 0.84, D(G(z)): 0.11
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.6240, g_loss: 3.8361, D(x): 0.85, D(G(z)): 0.20
# Epoch [30/300], Step [400/600], d_loss: 0.4388, g_loss: 3.4268, D(x): 0.84, D(G(z)): 0.11
# Epoch [30/300], Step [600/600], d_loss: 0.6842, g_loss: 2.3780, D(x): 0.82, D(G(z)): 0.22
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.4006, g_loss: 2.9937, D(x): 0.90, D(G(z)): 0.19
# Epoch [31/300], Step [400/600], d_loss: 0.5345, g_loss: 2.5243, D(x): 0.81, D(G(z)): 0.14
# Epoch [31/300], Step [600/600], d_loss: 0.5968, g_loss: 3.0837, D(x): 0.82, D(G(z)): 0.18
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.4951, g_loss: 2.8729, D(x): 0.83, D(G(z)): 0.11
# Epoch [32/300], Step [400/600], d_loss: 0.6493, g_loss: 2.5631, D(x): 0.87, D(G(z)): 0.28
# Epoch [32/300], Step [600/600], d_loss: 0.4239, g_loss: 2.8845, D(x): 0.86, D(G(z)): 0.15
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.4146, g_loss: 3.9120, D(x): 0.85, D(G(z)): 0.10
# Epoch [33/300], Step [400/600], d_loss: 0.3762, g_loss: 3.3043, D(x): 0.85, D(G(z)): 0.08
# Epoch [33/300], Step [600/600], d_loss: 0.5405, g_loss: 3.0847, D(x): 0.81, D(G(z)): 0.15
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.4109, g_loss: 2.5505, D(x): 0.91, D(G(z)): 0.20
# Epoch [34/300], Step [400/600], d_loss: 0.4703, g_loss: 3.4901, D(x): 0.81, D(G(z)): 0.10
# Epoch [34/300], Step [600/600], d_loss: 0.6172, g_loss: 3.1490, D(x): 0.89, D(G(z)): 0.24
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.6751, g_loss: 2.2203, D(x): 0.86, D(G(z)): 0.24
# Epoch [35/300], Step [400/600], d_loss: 0.5525, g_loss: 3.0959, D(x): 0.84, D(G(z)): 0.17
# Epoch [35/300], Step [600/600], d_loss: 0.7210, g_loss: 3.5598, D(x): 0.77, D(G(z)): 0.12
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.6776, g_loss: 3.8854, D(x): 0.76, D(G(z)): 0.10
# Epoch [36/300], Step [400/600], d_loss: 0.4566, g_loss: 3.5903, D(x): 0.81, D(G(z)): 0.11
# Epoch [36/300], Step [600/600], d_loss: 0.5793, g_loss: 2.7555, D(x): 0.78, D(G(z)): 0.13
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.5014, g_loss: 3.1009, D(x): 0.88, D(G(z)): 0.18
# Epoch [37/300], Step [400/600], d_loss: 0.8226, g_loss: 3.2480, D(x): 0.80, D(G(z)): 0.19
# Epoch [37/300], Step [600/600], d_loss: 0.6323, g_loss: 2.3162, D(x): 0.77, D(G(z)): 0.13
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.4070, g_loss: 3.3819, D(x): 0.88, D(G(z)): 0.18
# Epoch [38/300], Step [400/600], d_loss: 0.6288, g_loss: 2.5707, D(x): 0.77, D(G(z)): 0.17
# Epoch [38/300], Step [600/600], d_loss: 0.5290, g_loss: 2.5319, D(x): 0.84, D(G(z)): 0.18
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.5286, g_loss: 3.0749, D(x): 0.85, D(G(z)): 0.18
# Epoch [39/300], Step [400/600], d_loss: 0.6119, g_loss: 2.8754, D(x): 0.78, D(G(z)): 0.15
# Epoch [39/300], Step [600/600], d_loss: 0.4056, g_loss: 2.5473, D(x): 0.93, D(G(z)): 0.24
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.3486, g_loss: 3.3708, D(x): 0.89, D(G(z)): 0.15
# Epoch [40/300], Step [400/600], d_loss: 0.5868, g_loss: 2.5772, D(x): 0.79, D(G(z)): 0.14
# Epoch [40/300], Step [600/600], d_loss: 0.6887, g_loss: 2.8153, D(x): 0.77, D(G(z)): 0.14
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.7408, g_loss: 2.5469, D(x): 0.73, D(G(z)): 0.18
# Epoch [41/300], Step [400/600], d_loss: 0.4329, g_loss: 2.7807, D(x): 0.83, D(G(z)): 0.13
# Epoch [41/300], Step [600/600], d_loss: 0.5475, g_loss: 2.5204, D(x): 0.80, D(G(z)): 0.16
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.3992, g_loss: 2.7957, D(x): 0.86, D(G(z)): 0.15
# Epoch [42/300], Step [400/600], d_loss: 0.6287, g_loss: 2.9829, D(x): 0.84, D(G(z)): 0.27
# Epoch [42/300], Step [600/600], d_loss: 0.4439, g_loss: 3.4523, D(x): 0.85, D(G(z)): 0.13
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.4517, g_loss: 2.6209, D(x): 0.84, D(G(z)): 0.14
# Epoch [43/300], Step [400/600], d_loss: 0.4505, g_loss: 2.1649, D(x): 0.85, D(G(z)): 0.16
# Epoch [43/300], Step [600/600], d_loss: 0.7008, g_loss: 2.6016, D(x): 0.78, D(G(z)): 0.19
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.6304, g_loss: 2.1562, D(x): 0.82, D(G(z)): 0.21
# Epoch [44/300], Step [400/600], d_loss: 0.7046, g_loss: 2.0826, D(x): 0.73, D(G(z)): 0.13
# Epoch [44/300], Step [600/600], d_loss: 0.6193, g_loss: 3.3685, D(x): 0.82, D(G(z)): 0.20
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.6156, g_loss: 2.6409, D(x): 0.84, D(G(z)): 0.26
# Epoch [45/300], Step [400/600], d_loss: 0.7588, g_loss: 1.6182, D(x): 0.75, D(G(z)): 0.21
# Epoch [45/300], Step [600/600], d_loss: 0.5379, g_loss: 2.7438, D(x): 0.82, D(G(z)): 0.18
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.7706, g_loss: 2.7715, D(x): 0.76, D(G(z)): 0.15
# Epoch [46/300], Step [400/600], d_loss: 0.5708, g_loss: 2.9213, D(x): 0.80, D(G(z)): 0.15
# Epoch [46/300], Step [600/600], d_loss: 0.5618, g_loss: 2.5300, D(x): 0.81, D(G(z)): 0.16
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.8729, g_loss: 2.2539, D(x): 0.74, D(G(z)): 0.21
# Epoch [47/300], Step [400/600], d_loss: 0.8920, g_loss: 2.5380, D(x): 0.75, D(G(z)): 0.21
# Epoch [47/300], Step [600/600], d_loss: 0.6221, g_loss: 2.2473, D(x): 0.80, D(G(z)): 0.21
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.7308, g_loss: 2.8607, D(x): 0.81, D(G(z)): 0.21
# Epoch [48/300], Step [400/600], d_loss: 0.6700, g_loss: 2.9298, D(x): 0.77, D(G(z)): 0.14
# Epoch [48/300], Step [600/600], d_loss: 0.5966, g_loss: 3.0201, D(x): 0.80, D(G(z)): 0.13
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.5025, g_loss: 2.9618, D(x): 0.84, D(G(z)): 0.17
# Epoch [49/300], Step [400/600], d_loss: 0.5615, g_loss: 2.9197, D(x): 0.80, D(G(z)): 0.14
# Epoch [49/300], Step [600/600], d_loss: 0.5480, g_loss: 2.8180, D(x): 0.85, D(G(z)): 0.21
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.5612, g_loss: 2.5621, D(x): 0.79, D(G(z)): 0.15
# Epoch [50/300], Step [400/600], d_loss: 0.5703, g_loss: 2.7620, D(x): 0.84, D(G(z)): 0.23
# Epoch [50/300], Step [600/600], d_loss: 0.6985, g_loss: 3.0928, D(x): 0.76, D(G(z)): 0.15
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.5644, g_loss: 2.8515, D(x): 0.86, D(G(z)): 0.25
# Epoch [51/300], Step [400/600], d_loss: 0.6356, g_loss: 2.0538, D(x): 0.78, D(G(z)): 0.22
# Epoch [51/300], Step [600/600], d_loss: 0.6794, g_loss: 3.1005, D(x): 0.76, D(G(z)): 0.14
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.8235, g_loss: 2.3340, D(x): 0.85, D(G(z)): 0.36
# Epoch [52/300], Step [400/600], d_loss: 0.4983, g_loss: 2.5017, D(x): 0.87, D(G(z)): 0.21
# Epoch [52/300], Step [600/600], d_loss: 0.8084, g_loss: 2.4121, D(x): 0.79, D(G(z)): 0.28
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.6205, g_loss: 2.5063, D(x): 0.79, D(G(z)): 0.20
# Epoch [53/300], Step [400/600], d_loss: 0.4590, g_loss: 2.5667, D(x): 0.87, D(G(z)): 0.19
# Epoch [53/300], Step [600/600], d_loss: 0.7483, g_loss: 2.4025, D(x): 0.78, D(G(z)): 0.25
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.8614, g_loss: 2.9132, D(x): 0.75, D(G(z)): 0.22
# Epoch [54/300], Step [400/600], d_loss: 0.4881, g_loss: 2.5099, D(x): 0.86, D(G(z)): 0.17
# Epoch [54/300], Step [600/600], d_loss: 0.5183, g_loss: 2.4670, D(x): 0.86, D(G(z)): 0.19
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.7580, g_loss: 2.4627, D(x): 0.74, D(G(z)): 0.20
# Epoch [55/300], Step [400/600], d_loss: 0.4736, g_loss: 2.4550, D(x): 0.90, D(G(z)): 0.21
# Epoch [55/300], Step [600/600], d_loss: 0.7594, g_loss: 1.7661, D(x): 0.75, D(G(z)): 0.19
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.5637, g_loss: 2.6348, D(x): 0.83, D(G(z)): 0.22
# Epoch [56/300], Step [400/600], d_loss: 0.9888, g_loss: 1.9016, D(x): 0.79, D(G(z)): 0.31
# Epoch [56/300], Step [600/600], d_loss: 0.6565, g_loss: 2.2741, D(x): 0.78, D(G(z)): 0.25
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.7517, g_loss: 2.5417, D(x): 0.81, D(G(z)): 0.23
# Epoch [57/300], Step [400/600], d_loss: 0.7565, g_loss: 2.1305, D(x): 0.83, D(G(z)): 0.30
# Epoch [57/300], Step [600/600], d_loss: 0.7862, g_loss: 2.1803, D(x): 0.73, D(G(z)): 0.18
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.6996, g_loss: 2.7721, D(x): 0.77, D(G(z)): 0.17
# Epoch [58/300], Step [400/600], d_loss: 0.6252, g_loss: 2.2877, D(x): 0.81, D(G(z)): 0.21
# Epoch [58/300], Step [600/600], d_loss: 0.5874, g_loss: 2.0068, D(x): 0.83, D(G(z)): 0.25
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 0.4842, g_loss: 2.1256, D(x): 0.81, D(G(z)): 0.16
# Epoch [59/300], Step [400/600], d_loss: 0.6160, g_loss: 2.1356, D(x): 0.81, D(G(z)): 0.22
# Epoch [59/300], Step [600/600], d_loss: 0.6570, g_loss: 2.2364, D(x): 0.78, D(G(z)): 0.22
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.9386, g_loss: 2.3450, D(x): 0.70, D(G(z)): 0.25
# Epoch [60/300], Step [400/600], d_loss: 0.5471, g_loss: 1.9345, D(x): 0.80, D(G(z)): 0.18
# Epoch [60/300], Step [600/600], d_loss: 0.5145, g_loss: 2.1474, D(x): 0.86, D(G(z)): 0.24
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.9177, g_loss: 2.6646, D(x): 0.63, D(G(z)): 0.12
# Epoch [61/300], Step [400/600], d_loss: 0.7986, g_loss: 2.4843, D(x): 0.68, D(G(z)): 0.14
# Epoch [61/300], Step [600/600], d_loss: 0.5161, g_loss: 2.9383, D(x): 0.80, D(G(z)): 0.14
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.4874, g_loss: 2.2096, D(x): 0.86, D(G(z)): 0.22
# Epoch [62/300], Step [400/600], d_loss: 0.9403, g_loss: 2.0136, D(x): 0.73, D(G(z)): 0.30
# Epoch [62/300], Step [600/600], d_loss: 0.7722, g_loss: 1.7539, D(x): 0.71, D(G(z)): 0.20
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.6958, g_loss: 2.2697, D(x): 0.76, D(G(z)): 0.21
# Epoch [63/300], Step [400/600], d_loss: 0.5466, g_loss: 2.4431, D(x): 0.89, D(G(z)): 0.27
# Epoch [63/300], Step [600/600], d_loss: 0.8120, g_loss: 2.3341, D(x): 0.77, D(G(z)): 0.28
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.6344, g_loss: 1.8525, D(x): 0.79, D(G(z)): 0.22
# Epoch [64/300], Step [400/600], d_loss: 0.6597, g_loss: 1.7051, D(x): 0.82, D(G(z)): 0.24
# Epoch [64/300], Step [600/600], d_loss: 0.6605, g_loss: 2.0322, D(x): 0.85, D(G(z)): 0.27
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 0.8320, g_loss: 2.0435, D(x): 0.73, D(G(z)): 0.24
# Epoch [65/300], Step [400/600], d_loss: 0.6884, g_loss: 2.3367, D(x): 0.74, D(G(z)): 0.17
# Epoch [65/300], Step [600/600], d_loss: 0.6090, g_loss: 2.2627, D(x): 0.82, D(G(z)): 0.23
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.6279, g_loss: 2.6274, D(x): 0.86, D(G(z)): 0.26
# Epoch [66/300], Step [400/600], d_loss: 0.6899, g_loss: 2.4766, D(x): 0.76, D(G(z)): 0.20
# Epoch [66/300], Step [600/600], d_loss: 0.8372, g_loss: 2.2726, D(x): 0.71, D(G(z)): 0.22
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.7209, g_loss: 1.5095, D(x): 0.78, D(G(z)): 0.25
# Epoch [67/300], Step [400/600], d_loss: 0.6135, g_loss: 2.3456, D(x): 0.82, D(G(z)): 0.22
# Epoch [67/300], Step [600/600], d_loss: 0.8151, g_loss: 2.5161, D(x): 0.74, D(G(z)): 0.24
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.6867, g_loss: 2.9037, D(x): 0.75, D(G(z)): 0.18
# Epoch [68/300], Step [400/600], d_loss: 0.6825, g_loss: 2.1790, D(x): 0.76, D(G(z)): 0.19
# Epoch [68/300], Step [600/600], d_loss: 0.5302, g_loss: 2.1790, D(x): 0.79, D(G(z)): 0.16
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 0.8848, g_loss: 1.8991, D(x): 0.71, D(G(z)): 0.26
# Epoch [69/300], Step [400/600], d_loss: 0.8311, g_loss: 2.0080, D(x): 0.74, D(G(z)): 0.21
# Epoch [69/300], Step [600/600], d_loss: 0.6755, g_loss: 2.1033, D(x): 0.76, D(G(z)): 0.21
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 1.0278, g_loss: 1.6996, D(x): 0.66, D(G(z)): 0.25
# Epoch [70/300], Step [400/600], d_loss: 0.8217, g_loss: 2.3372, D(x): 0.80, D(G(z)): 0.27
# Epoch [70/300], Step [600/600], d_loss: 0.9950, g_loss: 2.2386, D(x): 0.74, D(G(z)): 0.33
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.5993, g_loss: 2.6481, D(x): 0.82, D(G(z)): 0.21
# Epoch [71/300], Step [400/600], d_loss: 0.8186, g_loss: 2.0694, D(x): 0.73, D(G(z)): 0.22
# Epoch [71/300], Step [600/600], d_loss: 0.8763, g_loss: 2.2193, D(x): 0.67, D(G(z)): 0.20
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.5417, g_loss: 1.9379, D(x): 0.82, D(G(z)): 0.20
# Epoch [72/300], Step [400/600], d_loss: 0.6790, g_loss: 2.7281, D(x): 0.79, D(G(z)): 0.26
# Epoch [72/300], Step [600/600], d_loss: 0.8242, g_loss: 1.7998, D(x): 0.80, D(G(z)): 0.34
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.7036, g_loss: 1.6679, D(x): 0.76, D(G(z)): 0.24
# Epoch [73/300], Step [400/600], d_loss: 0.8332, g_loss: 1.5640, D(x): 0.84, D(G(z)): 0.37
# Epoch [73/300], Step [600/600], d_loss: 0.6775, g_loss: 1.8745, D(x): 0.78, D(G(z)): 0.23
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.8683, g_loss: 1.8234, D(x): 0.78, D(G(z)): 0.32
# Epoch [74/300], Step [400/600], d_loss: 0.7086, g_loss: 2.1856, D(x): 0.77, D(G(z)): 0.23
# Epoch [74/300], Step [600/600], d_loss: 0.7479, g_loss: 2.1727, D(x): 0.80, D(G(z)): 0.30
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 1.1019, g_loss: 1.6853, D(x): 0.68, D(G(z)): 0.34
# Epoch [75/300], Step [400/600], d_loss: 0.7024, g_loss: 1.8233, D(x): 0.81, D(G(z)): 0.27
# Epoch [75/300], Step [600/600], d_loss: 0.7025, g_loss: 1.8832, D(x): 0.78, D(G(z)): 0.28
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.9361, g_loss: 2.3355, D(x): 0.71, D(G(z)): 0.23
# Epoch [76/300], Step [400/600], d_loss: 0.9479, g_loss: 1.9113, D(x): 0.75, D(G(z)): 0.31
# Epoch [76/300], Step [600/600], d_loss: 0.6925, g_loss: 1.8412, D(x): 0.78, D(G(z)): 0.25
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.9327, g_loss: 2.0979, D(x): 0.71, D(G(z)): 0.26
# Epoch [77/300], Step [400/600], d_loss: 0.6127, g_loss: 1.9048, D(x): 0.81, D(G(z)): 0.21
# Epoch [77/300], Step [600/600], d_loss: 0.9933, g_loss: 2.2709, D(x): 0.67, D(G(z)): 0.22
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.9095, g_loss: 2.1401, D(x): 0.69, D(G(z)): 0.25
# Epoch [78/300], Step [400/600], d_loss: 0.6533, g_loss: 2.8491, D(x): 0.74, D(G(z)): 0.17
# Epoch [78/300], Step [600/600], d_loss: 0.6418, g_loss: 2.5033, D(x): 0.78, D(G(z)): 0.19
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 0.9040, g_loss: 1.6038, D(x): 0.74, D(G(z)): 0.31
# Epoch [79/300], Step [400/600], d_loss: 0.9470, g_loss: 1.9681, D(x): 0.74, D(G(z)): 0.34
# Epoch [79/300], Step [600/600], d_loss: 0.5802, g_loss: 2.1291, D(x): 0.80, D(G(z)): 0.21
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 0.8109, g_loss: 2.1730, D(x): 0.77, D(G(z)): 0.29
# Epoch [80/300], Step [400/600], d_loss: 0.8912, g_loss: 1.9423, D(x): 0.65, D(G(z)): 0.20
# Epoch [80/300], Step [600/600], d_loss: 0.6501, g_loss: 2.3878, D(x): 0.78, D(G(z)): 0.20
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 0.9898, g_loss: 2.3459, D(x): 0.64, D(G(z)): 0.21
# Epoch [81/300], Step [400/600], d_loss: 0.5921, g_loss: 1.9643, D(x): 0.78, D(G(z)): 0.20
# Epoch [81/300], Step [600/600], d_loss: 0.9375, g_loss: 2.3127, D(x): 0.80, D(G(z)): 0.33
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 0.8939, g_loss: 1.8933, D(x): 0.75, D(G(z)): 0.31
# Epoch [82/300], Step [400/600], d_loss: 0.6671, g_loss: 2.3173, D(x): 0.74, D(G(z)): 0.20
# Epoch [82/300], Step [600/600], d_loss: 0.6202, g_loss: 2.6510, D(x): 0.80, D(G(z)): 0.21
# Saving fake_images-0083.png
# Epoch [83/300], Step [200/600], d_loss: 0.9237, g_loss: 1.9266, D(x): 0.75, D(G(z)): 0.33
# Epoch [83/300], Step [400/600], d_loss: 0.9529, g_loss: 2.3543, D(x): 0.78, D(G(z)): 0.30
# Epoch [83/300], Step [600/600], d_loss: 0.8294, g_loss: 1.8281, D(x): 0.71, D(G(z)): 0.23
# Saving fake_images-0084.png
# Epoch [84/300], Step [200/600], d_loss: 0.9933, g_loss: 1.6771, D(x): 0.71, D(G(z)): 0.32
# Epoch [84/300], Step [400/600], d_loss: 0.7506, g_loss: 2.1531, D(x): 0.69, D(G(z)): 0.17
# Epoch [84/300], Step [600/600], d_loss: 1.0259, g_loss: 1.6848, D(x): 0.69, D(G(z)): 0.29
# Saving fake_images-0085.png
# Epoch [85/300], Step [200/600], d_loss: 0.6710, g_loss: 1.9967, D(x): 0.79, D(G(z)): 0.24
# Epoch [85/300], Step [400/600], d_loss: 0.6271, g_loss: 1.9591, D(x): 0.75, D(G(z)): 0.18
# Epoch [85/300], Step [600/600], d_loss: 1.0410, g_loss: 1.7044, D(x): 0.77, D(G(z)): 0.39
# Saving fake_images-0086.png
# Epoch [86/300], Step [200/600], d_loss: 0.5697, g_loss: 2.2341, D(x): 0.85, D(G(z)): 0.23
# Epoch [86/300], Step [400/600], d_loss: 0.6728, g_loss: 1.9941, D(x): 0.74, D(G(z)): 0.20
# Epoch [86/300], Step [600/600], d_loss: 0.7137, g_loss: 2.8396, D(x): 0.78, D(G(z)): 0.23
# Saving fake_images-0087.png
# Epoch [87/300], Step [200/600], d_loss: 0.9370, g_loss: 1.9639, D(x): 0.76, D(G(z)): 0.33
# Epoch [87/300], Step [400/600], d_loss: 0.6925, g_loss: 2.2355, D(x): 0.84, D(G(z)): 0.25
# Epoch [87/300], Step [600/600], d_loss: 0.8410, g_loss: 2.1774, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0088.png
# Epoch [88/300], Step [200/600], d_loss: 0.6746, g_loss: 2.2557, D(x): 0.75, D(G(z)): 0.23
# Epoch [88/300], Step [400/600], d_loss: 0.8656, g_loss: 2.0093, D(x): 0.69, D(G(z)): 0.23
# Epoch [88/300], Step [600/600], d_loss: 1.0377, g_loss: 2.0189, D(x): 0.67, D(G(z)): 0.27
# Saving fake_images-0089.png
# Epoch [89/300], Step [200/600], d_loss: 0.7976, g_loss: 1.8378, D(x): 0.75, D(G(z)): 0.27
# Epoch [89/300], Step [400/600], d_loss: 1.0740, g_loss: 1.7260, D(x): 0.65, D(G(z)): 0.27
# Epoch [89/300], Step [600/600], d_loss: 0.6820, g_loss: 2.0254, D(x): 0.80, D(G(z)): 0.27
# Saving fake_images-0090.png
# Epoch [90/300], Step [200/600], d_loss: 1.1578, g_loss: 1.7357, D(x): 0.64, D(G(z)): 0.31
# Epoch [90/300], Step [400/600], d_loss: 0.6234, g_loss: 2.2056, D(x): 0.79, D(G(z)): 0.21
# Epoch [90/300], Step [600/600], d_loss: 0.9716, g_loss: 1.7882, D(x): 0.70, D(G(z)): 0.28
# Saving fake_images-0091.png
# Epoch [91/300], Step [200/600], d_loss: 1.0874, g_loss: 1.7700, D(x): 0.71, D(G(z)): 0.34
# Epoch [91/300], Step [400/600], d_loss: 0.6232, g_loss: 2.0807, D(x): 0.79, D(G(z)): 0.25
# Epoch [91/300], Step [600/600], d_loss: 0.7600, g_loss: 2.2285, D(x): 0.77, D(G(z)): 0.26
# Saving fake_images-0092.png
# Epoch [92/300], Step [200/600], d_loss: 0.7899, g_loss: 1.7422, D(x): 0.69, D(G(z)): 0.22
# Epoch [92/300], Step [400/600], d_loss: 0.8082, g_loss: 1.9483, D(x): 0.76, D(G(z)): 0.28
# Epoch [92/300], Step [600/600], d_loss: 1.1026, g_loss: 2.1130, D(x): 0.71, D(G(z)): 0.36
# Saving fake_images-0093.png
# Epoch [93/300], Step [200/600], d_loss: 1.2206, g_loss: 1.6984, D(x): 0.67, D(G(z)): 0.35
# Epoch [93/300], Step [400/600], d_loss: 0.7677, g_loss: 2.4924, D(x): 0.69, D(G(z)): 0.18
# Epoch [93/300], Step [600/600], d_loss: 0.8358, g_loss: 2.0131, D(x): 0.78, D(G(z)): 0.29
# Saving fake_images-0094.png
# Epoch [94/300], Step [200/600], d_loss: 0.7123, g_loss: 2.0492, D(x): 0.80, D(G(z)): 0.27
# Epoch [94/300], Step [400/600], d_loss: 0.6543, g_loss: 1.8478, D(x): 0.77, D(G(z)): 0.23
# Epoch [94/300], Step [600/600], d_loss: 0.7476, g_loss: 2.4544, D(x): 0.71, D(G(z)): 0.18
# Saving fake_images-0095.png
# Epoch [95/300], Step [200/600], d_loss: 0.9736, g_loss: 1.8960, D(x): 0.68, D(G(z)): 0.24
# Epoch [95/300], Step [400/600], d_loss: 0.9147, g_loss: 1.8563, D(x): 0.66, D(G(z)): 0.22
# Epoch [95/300], Step [600/600], d_loss: 0.6061, g_loss: 2.1414, D(x): 0.81, D(G(z)): 0.27
# Saving fake_images-0096.png
# Epoch [96/300], Step [200/600], d_loss: 0.9132, g_loss: 1.9851, D(x): 0.70, D(G(z)): 0.27
# Epoch [96/300], Step [400/600], d_loss: 1.1547, g_loss: 1.7187, D(x): 0.66, D(G(z)): 0.34
# Epoch [96/300], Step [600/600], d_loss: 0.6831, g_loss: 2.0773, D(x): 0.74, D(G(z)): 0.22
# Saving fake_images-0097.png
# Epoch [97/300], Step [200/600], d_loss: 1.1903, g_loss: 2.0138, D(x): 0.70, D(G(z)): 0.37
# Epoch [97/300], Step [400/600], d_loss: 0.6548, g_loss: 2.0543, D(x): 0.78, D(G(z)): 0.25
# Epoch [97/300], Step [600/600], d_loss: 0.9353, g_loss: 1.9399, D(x): 0.67, D(G(z)): 0.25
# Saving fake_images-0098.png
# Epoch [98/300], Step [200/600], d_loss: 0.8237, g_loss: 1.9093, D(x): 0.74, D(G(z)): 0.32
# Epoch [98/300], Step [400/600], d_loss: 0.8222, g_loss: 1.9110, D(x): 0.72, D(G(z)): 0.25
# Epoch [98/300], Step [600/600], d_loss: 0.8553, g_loss: 1.8120, D(x): 0.74, D(G(z)): 0.33
# Saving fake_images-0099.png
# Epoch [99/300], Step [200/600], d_loss: 0.9525, g_loss: 1.8006, D(x): 0.71, D(G(z)): 0.31
# Epoch [99/300], Step [400/600], d_loss: 1.0385, g_loss: 1.4743, D(x): 0.72, D(G(z)): 0.38
# Epoch [99/300], Step [600/600], d_loss: 1.0078, g_loss: 1.5548, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0100.png
# Epoch [100/300], Step [200/600], d_loss: 0.8435, g_loss: 1.8531, D(x): 0.76, D(G(z)): 0.31
# Epoch [100/300], Step [400/600], d_loss: 0.7854, g_loss: 2.2244, D(x): 0.79, D(G(z)): 0.32
# Epoch [100/300], Step [600/600], d_loss: 0.9210, g_loss: 1.5869, D(x): 0.71, D(G(z)): 0.28
# Saving fake_images-0101.png
# Epoch [101/300], Step [200/600], d_loss: 1.0115, g_loss: 1.7233, D(x): 0.72, D(G(z)): 0.33
# Epoch [101/300], Step [400/600], d_loss: 0.9251, g_loss: 1.6644, D(x): 0.70, D(G(z)): 0.31
# Epoch [101/300], Step [600/600], d_loss: 0.7453, g_loss: 1.8812, D(x): 0.73, D(G(z)): 0.24
# Saving fake_images-0102.png
# Epoch [102/300], Step [200/600], d_loss: 0.7702, g_loss: 1.6004, D(x): 0.74, D(G(z)): 0.26
# Epoch [102/300], Step [400/600], d_loss: 1.0175, g_loss: 1.9470, D(x): 0.67, D(G(z)): 0.27
# Epoch [102/300], Step [600/600], d_loss: 0.7787, g_loss: 1.9368, D(x): 0.74, D(G(z)): 0.24
# Saving fake_images-0103.png
# Epoch [103/300], Step [200/600], d_loss: 0.8873, g_loss: 2.2069, D(x): 0.76, D(G(z)): 0.32
# Epoch [103/300], Step [400/600], d_loss: 0.7799, g_loss: 1.5115, D(x): 0.79, D(G(z)): 0.30
# Epoch [103/300], Step [600/600], d_loss: 1.0024, g_loss: 1.4450, D(x): 0.71, D(G(z)): 0.35
# Saving fake_images-0104.png
# Epoch [104/300], Step [200/600], d_loss: 0.9718, g_loss: 2.0743, D(x): 0.61, D(G(z)): 0.20
# Epoch [104/300], Step [400/600], d_loss: 1.0098, g_loss: 1.9925, D(x): 0.67, D(G(z)): 0.29
# Epoch [104/300], Step [600/600], d_loss: 0.9326, g_loss: 1.6148, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0105.png
# Epoch [105/300], Step [200/600], d_loss: 0.9403, g_loss: 2.2622, D(x): 0.75, D(G(z)): 0.33
# Epoch [105/300], Step [400/600], d_loss: 0.7359, g_loss: 1.9495, D(x): 0.81, D(G(z)): 0.33
# Epoch [105/300], Step [600/600], d_loss: 0.7064, g_loss: 1.7377, D(x): 0.80, D(G(z)): 0.30
# Saving fake_images-0106.png
# Epoch [106/300], Step [200/600], d_loss: 0.9618, g_loss: 1.8588, D(x): 0.70, D(G(z)): 0.32
# Epoch [106/300], Step [400/600], d_loss: 1.0684, g_loss: 1.3820, D(x): 0.64, D(G(z)): 0.32
# Epoch [106/300], Step [600/600], d_loss: 0.8066, g_loss: 1.6000, D(x): 0.74, D(G(z)): 0.29
# Saving fake_images-0107.png
# Epoch [107/300], Step [200/600], d_loss: 1.0511, g_loss: 1.2842, D(x): 0.74, D(G(z)): 0.40
# Epoch [107/300], Step [400/600], d_loss: 0.8108, g_loss: 1.5612, D(x): 0.76, D(G(z)): 0.32
# Epoch [107/300], Step [600/600], d_loss: 0.9656, g_loss: 2.1662, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0108.png
# Epoch [108/300], Step [200/600], d_loss: 1.0278, g_loss: 1.6889, D(x): 0.71, D(G(z)): 0.32
# Epoch [108/300], Step [400/600], d_loss: 1.0611, g_loss: 1.4910, D(x): 0.74, D(G(z)): 0.39
# Epoch [108/300], Step [600/600], d_loss: 0.9394, g_loss: 2.2840, D(x): 0.64, D(G(z)): 0.22
# Saving fake_images-0109.png
# Epoch [109/300], Step [200/600], d_loss: 1.1417, g_loss: 1.9278, D(x): 0.61, D(G(z)): 0.27
# Epoch [109/300], Step [400/600], d_loss: 1.0628, g_loss: 2.0993, D(x): 0.68, D(G(z)): 0.29
# Epoch [109/300], Step [600/600], d_loss: 0.8554, g_loss: 1.6652, D(x): 0.72, D(G(z)): 0.27
# Saving fake_images-0110.png
# Epoch [110/300], Step [200/600], d_loss: 0.8908, g_loss: 1.5797, D(x): 0.71, D(G(z)): 0.31
# Epoch [110/300], Step [400/600], d_loss: 1.0558, g_loss: 1.3000, D(x): 0.69, D(G(z)): 0.38
# Epoch [110/300], Step [600/600], d_loss: 1.0499, g_loss: 1.6439, D(x): 0.69, D(G(z)): 0.35
# Saving fake_images-0111.png
# Epoch [111/300], Step [200/600], d_loss: 0.8183, g_loss: 1.7613, D(x): 0.70, D(G(z)): 0.27
# Epoch [111/300], Step [400/600], d_loss: 0.8112, g_loss: 1.4415, D(x): 0.73, D(G(z)): 0.30
# Epoch [111/300], Step [600/600], d_loss: 0.9030, g_loss: 1.4872, D(x): 0.65, D(G(z)): 0.26
# Saving fake_images-0112.png
# Epoch [112/300], Step [200/600], d_loss: 0.7514, g_loss: 1.7667, D(x): 0.74, D(G(z)): 0.27
# Epoch [112/300], Step [400/600], d_loss: 0.7174, g_loss: 1.5701, D(x): 0.83, D(G(z)): 0.32
# Epoch [112/300], Step [600/600], d_loss: 0.7678, g_loss: 1.8177, D(x): 0.75, D(G(z)): 0.26
# Saving fake_images-0113.png
# Epoch [113/300], Step [200/600], d_loss: 0.8943, g_loss: 1.5345, D(x): 0.65, D(G(z)): 0.24
# Epoch [113/300], Step [400/600], d_loss: 1.0388, g_loss: 1.8242, D(x): 0.68, D(G(z)): 0.32
# Epoch [113/300], Step [600/600], d_loss: 0.6543, g_loss: 1.9794, D(x): 0.85, D(G(z)): 0.31
# Saving fake_images-0114.png
# Epoch [114/300], Step [200/600], d_loss: 0.8653, g_loss: 1.5512, D(x): 0.76, D(G(z)): 0.35
# Epoch [114/300], Step [400/600], d_loss: 0.7666, g_loss: 1.8528, D(x): 0.74, D(G(z)): 0.27
# Epoch [114/300], Step [600/600], d_loss: 0.8349, g_loss: 1.5231, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0115.png
# Epoch [115/300], Step [200/600], d_loss: 1.1494, g_loss: 1.7492, D(x): 0.63, D(G(z)): 0.31
# Epoch [115/300], Step [400/600], d_loss: 0.8506, g_loss: 1.4515, D(x): 0.77, D(G(z)): 0.35
# Epoch [115/300], Step [600/600], d_loss: 0.7593, g_loss: 1.4536, D(x): 0.81, D(G(z)): 0.34
# Saving fake_images-0116.png
# Epoch [116/300], Step [200/600], d_loss: 0.6767, g_loss: 1.9378, D(x): 0.76, D(G(z)): 0.23
# Epoch [116/300], Step [400/600], d_loss: 0.6632, g_loss: 1.9933, D(x): 0.73, D(G(z)): 0.18
# Epoch [116/300], Step [600/600], d_loss: 0.6507, g_loss: 2.2345, D(x): 0.77, D(G(z)): 0.21
# Saving fake_images-0117.png
# Epoch [117/300], Step [200/600], d_loss: 0.8156, g_loss: 2.2623, D(x): 0.68, D(G(z)): 0.21
# Epoch [117/300], Step [400/600], d_loss: 0.7670, g_loss: 1.5708, D(x): 0.73, D(G(z)): 0.24
# Epoch [117/300], Step [600/600], d_loss: 0.7270, g_loss: 1.9540, D(x): 0.75, D(G(z)): 0.25
# Saving fake_images-0118.png
# Epoch [118/300], Step [200/600], d_loss: 0.9938, g_loss: 1.5820, D(x): 0.76, D(G(z)): 0.39
# Epoch [118/300], Step [400/600], d_loss: 0.8853, g_loss: 1.5467, D(x): 0.72, D(G(z)): 0.33
# Epoch [118/300], Step [600/600], d_loss: 0.8863, g_loss: 1.7326, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0119.png
# Epoch [119/300], Step [200/600], d_loss: 1.0646, g_loss: 1.6804, D(x): 0.73, D(G(z)): 0.38
# Epoch [119/300], Step [400/600], d_loss: 0.6247, g_loss: 2.2090, D(x): 0.80, D(G(z)): 0.24
# Epoch [119/300], Step [600/600], d_loss: 0.8302, g_loss: 1.6851, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0120.png
# Epoch [120/300], Step [200/600], d_loss: 1.0728, g_loss: 1.6876, D(x): 0.70, D(G(z)): 0.34
# Epoch [120/300], Step [400/600], d_loss: 0.9968, g_loss: 1.4382, D(x): 0.69, D(G(z)): 0.33
# Epoch [120/300], Step [600/600], d_loss: 1.1086, g_loss: 1.6659, D(x): 0.67, D(G(z)): 0.35
# Saving fake_images-0121.png
# Epoch [121/300], Step [200/600], d_loss: 0.7431, g_loss: 1.7517, D(x): 0.72, D(G(z)): 0.25
# Epoch [121/300], Step [400/600], d_loss: 0.8900, g_loss: 1.5442, D(x): 0.77, D(G(z)): 0.33
# Epoch [121/300], Step [600/600], d_loss: 0.7756, g_loss: 1.8335, D(x): 0.72, D(G(z)): 0.24
# Saving fake_images-0122.png
# Epoch [122/300], Step [200/600], d_loss: 0.8659, g_loss: 1.5906, D(x): 0.74, D(G(z)): 0.31
# Epoch [122/300], Step [400/600], d_loss: 0.9819, g_loss: 1.2337, D(x): 0.70, D(G(z)): 0.32
# Epoch [122/300], Step [600/600], d_loss: 0.8824, g_loss: 1.5349, D(x): 0.71, D(G(z)): 0.29
# Saving fake_images-0123.png
# Epoch [123/300], Step [200/600], d_loss: 0.8366, g_loss: 2.0145, D(x): 0.66, D(G(z)): 0.20
# Epoch [123/300], Step [400/600], d_loss: 0.7694, g_loss: 1.5152, D(x): 0.77, D(G(z)): 0.28
# Epoch [123/300], Step [600/600], d_loss: 1.0712, g_loss: 1.1860, D(x): 0.68, D(G(z)): 0.35
# Saving fake_images-0124.png
# Epoch [124/300], Step [200/600], d_loss: 0.9883, g_loss: 1.9493, D(x): 0.62, D(G(z)): 0.23
# Epoch [124/300], Step [400/600], d_loss: 1.1819, g_loss: 1.6771, D(x): 0.66, D(G(z)): 0.33
# Epoch [124/300], Step [600/600], d_loss: 0.9151, g_loss: 1.6605, D(x): 0.64, D(G(z)): 0.22
# Saving fake_images-0125.png
# Epoch [125/300], Step [200/600], d_loss: 0.8700, g_loss: 1.9136, D(x): 0.67, D(G(z)): 0.22
# Epoch [125/300], Step [400/600], d_loss: 0.6887, g_loss: 1.5593, D(x): 0.77, D(G(z)): 0.25
# Epoch [125/300], Step [600/600], d_loss: 1.0076, g_loss: 1.4782, D(x): 0.64, D(G(z)): 0.29
# Saving fake_images-0126.png
# Epoch [126/300], Step [200/600], d_loss: 1.1568, g_loss: 1.4445, D(x): 0.60, D(G(z)): 0.30
# Epoch [126/300], Step [400/600], d_loss: 0.9161, g_loss: 1.7381, D(x): 0.69, D(G(z)): 0.33
# Epoch [126/300], Step [600/600], d_loss: 1.0250, g_loss: 1.2264, D(x): 0.72, D(G(z)): 0.38
# Saving fake_images-0127.png
# Epoch [127/300], Step [200/600], d_loss: 1.1609, g_loss: 1.5328, D(x): 0.69, D(G(z)): 0.37
# Epoch [127/300], Step [400/600], d_loss: 1.1146, g_loss: 1.4067, D(x): 0.69, D(G(z)): 0.37
# Epoch [127/300], Step [600/600], d_loss: 1.1641, g_loss: 1.7142, D(x): 0.59, D(G(z)): 0.26
# Saving fake_images-0128.png
# Epoch [128/300], Step [200/600], d_loss: 1.1150, g_loss: 1.5648, D(x): 0.67, D(G(z)): 0.32
# Epoch [128/300], Step [400/600], d_loss: 0.6861, g_loss: 1.8836, D(x): 0.76, D(G(z)): 0.25
# Epoch [128/300], Step [600/600], d_loss: 0.8161, g_loss: 1.6240, D(x): 0.66, D(G(z)): 0.22
# Saving fake_images-0129.png
# Epoch [129/300], Step [200/600], d_loss: 0.8775, g_loss: 1.6417, D(x): 0.77, D(G(z)): 0.34
# Epoch [129/300], Step [400/600], d_loss: 0.7692, g_loss: 1.9145, D(x): 0.71, D(G(z)): 0.24
# Epoch [129/300], Step [600/600], d_loss: 1.1266, g_loss: 1.4052, D(x): 0.62, D(G(z)): 0.30
# Saving fake_images-0130.png
# Epoch [130/300], Step [200/600], d_loss: 0.8459, g_loss: 2.3821, D(x): 0.65, D(G(z)): 0.19
# Epoch [130/300], Step [400/600], d_loss: 1.0361, g_loss: 1.8282, D(x): 0.60, D(G(z)): 0.26
# Epoch [130/300], Step [600/600], d_loss: 1.0689, g_loss: 2.0104, D(x): 0.72, D(G(z)): 0.35
# Saving fake_images-0131.png
# Epoch [131/300], Step [200/600], d_loss: 1.1738, g_loss: 1.5848, D(x): 0.61, D(G(z)): 0.31
# Epoch [131/300], Step [400/600], d_loss: 0.8216, g_loss: 1.4874, D(x): 0.77, D(G(z)): 0.32
# Epoch [131/300], Step [600/600], d_loss: 0.8406, g_loss: 1.7733, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0132.png
# Epoch [132/300], Step [200/600], d_loss: 0.7854, g_loss: 1.8952, D(x): 0.70, D(G(z)): 0.22
# Epoch [132/300], Step [400/600], d_loss: 1.0283, g_loss: 1.7804, D(x): 0.70, D(G(z)): 0.30
# Epoch [132/300], Step [600/600], d_loss: 0.9612, g_loss: 1.5565, D(x): 0.63, D(G(z)): 0.23
# Saving fake_images-0133.png
# Epoch [133/300], Step [200/600], d_loss: 0.9625, g_loss: 1.8133, D(x): 0.63, D(G(z)): 0.27
# Epoch [133/300], Step [400/600], d_loss: 0.9525, g_loss: 1.6661, D(x): 0.72, D(G(z)): 0.32
# Epoch [133/300], Step [600/600], d_loss: 0.7924, g_loss: 1.6957, D(x): 0.70, D(G(z)): 0.24
# Saving fake_images-0134.png
# Epoch [134/300], Step [200/600], d_loss: 0.8678, g_loss: 1.9663, D(x): 0.72, D(G(z)): 0.30
# Epoch [134/300], Step [400/600], d_loss: 0.8730, g_loss: 1.6624, D(x): 0.73, D(G(z)): 0.33
# Epoch [134/300], Step [600/600], d_loss: 0.9754, g_loss: 1.4834, D(x): 0.65, D(G(z)): 0.25
# Saving fake_images-0135.png
# Epoch [135/300], Step [200/600], d_loss: 0.8792, g_loss: 1.7052, D(x): 0.67, D(G(z)): 0.27
# Epoch [135/300], Step [400/600], d_loss: 0.8414, g_loss: 1.5375, D(x): 0.70, D(G(z)): 0.28
# Epoch [135/300], Step [600/600], d_loss: 1.2346, g_loss: 1.0713, D(x): 0.68, D(G(z)): 0.41
# Saving fake_images-0136.png
# Epoch [136/300], Step [200/600], d_loss: 0.9987, g_loss: 1.9230, D(x): 0.69, D(G(z)): 0.30
# Epoch [136/300], Step [400/600], d_loss: 0.6771, g_loss: 2.2793, D(x): 0.75, D(G(z)): 0.22
# Epoch [136/300], Step [600/600], d_loss: 1.2588, g_loss: 1.1205, D(x): 0.66, D(G(z)): 0.40
# Saving fake_images-0137.png
# Epoch [137/300], Step [200/600], d_loss: 1.0272, g_loss: 1.4293, D(x): 0.66, D(G(z)): 0.32
# Epoch [137/300], Step [400/600], d_loss: 0.7809, g_loss: 1.5681, D(x): 0.72, D(G(z)): 0.29
# Epoch [137/300], Step [600/600], d_loss: 0.8941, g_loss: 1.6122, D(x): 0.69, D(G(z)): 0.27
# Saving fake_images-0138.png
# Epoch [138/300], Step [200/600], d_loss: 0.9420, g_loss: 1.1658, D(x): 0.73, D(G(z)): 0.38
# Epoch [138/300], Step [400/600], d_loss: 1.1185, g_loss: 1.3886, D(x): 0.68, D(G(z)): 0.34
# Epoch [138/300], Step [600/600], d_loss: 1.1227, g_loss: 1.1992, D(x): 0.66, D(G(z)): 0.37
# Saving fake_images-0139.png
# Epoch [139/300], Step [200/600], d_loss: 1.0152, g_loss: 1.3862, D(x): 0.64, D(G(z)): 0.33
# Epoch [139/300], Step [400/600], d_loss: 0.9914, g_loss: 1.5187, D(x): 0.68, D(G(z)): 0.33
# Epoch [139/300], Step [600/600], d_loss: 1.0488, g_loss: 1.4275, D(x): 0.62, D(G(z)): 0.31
# Saving fake_images-0140.png
# Epoch [140/300], Step [200/600], d_loss: 0.9835, g_loss: 1.7444, D(x): 0.68, D(G(z)): 0.29
# Epoch [140/300], Step [400/600], d_loss: 1.1075, g_loss: 1.2419, D(x): 0.70, D(G(z)): 0.40
# Epoch [140/300], Step [600/600], d_loss: 0.9447, g_loss: 1.6985, D(x): 0.71, D(G(z)): 0.34
# Saving fake_images-0141.png
# Epoch [141/300], Step [200/600], d_loss: 0.7821, g_loss: 1.7891, D(x): 0.73, D(G(z)): 0.26
# Epoch [141/300], Step [400/600], d_loss: 0.9925, g_loss: 1.3580, D(x): 0.71, D(G(z)): 0.37
# Epoch [141/300], Step [600/600], d_loss: 1.1319, g_loss: 1.4897, D(x): 0.68, D(G(z)): 0.37
# Saving fake_images-0142.png
# Epoch [142/300], Step [200/600], d_loss: 0.9500, g_loss: 1.7397, D(x): 0.73, D(G(z)): 0.36
# Epoch [142/300], Step [400/600], d_loss: 0.8111, g_loss: 1.9518, D(x): 0.71, D(G(z)): 0.22
# Epoch [142/300], Step [600/600], d_loss: 1.0326, g_loss: 1.3933, D(x): 0.66, D(G(z)): 0.32
# Saving fake_images-0143.png
# Epoch [143/300], Step [200/600], d_loss: 0.9318, g_loss: 1.9065, D(x): 0.68, D(G(z)): 0.28
# Epoch [143/300], Step [400/600], d_loss: 0.9177, g_loss: 1.8787, D(x): 0.70, D(G(z)): 0.28
# Epoch [143/300], Step [600/600], d_loss: 0.9423, g_loss: 1.7869, D(x): 0.68, D(G(z)): 0.29
# Saving fake_images-0144.png
# Epoch [144/300], Step [200/600], d_loss: 1.1203, g_loss: 1.9033, D(x): 0.66, D(G(z)): 0.35
# Epoch [144/300], Step [400/600], d_loss: 1.3805, g_loss: 1.2971, D(x): 0.55, D(G(z)): 0.36
# Epoch [144/300], Step [600/600], d_loss: 1.0273, g_loss: 1.3492, D(x): 0.71, D(G(z)): 0.37
# Saving fake_images-0145.png
# Epoch [145/300], Step [200/600], d_loss: 0.9058, g_loss: 1.7156, D(x): 0.70, D(G(z)): 0.30
# Epoch [145/300], Step [400/600], d_loss: 0.9854, g_loss: 1.5036, D(x): 0.71, D(G(z)): 0.34
# Epoch [145/300], Step [600/600], d_loss: 0.8955, g_loss: 1.5520, D(x): 0.64, D(G(z)): 0.27
# Saving fake_images-0146.png
# Epoch [146/300], Step [200/600], d_loss: 1.2059, g_loss: 1.6236, D(x): 0.60, D(G(z)): 0.31
# Epoch [146/300], Step [400/600], d_loss: 0.9819, g_loss: 1.1314, D(x): 0.70, D(G(z)): 0.36
# Epoch [146/300], Step [600/600], d_loss: 1.0182, g_loss: 1.5171, D(x): 0.67, D(G(z)): 0.32
# Saving fake_images-0147.png
# Epoch [147/300], Step [200/600], d_loss: 1.1227, g_loss: 1.4693, D(x): 0.58, D(G(z)): 0.30
# Epoch [147/300], Step [400/600], d_loss: 1.0316, g_loss: 1.3548, D(x): 0.71, D(G(z)): 0.40
# Epoch [147/300], Step [600/600], d_loss: 0.8193, g_loss: 1.3479, D(x): 0.71, D(G(z)): 0.29
# Saving fake_images-0148.png
# Epoch [148/300], Step [200/600], d_loss: 0.8548, g_loss: 1.4189, D(x): 0.76, D(G(z)): 0.34
# Epoch [148/300], Step [400/600], d_loss: 0.9614, g_loss: 1.6431, D(x): 0.71, D(G(z)): 0.35
# Epoch [148/300], Step [600/600], d_loss: 0.8125, g_loss: 2.3283, D(x): 0.68, D(G(z)): 0.24
# Saving fake_images-0149.png
# Epoch [149/300], Step [200/600], d_loss: 0.9967, g_loss: 1.4168, D(x): 0.67, D(G(z)): 0.33
# Epoch [149/300], Step [400/600], d_loss: 0.9279, g_loss: 1.8557, D(x): 0.71, D(G(z)): 0.30
# Epoch [149/300], Step [600/600], d_loss: 1.1991, g_loss: 1.4299, D(x): 0.67, D(G(z)): 0.39
# Saving fake_images-0150.png
# Epoch [150/300], Step [200/600], d_loss: 0.7937, g_loss: 1.6844, D(x): 0.73, D(G(z)): 0.28
# Epoch [150/300], Step [400/600], d_loss: 1.2950, g_loss: 1.6667, D(x): 0.64, D(G(z)): 0.37
# Epoch [150/300], Step [600/600], d_loss: 0.9670, g_loss: 1.9110, D(x): 0.71, D(G(z)): 0.35
# Saving fake_images-0151.png
# Epoch [151/300], Step [200/600], d_loss: 0.9965, g_loss: 1.6927, D(x): 0.64, D(G(z)): 0.29
# Epoch [151/300], Step [400/600], d_loss: 1.2512, g_loss: 1.2374, D(x): 0.68, D(G(z)): 0.43
# Epoch [151/300], Step [600/600], d_loss: 1.1205, g_loss: 1.4219, D(x): 0.67, D(G(z)): 0.36
# Saving fake_images-0152.png
# Epoch [152/300], Step [200/600], d_loss: 0.9004, g_loss: 1.1001, D(x): 0.66, D(G(z)): 0.28
# Epoch [152/300], Step [400/600], d_loss: 1.1486, g_loss: 1.1712, D(x): 0.62, D(G(z)): 0.37
# Epoch [152/300], Step [600/600], d_loss: 0.9009, g_loss: 1.6585, D(x): 0.69, D(G(z)): 0.30
# Saving fake_images-0153.png
# Epoch [153/300], Step [200/600], d_loss: 1.0676, g_loss: 1.4685, D(x): 0.68, D(G(z)): 0.36
# Epoch [153/300], Step [400/600], d_loss: 1.0994, g_loss: 1.2052, D(x): 0.67, D(G(z)): 0.36
# Epoch [153/300], Step [600/600], d_loss: 1.0433, g_loss: 1.6020, D(x): 0.65, D(G(z)): 0.31
# Saving fake_images-0154.png
# Epoch [154/300], Step [200/600], d_loss: 1.1591, g_loss: 1.3011, D(x): 0.63, D(G(z)): 0.37
# Epoch [154/300], Step [400/600], d_loss: 0.7907, g_loss: 1.5021, D(x): 0.76, D(G(z)): 0.31
# Epoch [154/300], Step [600/600], d_loss: 1.2899, g_loss: 1.3509, D(x): 0.72, D(G(z)): 0.51
# Saving fake_images-0155.png
# Epoch [155/300], Step [200/600], d_loss: 0.8242, g_loss: 1.6273, D(x): 0.75, D(G(z)): 0.31
# Epoch [155/300], Step [400/600], d_loss: 0.7147, g_loss: 2.1787, D(x): 0.72, D(G(z)): 0.21
# Epoch [155/300], Step [600/600], d_loss: 0.8800, g_loss: 1.3417, D(x): 0.72, D(G(z)): 0.34
# Saving fake_images-0156.png
# Epoch [156/300], Step [200/600], d_loss: 1.0539, g_loss: 1.7464, D(x): 0.58, D(G(z)): 0.26
# Epoch [156/300], Step [400/600], d_loss: 1.1993, g_loss: 1.2614, D(x): 0.65, D(G(z)): 0.40
# Epoch [156/300], Step [600/600], d_loss: 0.9079, g_loss: 1.6062, D(x): 0.72, D(G(z)): 0.34
# Saving fake_images-0157.png
# Epoch [157/300], Step [200/600], d_loss: 1.1763, g_loss: 1.2924, D(x): 0.64, D(G(z)): 0.38
# Epoch [157/300], Step [400/600], d_loss: 1.0170, g_loss: 1.0956, D(x): 0.68, D(G(z)): 0.35
# Epoch [157/300], Step [600/600], d_loss: 0.7068, g_loss: 2.0402, D(x): 0.74, D(G(z)): 0.23
# Saving fake_images-0158.png
# Epoch [158/300], Step [200/600], d_loss: 1.1444, g_loss: 1.6161, D(x): 0.63, D(G(z)): 0.33
# Epoch [158/300], Step [400/600], d_loss: 0.8625, g_loss: 1.9993, D(x): 0.75, D(G(z)): 0.29
# Epoch [158/300], Step [600/600], d_loss: 0.8591, g_loss: 1.4103, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0159.png
# Epoch [159/300], Step [200/600], d_loss: 1.1656, g_loss: 1.2785, D(x): 0.65, D(G(z)): 0.38
# Epoch [159/300], Step [400/600], d_loss: 1.0781, g_loss: 1.7247, D(x): 0.58, D(G(z)): 0.25
# Epoch [159/300], Step [600/600], d_loss: 1.2483, g_loss: 1.1400, D(x): 0.60, D(G(z)): 0.38
# Saving fake_images-0160.png
# Epoch [160/300], Step [200/600], d_loss: 1.0365, g_loss: 1.3045, D(x): 0.64, D(G(z)): 0.34
# ...
# Epoch [247/300], Step [400/600], d_loss: 0.7158, g_loss: 2.0003, D(x): 0.79, D(G(z)): 0.27
# Epoch [247/300], Step [600/600], d_loss: 1.0989, g_loss: 1.2310, D(x): 0.64, D(G(z)): 0.37
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 0.9656, g_loss: 1.5286, D(x): 0.65, D(G(z)): 0.30
# Epoch [248/300], Step [400/600], d_loss: 1.1083, g_loss: 1.4515, D(x): 0.63, D(G(z)): 0.35
# Epoch [248/300], Step [600/600], d_loss: 0.9962, g_loss: 1.7208, D(x): 0.68, D(G(z)): 0.33
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 1.1551, g_loss: 1.3645, D(x): 0.59, D(G(z)): 0.34
# Epoch [249/300], Step [400/600], d_loss: 0.9793, g_loss: 1.4241, D(x): 0.63, D(G(z)): 0.31
# Epoch [249/300], Step [600/600], d_loss: 0.8226, g_loss: 1.8591, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 1.2149, g_loss: 1.0921, D(x): 0.66, D(G(z)): 0.43
# Epoch [250/300], Step [400/600], d_loss: 0.7846, g_loss: 1.3281, D(x): 0.75, D(G(z)): 0.31
# Epoch [250/300], Step [600/600], d_loss: 1.1207, g_loss: 1.2464, D(x): 0.65, D(G(z)): 0.38
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 1.2564, g_loss: 1.2675, D(x): 0.56, D(G(z)): 0.37
# Epoch [251/300], Step [400/600], d_loss: 1.1719, g_loss: 1.1612, D(x): 0.62, D(G(z)): 0.38
# Epoch [251/300], Step [600/600], d_loss: 1.3133, g_loss: 1.1754, D(x): 0.59, D(G(z)): 0.43
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 0.9273, g_loss: 1.6204, D(x): 0.71, D(G(z)): 0.35
# Epoch [252/300], Step [400/600], d_loss: 0.9173, g_loss: 1.3717, D(x): 0.65, D(G(z)): 0.28
# Epoch [252/300], Step [600/600], d_loss: 1.2609, g_loss: 1.2506, D(x): 0.62, D(G(z)): 0.39
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 1.0059, g_loss: 1.4316, D(x): 0.64, D(G(z)): 0.32
# Epoch [253/300], Step [400/600], d_loss: 0.9197, g_loss: 1.3878, D(x): 0.64, D(G(z)): 0.28
# Epoch [253/300], Step [600/600], d_loss: 1.2160, g_loss: 1.2719, D(x): 0.56, D(G(z)): 0.35
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 1.2079, g_loss: 1.2250, D(x): 0.69, D(G(z)): 0.46
# Epoch [254/300], Step [400/600], d_loss: 0.7273, g_loss: 1.6510, D(x): 0.69, D(G(z)): 0.24
# Epoch [254/300], Step [600/600], d_loss: 1.0310, g_loss: 1.2128, D(x): 0.64, D(G(z)): 0.35
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 1.0315, g_loss: 1.4545, D(x): 0.67, D(G(z)): 0.37
# Epoch [255/300], Step [400/600], d_loss: 1.2284, g_loss: 1.1834, D(x): 0.61, D(G(z)): 0.39
# Epoch [255/300], Step [600/600], d_loss: 0.8908, g_loss: 1.7095, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 0.7911, g_loss: 1.8714, D(x): 0.68, D(G(z)): 0.23
# Epoch [256/300], Step [400/600], d_loss: 1.1094, g_loss: 1.2847, D(x): 0.68, D(G(z)): 0.38
# Epoch [256/300], Step [600/600], d_loss: 0.9199, g_loss: 1.3541, D(x): 0.67, D(G(z)): 0.31
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 0.9510, g_loss: 1.4219, D(x): 0.70, D(G(z)): 0.38
# Epoch [257/300], Step [400/600], d_loss: 1.1868, g_loss: 1.3296, D(x): 0.57, D(G(z)): 0.34
# Epoch [257/300], Step [600/600], d_loss: 1.1150, g_loss: 1.2506, D(x): 0.64, D(G(z)): 0.37
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 0.7885, g_loss: 1.4106, D(x): 0.72, D(G(z)): 0.30
# Epoch [258/300], Step [400/600], d_loss: 0.7481, g_loss: 1.4736, D(x): 0.77, D(G(z)): 0.32
# Epoch [258/300], Step [600/600], d_loss: 1.1737, g_loss: 1.3148, D(x): 0.58, D(G(z)): 0.34
# Saving fake_images-0259.png
# Epoch [259/300], Step [200/600], d_loss: 1.4023, g_loss: 0.8921, D(x): 0.58, D(G(z)): 0.45
# Epoch [259/300], Step [400/600], d_loss: 0.9728, g_loss: 1.4436, D(x): 0.69, D(G(z)): 0.35
# Epoch [259/300], Step [600/600], d_loss: 0.8094, g_loss: 1.4028, D(x): 0.70, D(G(z)): 0.28
# Saving fake_images-0260.png
# Epoch [260/300], Step [200/600], d_loss: 0.8638, g_loss: 1.4392, D(x): 0.73, D(G(z)): 0.33
# Epoch [260/300], Step [400/600], d_loss: 0.8129, g_loss: 1.7200, D(x): 0.68, D(G(z)): 0.24
# Epoch [260/300], Step [600/600], d_loss: 1.2677, g_loss: 0.9739, D(x): 0.61, D(G(z)): 0.40
# Saving fake_images-0261.png
# Epoch [261/300], Step [200/600], d_loss: 0.9737, g_loss: 1.3977, D(x): 0.68, D(G(z)): 0.34
# Epoch [261/300], Step [400/600], d_loss: 1.0124, g_loss: 1.2512, D(x): 0.68, D(G(z)): 0.37
# Epoch [261/300], Step [600/600], d_loss: 1.0005, g_loss: 1.4021, D(x): 0.68, D(G(z)): 0.35
# Saving fake_images-0262.png
# Epoch [262/300], Step [200/600], d_loss: 0.9095, g_loss: 1.3326, D(x): 0.68, D(G(z)): 0.32
# Epoch [262/300], Step [400/600], d_loss: 1.3207, g_loss: 1.1133, D(x): 0.60, D(G(z)): 0.41
# Epoch [262/300], Step [600/600], d_loss: 1.0282, g_loss: 1.4049, D(x): 0.69, D(G(z)): 0.40
# Saving fake_images-0263.png
# Epoch [263/300], Step [200/600], d_loss: 1.1770, g_loss: 1.1078, D(x): 0.65, D(G(z)): 0.42
# Epoch [263/300], Step [400/600], d_loss: 1.1267, g_loss: 1.4151, D(x): 0.58, D(G(z)): 0.33
# Epoch [263/300], Step [600/600], d_loss: 0.9777, g_loss: 1.2347, D(x): 0.70, D(G(z)): 0.39
# Saving fake_images-0264.png
# Epoch [264/300], Step [200/600], d_loss: 1.1908, g_loss: 1.1414, D(x): 0.62, D(G(z)): 0.40
# Epoch [264/300], Step [400/600], d_loss: 0.8596, g_loss: 1.6660, D(x): 0.74, D(G(z)): 0.33
# Epoch [264/300], Step [600/600], d_loss: 1.2556, g_loss: 1.1065, D(x): 0.61, D(G(z)): 0.41
# Saving fake_images-0265.png
# Epoch [265/300], Step [200/600], d_loss: 0.7484, g_loss: 1.4347, D(x): 0.77, D(G(z)): 0.32
# Epoch [265/300], Step [400/600], d_loss: 1.0155, g_loss: 1.5369, D(x): 0.63, D(G(z)): 0.30
# Epoch [265/300], Step [600/600], d_loss: 0.8973, g_loss: 1.5793, D(x): 0.72, D(G(z)): 0.34
# Saving fake_images-0266.png
# Epoch [266/300], Step [200/600], d_loss: 0.6535, g_loss: 1.5494, D(x): 0.77, D(G(z)): 0.24
# Epoch [266/300], Step [400/600], d_loss: 0.8382, g_loss: 1.6621, D(x): 0.70, D(G(z)): 0.30
# Epoch [266/300], Step [600/600], d_loss: 1.1224, g_loss: 1.4838, D(x): 0.60, D(G(z)): 0.32
# Saving fake_images-0267.png
# Epoch [267/300], Step [200/600], d_loss: 0.7038, g_loss: 1.7140, D(x): 0.74, D(G(z)): 0.25
# Epoch [267/300], Step [400/600], d_loss: 1.1211, g_loss: 1.1375, D(x): 0.63, D(G(z)): 0.38
# Epoch [267/300], Step [600/600], d_loss: 1.3019, g_loss: 1.1276, D(x): 0.59, D(G(z)): 0.41
# Saving fake_images-0268.png
# Epoch [268/300], Step [200/600], d_loss: 0.8475, g_loss: 1.4088, D(x): 0.72, D(G(z)): 0.31
# Epoch [268/300], Step [400/600], d_loss: 0.9729, g_loss: 1.3857, D(x): 0.66, D(G(z)): 0.34
# Epoch [268/300], Step [600/600], d_loss: 1.3686, g_loss: 1.0901, D(x): 0.62, D(G(z)): 0.47
# Saving fake_images-0269.png
# Epoch [269/300], Step [200/600], d_loss: 0.6983, g_loss: 1.6766, D(x): 0.71, D(G(z)): 0.24
# Epoch [269/300], Step [400/600], d_loss: 1.0691, g_loss: 1.1611, D(x): 0.66, D(G(z)): 0.38
# Epoch [269/300], Step [600/600], d_loss: 0.8740, g_loss: 1.6924, D(x): 0.71, D(G(z)): 0.30
# Saving fake_images-0270.png
# Epoch [270/300], Step [200/600], d_loss: 0.9599, g_loss: 1.3158, D(x): 0.68, D(G(z)): 0.35
# Epoch [270/300], Step [400/600], d_loss: 1.4760, g_loss: 0.9991, D(x): 0.54, D(G(z)): 0.39
# Epoch [270/300], Step [600/600], d_loss: 0.8383, g_loss: 1.2869, D(x): 0.77, D(G(z)): 0.35
# Saving fake_images-0271.png
# Epoch [271/300], Step [200/600], d_loss: 1.2639, g_loss: 1.2113, D(x): 0.58, D(G(z)): 0.39
# Epoch [271/300], Step [400/600], d_loss: 1.3896, g_loss: 0.9024, D(x): 0.59, D(G(z)): 0.45
# Epoch [271/300], Step [600/600], d_loss: 1.0115, g_loss: 1.2156, D(x): 0.69, D(G(z)): 0.37
# Saving fake_images-0272.png
# Epoch [272/300], Step [200/600], d_loss: 1.4136, g_loss: 0.9573, D(x): 0.61, D(G(z)): 0.49
# Epoch [272/300], Step [400/600], d_loss: 1.0038, g_loss: 1.3320, D(x): 0.69, D(G(z)): 0.36
# Epoch [272/300], Step [600/600], d_loss: 0.9469, g_loss: 1.4016, D(x): 0.69, D(G(z)): 0.35
# Saving fake_images-0273.png
# Epoch [273/300], Step [200/600], d_loss: 1.1796, g_loss: 1.2171, D(x): 0.62, D(G(z)): 0.39
# Epoch [273/300], Step [400/600], d_loss: 0.6581, g_loss: 1.5399, D(x): 0.75, D(G(z)): 0.25
# Epoch [273/300], Step [600/600], d_loss: 1.1180, g_loss: 1.1927, D(x): 0.62, D(G(z)): 0.37
# Saving fake_images-0274.png
# Epoch [274/300], Step [200/600], d_loss: 1.0291, g_loss: 1.3647, D(x): 0.64, D(G(z)): 0.34
# Epoch [274/300], Step [400/600], d_loss: 0.8290, g_loss: 1.5946, D(x): 0.69, D(G(z)): 0.25
# Epoch [274/300], Step [600/600], d_loss: 1.2208, g_loss: 1.1109, D(x): 0.59, D(G(z)): 0.39
# Saving fake_images-0275.png
# Epoch [275/300], Step [200/600], d_loss: 1.0731, g_loss: 1.4303, D(x): 0.66, D(G(z)): 0.37
# Epoch [275/300], Step [400/600], d_loss: 0.7266, g_loss: 1.8224, D(x): 0.71, D(G(z)): 0.25
# Epoch [275/300], Step [600/600], d_loss: 1.1556, g_loss: 1.1067, D(x): 0.64, D(G(z)): 0.39
# Saving fake_images-0276.png
# Epoch [276/300], Step [200/600], d_loss: 1.4585, g_loss: 1.1158, D(x): 0.49, D(G(z)): 0.38
# Epoch [276/300], Step [400/600], d_loss: 0.9490, g_loss: 1.5657, D(x): 0.69, D(G(z)): 0.36
# Epoch [276/300], Step [600/600], d_loss: 0.8056, g_loss: 1.6313, D(x): 0.71, D(G(z)): 0.30
# Saving fake_images-0277.png
# Epoch [277/300], Step [200/600], d_loss: 1.0074, g_loss: 1.1906, D(x): 0.71, D(G(z)): 0.38
# Epoch [277/300], Step [400/600], d_loss: 0.7184, g_loss: 1.4776, D(x): 0.79, D(G(z)): 0.32
# Epoch [277/300], Step [600/600], d_loss: 1.0064, g_loss: 1.3278, D(x): 0.71, D(G(z)): 0.40
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 0.8537, g_loss: 1.2782, D(x): 0.70, D(G(z)): 0.31
# Epoch [278/300], Step [400/600], d_loss: 0.9248, g_loss: 1.5195, D(x): 0.70, D(G(z)): 0.31
# Epoch [278/300], Step [600/600], d_loss: 1.0424, g_loss: 1.4127, D(x): 0.65, D(G(z)): 0.35
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 0.8308, g_loss: 1.5407, D(x): 0.72, D(G(z)): 0.31
# Epoch [279/300], Step [400/600], d_loss: 1.0368, g_loss: 1.4034, D(x): 0.62, D(G(z)): 0.32
# Epoch [279/300], Step [600/600], d_loss: 1.3883, g_loss: 1.2386, D(x): 0.55, D(G(z)): 0.43
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 0.7481, g_loss: 1.5312, D(x): 0.72, D(G(z)): 0.26
# Epoch [280/300], Step [400/600], d_loss: 0.9174, g_loss: 1.6151, D(x): 0.70, D(G(z)): 0.32
# Epoch [280/300], Step [600/600], d_loss: 1.5023, g_loss: 1.1287, D(x): 0.51, D(G(z)): 0.41
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 1.2858, g_loss: 1.2076, D(x): 0.58, D(G(z)): 0.39
# Epoch [281/300], Step [400/600], d_loss: 0.7885, g_loss: 1.5465, D(x): 0.69, D(G(z)): 0.27
# Epoch [281/300], Step [600/600], d_loss: 1.2928, g_loss: 1.0936, D(x): 0.58, D(G(z)): 0.39
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 1.0257, g_loss: 1.2551, D(x): 0.65, D(G(z)): 0.37
# Epoch [282/300], Step [400/600], d_loss: 0.9006, g_loss: 1.4271, D(x): 0.68, D(G(z)): 0.31
# Epoch [282/300], Step [600/600], d_loss: 1.0791, g_loss: 1.2852, D(x): 0.67, D(G(z)): 0.38
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 0.7297, g_loss: 1.7979, D(x): 0.73, D(G(z)): 0.25
# Epoch [283/300], Step [400/600], d_loss: 1.2391, g_loss: 1.2200, D(x): 0.57, D(G(z)): 0.39
# Epoch [283/300], Step [600/600], d_loss: 1.1650, g_loss: 1.0416, D(x): 0.60, D(G(z)): 0.38
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 0.8966, g_loss: 1.3382, D(x): 0.66, D(G(z)): 0.30
# Epoch [284/300], Step [400/600], d_loss: 1.3720, g_loss: 0.9435, D(x): 0.62, D(G(z)): 0.47
# Epoch [284/300], Step [600/600], d_loss: 0.9600, g_loss: 1.2607, D(x): 0.67, D(G(z)): 0.33
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 0.9644, g_loss: 1.2916, D(x): 0.66, D(G(z)): 0.32
# Epoch [285/300], Step [400/600], d_loss: 1.5588, g_loss: 1.0542, D(x): 0.53, D(G(z)): 0.46
# Epoch [285/300], Step [600/600], d_loss: 0.9288, g_loss: 1.4509, D(x): 0.63, D(G(z)): 0.28
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 0.9232, g_loss: 1.1524, D(x): 0.72, D(G(z)): 0.37
# Epoch [286/300], Step [400/600], d_loss: 1.4004, g_loss: 0.9535, D(x): 0.60, D(G(z)): 0.46
# Epoch [286/300], Step [600/600], d_loss: 1.0581, g_loss: 1.2177, D(x): 0.70, D(G(z)): 0.39
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 0.8421, g_loss: 1.3451, D(x): 0.74, D(G(z)): 0.33
# Epoch [287/300], Step [400/600], d_loss: 1.3840, g_loss: 1.0461, D(x): 0.57, D(G(z)): 0.44
# Epoch [287/300], Step [600/600], d_loss: 1.1264, g_loss: 1.5263, D(x): 0.64, D(G(z)): 0.36
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss: 0.8489, g_loss: 1.7572, D(x): 0.70, D(G(z)): 0.32
# Epoch [288/300], Step [400/600], d_loss: 1.1607, g_loss: 1.0865, D(x): 0.62, D(G(z)): 0.37
# Epoch [288/300], Step [600/600], d_loss: 1.0141, g_loss: 1.5493, D(x): 0.60, D(G(z)): 0.29
# Saving fake_images-0289.png
# Epoch [289/300], Step [200/600], d_loss: 0.7393, g_loss: 1.3881, D(x): 0.75, D(G(z)): 0.28
# Epoch [289/300], Step [400/600], d_loss: 1.2922, g_loss: 1.0638, D(x): 0.59, D(G(z)): 0.43
# Epoch [289/300], Step [600/600], d_loss: 1.4292, g_loss: 1.1447, D(x): 0.57, D(G(z)): 0.43
# Saving fake_images-0290.png
# Epoch [290/300], Step [200/600], d_loss: 0.9882, g_loss: 1.2982, D(x): 0.65, D(G(z)): 0.32
# Epoch [290/300], Step [400/600], d_loss: 0.8789, g_loss: 1.2704, D(x): 0.67, D(G(z)): 0.30
# Epoch [290/300], Step [600/600], d_loss: 0.9811, g_loss: 1.2682, D(x): 0.67, D(G(z)): 0.34
# Saving fake_images-0291.png
# Epoch [291/300], Step [200/600], d_loss: 1.2086, g_loss: 1.1717, D(x): 0.59, D(G(z)): 0.39
# Epoch [291/300], Step [400/600], d_loss: 1.2140, g_loss: 1.2135, D(x): 0.64, D(G(z)): 0.41
# Epoch [291/300], Step [600/600], d_loss: 0.7435, g_loss: 1.8315, D(x): 0.71, D(G(z)): 0.25
# Saving fake_images-0292.png
# Epoch [292/300], Step [200/600], d_loss: 0.8788, g_loss: 1.4927, D(x): 0.67, D(G(z)): 0.28
# Epoch [292/300], Step [400/600], d_loss: 1.3328, g_loss: 0.9113, D(x): 0.67, D(G(z)): 0.49
# Epoch [292/300], Step [600/600], d_loss: 0.7978, g_loss: 1.6008, D(x): 0.71, D(G(z)): 0.28
# Saving fake_images-0293.png
# Epoch [293/300], Step [200/600], d_loss: 1.0847, g_loss: 1.2134, D(x): 0.62, D(G(z)): 0.34
# Epoch [293/300], Step [400/600], d_loss: 1.1218, g_loss: 1.2369, D(x): 0.65, D(G(z)): 0.42
# Epoch [293/300], Step [600/600], d_loss: 0.9455, g_loss: 1.5645, D(x): 0.66, D(G(z)): 0.29
# Saving fake_images-0294.png
# Epoch [294/300], Step [200/600], d_loss: 0.8844, g_loss: 1.2456, D(x): 0.72, D(G(z)): 0.33
# Epoch [294/300], Step [400/600], d_loss: 1.0902, g_loss: 1.3912, D(x): 0.66, D(G(z)): 0.36
# Epoch [294/300], Step [600/600], d_loss: 1.0973, g_loss: 1.1835, D(x): 0.63, D(G(z)): 0.36
# Saving fake_images-0295.png
# Epoch [295/300], Step [200/600], d_loss: 1.0016, g_loss: 1.3335, D(x): 0.67, D(G(z)): 0.33
# Epoch [295/300], Step [400/600], d_loss: 1.2342, g_loss: 1.1681, D(x): 0.57, D(G(z)): 0.35
# Epoch [295/300], Step [600/600], d_loss: 1.1307, g_loss: 1.1774, D(x): 0.60, D(G(z)): 0.37
# Saving fake_images-0296.png
# Epoch [296/300], Step [200/600], d_loss: 0.9310, g_loss: 1.3801, D(x): 0.69, D(G(z)): 0.33
# Epoch [296/300], Step [400/600], d_loss: 0.8251, g_loss: 1.6130, D(x): 0.70, D(G(z)): 0.28
# Epoch [296/300], Step [600/600], d_loss: 0.7418, g_loss: 1.6771, D(x): 0.75, D(G(z)): 0.27
# Saving fake_images-0297.png
# Epoch [297/300], Step [200/600], d_loss: 0.8018, g_loss: 1.5184, D(x): 0.74, D(G(z)): 0.32
# Epoch [297/300], Step [400/600], d_loss: 1.1505, g_loss: 0.9187, D(x): 0.62, D(G(z)): 0.38
# Epoch [297/300], Step [600/600], d_loss: 1.1769, g_loss: 1.0966, D(x): 0.67, D(G(z)): 0.42
# Saving fake_images-0298.png
# Epoch [298/300], Step [200/600], d_loss: 0.7669, g_loss: 1.7226, D(x): 0.73, D(G(z)): 0.28
# Epoch [298/300], Step [400/600], d_loss: 0.9153, g_loss: 1.7365, D(x): 0.66, D(G(z)): 0.28
# Epoch [298/300], Step [600/600], d_loss: 1.2831, g_loss: 0.9843, D(x): 0.64, D(G(z)): 0.45
# Saving fake_images-0299.png
# Epoch [299/300], Step [200/600], d_loss: 1.3780, g_loss: 1.1298, D(x): 0.59, D(G(z)): 0.44
# Epoch [299/300], Step [400/600], d_loss: 0.9462, g_loss: 1.4921, D(x): 0.67, D(G(z)): 0.31
# Epoch [299/300], Step [600/600], d_loss: 1.0447, g_loss: 1.2297, D(x): 0.68, D(G(z)): 0.36
# Saving fake_images-0300.png
# CPU times: user 2h 31min 43s, sys: 31.4 s, total: 2h 32min 15s
# Wall time: 2h 33min 19s

# %% [markdown]
# Now that we have trained the models, we can save checkpoints.

# %% [markdown]
# Step3. Display at least 3 samples produced from your GAN model.

# %%
Image(os.path.join(sample_dir, 'fake_images-0050.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0150.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0250.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0300.png'))

# %% [markdown]
# It took 2h 33min 19s  and system crashes

# %%
# Save the model checkpoints
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %% [markdown]
# We can visualize the training process by combining the sample images generated
#
# ---
#
# after each epoch into a video using OpenCV.

# %%
import cv2
import os
from IPython.display import FileLink

vid_fname = 'gans_training.avi'

files = [os.path.join(sample_dir, f) for f in os.listdir(sample_dir) if 'fake_images' in f]
files.sort()

out = cv2.VideoWriter(vid_fname,cv2.VideoWriter_fourcc(*'MP4V'), 8, (302,302))
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink('gans_training.avi')
# Out:
# /content/gans_training.avi

# %% [markdown]
# You can view the animated training video here: https://www.youtube.com/watch?v=R7HTX79JlBg
#
# We can also visualize how the loss changes over time. Visualizing losses is quite useful for debugging the training process. For GANs, we expect the generator's loss to reduce over time, without the discriminator's loss getting too high.

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# #Step4. Save the model weights in the folder to be used later.

# %%
torch.save(G.state_dict(), 'generator_weights.pth')
torch.save(D.state_dict(), 'discriminator_weights.pth')

# %% [markdown]
# #Step5. Load the model using the saved weights.

# %%
G.load_state_dict(torch.load('generator_weights.pth'))
D.load_state_dict(torch.load('discriminator_weights.pth'))
# Out:
# <All keys matched successfully>

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %%
num_epochs = 50
for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        images = images.reshape(batch_size, -1).to(device)

        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        if (i+1) % 200 == 0:
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    save_fake_images(epoch+1)
# Out:
# Epoch [0/50], Step [200/600], d_loss: 1.1241, g_loss: 1.2316, D(x): 0.64, D(G(z)): 0.37
# Epoch [0/50], Step [400/600], d_loss: 1.2509, g_loss: 1.1316, D(x): 0.61, D(G(z)): 0.41
# Epoch [0/50], Step [600/600], d_loss: 1.1413, g_loss: 1.1472, D(x): 0.63, D(G(z)): 0.35
# Saving fake_images-0001.png
# Epoch [1/50], Step [200/600], d_loss: 1.2079, g_loss: 1.0589, D(x): 0.67, D(G(z)): 0.43
# Epoch [1/50], Step [400/600], d_loss: 1.3027, g_loss: 1.1126, D(x): 0.60, D(G(z)): 0.44
# Epoch [1/50], Step [600/600], d_loss: 1.0070, g_loss: 1.1088, D(x): 0.70, D(G(z)): 0.37
# Saving fake_images-0002.png
# Epoch [2/50], Step [200/600], d_loss: 0.9890, g_loss: 1.5099, D(x): 0.66, D(G(z)): 0.34
# Epoch [2/50], Step [400/600], d_loss: 0.7872, g_loss: 1.7836, D(x): 0.69, D(G(z)): 0.26
# Epoch [2/50], Step [600/600], d_loss: 0.8699, g_loss: 1.6214, D(x): 0.72, D(G(z)): 0.32
# Saving fake_images-0003.png
# Epoch [3/50], Step [200/600], d_loss: 0.8477, g_loss: 1.6544, D(x): 0.72, D(G(z)): 0.30
# Epoch [3/50], Step [400/600], d_loss: 0.8680, g_loss: 1.2972, D(x): 0.70, D(G(z)): 0.29
# Epoch [3/50], Step [600/600], d_loss: 0.9317, g_loss: 1.3721, D(x): 0.69, D(G(z)): 0.32
# Saving fake_images-0004.png
# Epoch [4/50], Step [200/600], d_loss: 0.6953, g_loss: 1.4533, D(x): 0.76, D(G(z)): 0.28
# Epoch [4/50], Step [400/600], d_loss: 0.9334, g_loss: 1.3235, D(x): 0.68, D(G(z)): 0.34
# Epoch [4/50], Step [600/600], d_loss: 1.1134, g_loss: 1.2499, D(x): 0.63, D(G(z)): 0.35
# Saving fake_images-0005.png
# Epoch [5/50], Step [200/600], d_loss: 1.0312, g_loss: 1.1950, D(x): 0.68, D(G(z)): 0.36
# Epoch [5/50], Step [400/600], d_loss: 1.1040, g_loss: 1.2890, D(x): 0.64, D(G(z)): 0.36
# Epoch [5/50], Step [600/600], d_loss: 1.1589, g_loss: 1.2337, D(x): 0.63, D(G(z)): 0.38
# Saving fake_images-0006.png
# Epoch [6/50], Step [200/600], d_loss: 0.8941, g_loss: 1.7658, D(x): 0.63, D(G(z)): 0.26
# Epoch [6/50], Step [400/600], d_loss: 0.8642, g_loss: 1.5308, D(x): 0.68, D(G(z)): 0.27
# Epoch [6/50], Step [600/600], d_loss: 0.7511, g_loss: 1.4567, D(x): 0.76, D(G(z)): 0.29
# Saving fake_images-0007.png
# Epoch [7/50], Step [200/600], d_loss: 0.9341, g_loss: 1.2528, D(x): 0.69, D(G(z)): 0.33
# Epoch [7/50], Step [400/600], d_loss: 1.2299, g_loss: 1.1184, D(x): 0.64, D(G(z)): 0.43
# Epoch [7/50], Step [600/600], d_loss: 0.7810, g_loss: 1.6450, D(x): 0.69, D(G(z)): 0.24
# Saving fake_images-0008.png
# Epoch [8/50], Step [200/600], d_loss: 0.9264, g_loss: 1.5386, D(x): 0.69, D(G(z)): 0.32
# Epoch [8/50], Step [400/600], d_loss: 1.1261, g_loss: 1.1763, D(x): 0.65, D(G(z)): 0.37
# Epoch [8/50], Step [600/600], d_loss: 1.0565, g_loss: 1.2797, D(x): 0.62, D(G(z)): 0.32
# Saving fake_images-0009.png
# Epoch [9/50], Step [200/600], d_loss: 1.1788, g_loss: 1.2017, D(x): 0.62, D(G(z)): 0.38
# Epoch [9/50], Step [400/600], d_loss: 0.9347, g_loss: 1.5057, D(x): 0.69, D(G(z)): 0.32
# Epoch [9/50], Step [600/600], d_loss: 0.9735, g_loss: 1.3109, D(x): 0.66, D(G(z)): 0.34
# Saving fake_images-0010.png
# Epoch [10/50], Step [200/600], d_loss: 1.1542, g_loss: 1.2647, D(x): 0.59, D(G(z)): 0.33
# Epoch [10/50], Step [400/600], d_loss: 1.0075, g_loss: 1.5592, D(x): 0.67, D(G(z)): 0.32
# Epoch [10/50], Step [600/600], d_loss: 0.9564, g_loss: 1.3908, D(x): 0.66, D(G(z)): 0.30
# Saving fake_images-0011.png
# Epoch [11/50], Step [200/600], d_loss: 0.7837, g_loss: 1.8530, D(x): 0.67, D(G(z)): 0.21
# Epoch [11/50], Step [400/600], d_loss: 0.8893, g_loss: 1.3062, D(x): 0.71, D(G(z)): 0.33
# Epoch [11/50], Step [600/600], d_loss: 0.8405, g_loss: 1.4760, D(x): 0.75, D(G(z)): 0.33
# Saving fake_images-0012.png
# Epoch [12/50], Step [200/600], d_loss: 0.8991, g_loss: 1.3112, D(x): 0.66, D(G(z)): 0.30
# Epoch [12/50], Step [400/600], d_loss: 1.0796, g_loss: 1.1303, D(x): 0.64, D(G(z)): 0.37
# Epoch [12/50], Step [600/600], d_loss: 1.0686, g_loss: 1.0784, D(x): 0.64, D(G(z)): 0.36
# Saving fake_images-0013.png
# Epoch [13/50], Step [200/600], d_loss: 1.2959, g_loss: 1.0747, D(x): 0.66, D(G(z)): 0.46
# Epoch [13/50], Step [400/600], d_loss: 1.0269, g_loss: 1.3143, D(x): 0.66, D(G(z)): 0.35
# Epoch [13/50], Step [600/600], d_loss: 0.9126, g_loss: 1.2225, D(x): 0.72, D(G(z)): 0.35
# Saving fake_images-0014.png
# Epoch [14/50], Step [200/600], d_loss: 0.7945, g_loss: 1.4749, D(x): 0.72, D(G(z)): 0.31
# Epoch [14/50], Step [400/600], d_loss: 0.9142, g_loss: 1.2509, D(x): 0.75, D(G(z)): 0.36
# Epoch [14/50], Step [600/600], d_loss: 1.2181, g_loss: 1.2434, D(x): 0.58, D(G(z)): 0.37
# Saving fake_images-0015.png
# Epoch [15/50], Step [200/600], d_loss: 1.3827, g_loss: 1.3920, D(x): 0.50, D(G(z)): 0.35
# Epoch [15/50], Step [400/600], d_loss: 1.1244, g_loss: 1.0067, D(x): 0.64, D(G(z)): 0.40
# Epoch [15/50], Step [600/600], d_loss: 0.7365, g_loss: 1.5729, D(x): 0.75, D(G(z)): 0.29
# Saving fake_images-0016.png
# Epoch [16/50], Step [200/600], d_loss: 0.9056, g_loss: 1.2485, D(x): 0.71, D(G(z)): 0.33
# Epoch [16/50], Step [400/600], d_loss: 0.9974, g_loss: 1.3610, D(x): 0.70, D(G(z)): 0.37
# Epoch [16/50], Step [600/600], d_loss: 1.0779, g_loss: 1.5476, D(x): 0.63, D(G(z)): 0.32
# Saving fake_images-0017.png
# Epoch [17/50], Step [200/600], d_loss: 1.2036, g_loss: 1.4011, D(x): 0.59, D(G(z)): 0.35
# Epoch [17/50], Step [400/600], d_loss: 1.1654, g_loss: 1.2440, D(x): 0.62, D(G(z)): 0.36
# Epoch [17/50], Step [600/600], d_loss: 1.0469, g_loss: 1.5192, D(x): 0.66, D(G(z)): 0.35
# Saving fake_images-0018.png
# Epoch [18/50], Step [200/600], d_loss: 0.8561, g_loss: 1.5602, D(x): 0.68, D(G(z)): 0.29
# Epoch [18/50], Step [400/600], d_loss: 0.7131, g_loss: 1.6581, D(x): 0.79, D(G(z)): 0.30
# Epoch [18/50], Step [600/600], d_loss: 1.0062, g_loss: 1.6843, D(x): 0.68, D(G(z)): 0.35
# Saving fake_images-0019.png
# Epoch [19/50], Step [200/600], d_loss: 0.8292, g_loss: 1.7959, D(x): 0.68, D(G(z)): 0.25
# Epoch [19/50], Step [400/600], d_loss: 0.7841, g_loss: 1.4822, D(x): 0.72, D(G(z)): 0.28
# Epoch [19/50], Step [600/600], d_loss: 0.8631, g_loss: 1.6312, D(x): 0.74, D(G(z)): 0.33
# Saving fake_images-0020.png
# Epoch [20/50], Step [200/600], d_loss: 0.9687, g_loss: 1.4254, D(x): 0.65, D(G(z)): 0.30
# Epoch [20/50], Step [400/600], d_loss: 0.9738, g_loss: 1.3964, D(x): 0.68, D(G(z)): 0.33
# Epoch [20/50], Step [600/600], d_loss: 1.1107, g_loss: 1.1786, D(x): 0.61, D(G(z)): 0.34
# Saving fake_images-0021.png
# Epoch [21/50], Step [200/600], d_loss: 0.8378, g_loss: 1.0833, D(x): 0.70, D(G(z)): 0.29
# Epoch [21/50], Step [400/600], d_loss: 0.9025, g_loss: 1.5777, D(x): 0.69, D(G(z)): 0.32
# Epoch [21/50], Step [600/600], d_loss: 1.1671, g_loss: 1.3927, D(x): 0.66, D(G(z)): 0.40
# Saving fake_images-0022.png
# Epoch [22/50], Step [200/600], d_loss: 1.1786, g_loss: 1.6240, D(x): 0.68, D(G(z)): 0.41
# Epoch [22/50], Step [400/600], d_loss: 0.9855, g_loss: 1.6065, D(x): 0.67, D(G(z)): 0.31
# Epoch [22/50], Step [600/600], d_loss: 1.1899, g_loss: 1.3167, D(x): 0.66, D(G(z)): 0.37
# Saving fake_images-0023.png
# Epoch [23/50], Step [200/600], d_loss: 1.1324, g_loss: 1.0145, D(x): 0.61, D(G(z)): 0.36
# Epoch [23/50], Step [400/600], d_loss: 0.8844, g_loss: 1.4045, D(x): 0.68, D(G(z)): 0.31
# Epoch [23/50], Step [600/600], d_loss: 0.8969, g_loss: 1.4145, D(x): 0.68, D(G(z)): 0.31
# Saving fake_images-0024.png
# Epoch [24/50], Step [200/600], d_loss: 0.9434, g_loss: 1.3436, D(x): 0.68, D(G(z)): 0.34
# Epoch [24/50], Step [400/600], d_loss: 0.8566, g_loss: 1.4708, D(x): 0.70, D(G(z)): 0.28
# Epoch [24/50], Step [600/600], d_loss: 1.1905, g_loss: 1.1965, D(x): 0.61, D(G(z)): 0.36
# Saving fake_images-0025.png
# Epoch [25/50], Step [200/600], d_loss: 1.3733, g_loss: 1.2882, D(x): 0.54, D(G(z)): 0.36
# Epoch [25/50], Step [400/600], d_loss: 0.9129, g_loss: 1.3985, D(x): 0.70, D(G(z)): 0.34
# Epoch [25/50], Step [600/600], d_loss: 0.8889, g_loss: 1.5261, D(x): 0.67, D(G(z)): 0.27
# Saving fake_images-0026.png
# Epoch [26/50], Step [200/600], d_loss: 0.8638, g_loss: 1.7305, D(x): 0.69, D(G(z)): 0.27
# Epoch [26/50], Step [400/600], d_loss: 1.1101, g_loss: 1.3317, D(x): 0.63, D(G(z)): 0.33
# Epoch [26/50], Step [600/600], d_loss: 1.0961, g_loss: 1.3151, D(x): 0.62, D(G(z)): 0.33
# Saving fake_images-0027.png
# Epoch [27/50], Step [200/600], d_loss: 0.9900, g_loss: 1.5346, D(x): 0.64, D(G(z)): 0.33
# Epoch [27/50], Step [400/600], d_loss: 0.7825, g_loss: 1.6574, D(x): 0.70, D(G(z)): 0.26
# Epoch [27/50], Step [600/600], d_loss: 1.0042, g_loss: 1.4488, D(x): 0.67, D(G(z)): 0.35
# Saving fake_images-0028.png
# Epoch [28/50], Step [200/600], d_loss: 1.3878, g_loss: 1.1221, D(x): 0.57, D(G(z)): 0.39
# Epoch [28/50], Step [400/600], d_loss: 0.9481, g_loss: 1.3580, D(x): 0.73, D(G(z)): 0.37
# Epoch [28/50], Step [600/600], d_loss: 1.0492, g_loss: 1.3631, D(x): 0.66, D(G(z)): 0.36
# Saving fake_images-0029.png
# Epoch [29/50], Step [200/600], d_loss: 1.1650, g_loss: 1.4751, D(x): 0.64, D(G(z)): 0.38
# Epoch [29/50], Step [400/600], d_loss: 0.8459, g_loss: 1.5717, D(x): 0.67, D(G(z)): 0.26
# Epoch [29/50], Step [600/600], d_loss: 0.8301, g_loss: 1.4776, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0030.png
# Epoch [30/50], Step [200/600], d_loss: 1.2601, g_loss: 1.2423, D(x): 0.61, D(G(z)): 0.38
# Epoch [30/50], Step [400/600], d_loss: 1.2265, g_loss: 1.3131, D(x): 0.59, D(G(z)): 0.38
# Epoch [30/50], Step [600/600], d_loss: 0.6679, g_loss: 1.8094, D(x): 0.75, D(G(z)): 0.26
# Saving fake_images-0031.png
# Epoch [31/50], Step [200/600], d_loss: 1.1834, g_loss: 1.1289, D(x): 0.65, D(G(z)): 0.40
# Epoch [31/50], Step [400/600], d_loss: 1.3026, g_loss: 1.3342, D(x): 0.57, D(G(z)): 0.36
# Epoch [31/50], Step [600/600], d_loss: 0.9071, g_loss: 1.3134, D(x): 0.72, D(G(z)): 0.35
# Saving fake_images-0032.png
# Epoch [32/50], Step [200/600], d_loss: 1.1237, g_loss: 1.3559, D(x): 0.60, D(G(z)): 0.32
# Epoch [32/50], Step [400/600], d_loss: 0.8205, g_loss: 1.4777, D(x): 0.69, D(G(z)): 0.28
# Epoch [32/50], Step [600/600], d_loss: 0.8374, g_loss: 1.6034, D(x): 0.73, D(G(z)): 0.30
# Saving fake_images-0033.png
# Epoch [33/50], Step [200/600], d_loss: 1.1035, g_loss: 1.1106, D(x): 0.68, D(G(z)): 0.40
# Epoch [33/50], Step [400/600], d_loss: 0.9811, g_loss: 1.4432, D(x): 0.64, D(G(z)): 0.28
# Epoch [33/50], Step [600/600], d_loss: 0.8858, g_loss: 1.3481, D(x): 0.67, D(G(z)): 0.29
# Saving fake_images-0034.png
# Epoch [34/50], Step [200/600], d_loss: 0.9699, g_loss: 1.2956, D(x): 0.69, D(G(z)): 0.36
# Epoch [34/50], Step [400/600], d_loss: 0.8705, g_loss: 1.5389, D(x): 0.72, D(G(z)): 0.31
# Epoch [34/50], Step [600/600], d_loss: 1.1545, g_loss: 1.2589, D(x): 0.66, D(G(z)): 0.39
# Saving fake_images-0035.png
# Epoch [35/50], Step [200/600], d_loss: 1.0781, g_loss: 1.3051, D(x): 0.68, D(G(z)): 0.38
# Epoch [35/50], Step [400/600], d_loss: 1.0834, g_loss: 1.3045, D(x): 0.64, D(G(z)): 0.36
# Epoch [35/50], Step [600/600], d_loss: 0.8773, g_loss: 1.3107, D(x): 0.69, D(G(z)): 0.31
# Saving fake_images-0036.png
# Epoch [36/50], Step [200/600], d_loss: 0.9926, g_loss: 1.3857, D(x): 0.66, D(G(z)): 0.32
# Epoch [36/50], Step [400/600], d_loss: 1.0821, g_loss: 1.4552, D(x): 0.62, D(G(z)): 0.32
# Epoch [36/50], Step [600/600], d_loss: 1.1507, g_loss: 1.2996, D(x): 0.61, D(G(z)): 0.36
# Saving fake_images-0037.png
# Epoch [37/50], Step [200/600], d_loss: 1.2898, g_loss: 1.5260, D(x): 0.55, D(G(z)): 0.34
# Epoch [37/50], Step [400/600], d_loss: 0.8885, g_loss: 1.3019, D(x): 0.71, D(G(z)): 0.33
# Epoch [37/50], Step [600/600], d_loss: 1.0771, g_loss: 1.4042, D(x): 0.67, D(G(z)): 0.34
# Saving fake_images-0038.png
# Epoch [38/50], Step [200/600], d_loss: 1.1019, g_loss: 1.4437, D(x): 0.61, D(G(z)): 0.31
# Epoch [38/50], Step [400/600], d_loss: 0.9210, g_loss: 1.5428, D(x): 0.68, D(G(z)): 0.31
# Epoch [38/50], Step [600/600], d_loss: 0.8494, g_loss: 1.4654, D(x): 0.70, D(G(z)): 0.30
# Saving fake_images-0039.png
# Epoch [39/50], Step [200/600], d_loss: 0.8890, g_loss: 1.3670, D(x): 0.68, D(G(z)): 0.31
# Epoch [39/50], Step [400/600], d_loss: 0.9555, g_loss: 1.1680, D(x): 0.69, D(G(z)): 0.35
# Epoch [39/50], Step [600/600], d_loss: 1.0991, g_loss: 1.3720, D(x): 0.61, D(G(z)): 0.34
# Saving fake_images-0040.png
# Epoch [40/50], Step [200/600], d_loss: 0.8608, g_loss: 1.5476, D(x): 0.74, D(G(z)): 0.34
# Epoch [40/50], Step [400/600], d_loss: 1.5047, g_loss: 0.9583, D(x): 0.58, D(G(z)): 0.47
# Epoch [40/50], Step [600/600], d_loss: 1.0144, g_loss: 1.6273, D(x): 0.64, D(G(z)): 0.31
# Saving fake_images-0041.png
# Epoch [41/50], Step [200/600], d_loss: 1.0469, g_loss: 1.5249, D(x): 0.64, D(G(z)): 0.32
# Epoch [41/50], Step [400/600], d_loss: 0.9654, g_loss: 1.2559, D(x): 0.68, D(G(z)): 0.33
# Epoch [41/50], Step [600/600], d_loss: 0.9461, g_loss: 1.3824, D(x): 0.65, D(G(z)): 0.28
# Saving fake_images-0042.png
# Epoch [42/50], Step [200/600], d_loss: 0.9433, g_loss: 1.2056, D(x): 0.67, D(G(z)): 0.34
# Epoch [42/50], Step [400/600], d_loss: 0.8949, g_loss: 1.4454, D(x): 0.70, D(G(z)): 0.32
# Epoch [42/50], Step [600/600], d_loss: 0.9632, g_loss: 1.4468, D(x): 0.69, D(G(z)): 0.34
# Saving fake_images-0043.png
# Epoch [43/50], Step [200/600], d_loss: 1.1676, g_loss: 1.1266, D(x): 0.66, D(G(z)): 0.41
# Epoch [43/50], Step [400/600], d_loss: 0.8977, g_loss: 1.4223, D(x): 0.68, D(G(z)): 0.31
# Epoch [43/50], Step [600/600], d_loss: 0.8205, g_loss: 1.6811, D(x): 0.74, D(G(z)): 0.31
# Saving fake_images-0044.png
# Epoch [44/50], Step [200/600], d_loss: 1.2190, g_loss: 1.3950, D(x): 0.64, D(G(z)): 0.41
# Epoch [44/50], Step [400/600], d_loss: 1.0276, g_loss: 1.4263, D(x): 0.64, D(G(z)): 0.31
# Epoch [44/50], Step [600/600], d_loss: 0.9486, g_loss: 1.7189, D(x): 0.67, D(G(z)): 0.30
# Saving fake_images-0045.png
# Epoch [45/50], Step [200/600], d_loss: 1.0376, g_loss: 1.4063, D(x): 0.68, D(G(z)): 0.36
# Epoch [45/50], Step [400/600], d_loss: 0.9990, g_loss: 1.4675, D(x): 0.62, D(G(z)): 0.30
# Epoch [45/50], Step [600/600], d_loss: 0.8784, g_loss: 1.5526, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0046.png
# Epoch [46/50], Step [200/600], d_loss: 1.1811, g_loss: 1.2200, D(x): 0.63, D(G(z)): 0.39
# Epoch [46/50], Step [400/600], d_loss: 1.0164, g_loss: 1.3471, D(x): 0.68, D(G(z)): 0.40
# Epoch [46/50], Step [600/600], d_loss: 1.1254, g_loss: 1.3582, D(x): 0.62, D(G(z)): 0.33
# Saving fake_images-0047.png
# Epoch [47/50], Step [200/600], d_loss: 1.1632, g_loss: 1.1426, D(x): 0.62, D(G(z)): 0.39
# Epoch [47/50], Step [400/600], d_loss: 0.8850, g_loss: 1.3605, D(x): 0.68, D(G(z)): 0.29
# Epoch [47/50], Step [600/600], d_loss: 1.0511, g_loss: 1.2451, D(x): 0.63, D(G(z)): 0.33
# Saving fake_images-0048.png
# Epoch [48/50], Step [200/600], d_loss: 1.2902, g_loss: 1.1114, D(x): 0.58, D(G(z)): 0.37
# Epoch [48/50], Step [400/600], d_loss: 0.9331, g_loss: 1.5323, D(x): 0.65, D(G(z)): 0.29
# Epoch [48/50], Step [600/600], d_loss: 0.8443, g_loss: 1.4641, D(x): 0.69, D(G(z)): 0.27
# Saving fake_images-0049.png
# Epoch [49/50], Step [200/600], d_loss: 1.2387, g_loss: 1.1542, D(x): 0.61, D(G(z)): 0.40
# Epoch [49/50], Step [400/600], d_loss: 1.1635, g_loss: 1.3203, D(x): 0.62, D(G(z)): 0.35
# Epoch [49/50], Step [600/600], d_loss: 0.8540, g_loss: 1.7902, D(x): 0.67, D(G(z)): 0.28
# Saving fake_images-0050.png

# %% [markdown]
# # Step 7: Save the model weights without using checkpoints.

# %%
torch.save(G.state_dict(), 'generator_weights_no_checkpoint.pth')
torch.save(D.state_dict(), 'discriminator_weights_no_checkpoint.pth')

# %% [markdown]
# #Step 8: Load the model weights without using checkpoints.

# %%
G_no_checkpoint = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh()
)

D_no_checkpoint = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid()
)

G_no_checkpoint.load_state_dict(torch.load('generator_weights_no_checkpoint.pth'))
D_no_checkpoint.load_state_dict(torch.load('discriminator_weights_no_checkpoint.pth'))
# Out:
# <All keys matched successfully>

# %%
Image(os.path.join(sample_dir, 'fake_images-0001.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0015.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0030.png'))

# %%
Image(os.path.join(sample_dir, 'fake_images-0050.png'))

# %% [markdown]
# The output the images is improved and is close to the original image

# %%
Image(os.path.join(sample_dir, 'real_images.png'))
